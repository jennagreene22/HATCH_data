# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
# don't use default na, this mistakenly converts 'NA' (iso code for Namibia) to a missing value
# I manually input all the default na vals except for 'NA' to prevent this
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
all_tech = pd.read_csv('all_tech_version 2.0.csv', keep_default_na=False, 
                       na_values=['-1.#IND', '1.#QNAN', '1.#IND', '-1.#QNAN', '#N/A N/A', '#N/A', 'N/A', 'n/a', 
                                  '<NA>', '#NA', 'NULL', 'null', 'NaN', '-NaN', 'nan', '-nan', 'None', ''])
all_tech
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 8638             Tin Production_Annual production_World        Global
# 8639        Objects Launched Into Space_Total Number_UA      National
# 8640        Objects Launched Into Space_Total Number_TM      National
# 8641         Liquefied Natural Gas_Annual Production_US      National
# 8642        Objects Launched Into Space_Total Number_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 8638        World          World               Tin Production
# 8639           UA        Ukraine  Objects Launched Into Space
# 8640           TM   Turkmenistan  Objects Launched Into Space
# 8641           US  United States        Liquefied Natural Gas
# 8642           CO       Colombia  Objects Launched Into Space
#
#                          Metric                Unit Data Source  \
# 0        Cumulative Rated Power                  kW       GESDB
# 1     Cumulative Rated Capacity                 kWh       GESDB
# 2        Cumulative Rated Power                  kW       GESDB
# 3     Cumulative Rated Capacity                 kWh       GESDB
# 4      Levelized Cost of Energy        2022 USD/kWh       IRENA
# ...                         ...                 ...         ...
# 8638          Annual production         metric tons        USGS
# 8639               Total Number                   -      UNOOSA
# 8640               Total Number                   -      UNOOSA
# 8641          Annual Production  billion cubic feet         EIA
# 8642               Total Number                   -      UNOOSA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 8638                   Annual production|Tin Production   NaN  ...
# 8639           Total Number|Objects Launched Into Space   NaN  ...
# 8640           Total Number|Objects Launched Into Space   NaN  ...
# 8641            Annual Production|Liquefied Natural Gas   NaN  ...
# 8642           Total Number|Objects Launched Into Space   NaN  ...
#
#               2016          2017          2018           2019         2020  \
# 0              NaN  1.900000e+02  2.900000e+02            NaN          NaN
# 1              NaN  7.600000e+02  1.160000e+03            NaN          NaN
# 2     2.550000e+05  3.550000e+05  4.550000e+05            NaN          NaN
# 3     1.195000e+06  1.745000e+06  2.945000e+06            NaN          NaN
# 4     5.929609e-02  4.898293e-02  4.679236e-02       0.048501     0.042769
# ...            ...           ...           ...            ...          ...
# 8638  5.226023e+05  5.767229e+05  5.462801e+05  500615.785555          NaN
# 8639           NaN           NaN           NaN            NaN          NaN
# 8640           NaN           NaN           NaN            NaN          NaN
# 8641  1.868400e+02  7.075400e+02  1.083120e+03    1819.400000  2389.840000
# 8642           NaN           NaN  1.000000e+00            NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 8638      NaN   NaN   NaN   NaN   NaN
# 8639      NaN   1.0   NaN   NaN   NaN
# 8640      NaN   NaN   NaN   NaN   NaN
# 8641  3560.82   NaN   NaN   NaN   NaN
# 8642      NaN   NaN   NaN   NaN   NaN
#
# [8643 rows x 335 columns]

# %%
# check that all data points should be float or int, everything else is str
for col in all_tech.columns[9:]:
    for val in all_tech[col]:
        if type(val)!=float and type(val)!=int:
            print(col, val, type(val))

# %%
for col in all_tech.columns[:9]:
    for val in all_tech[col]:
        if type(val)!=str:
            print(col, val, type(val))

# %%
# checking for all unique IDs (technology/metric/country)
dup = []
for x in all_tech['ID']:
    if x not in dup:
        dup.append(x)
    else:
        print(x)

# %%
# DEU is for Western Germany
# (to distinguish from Germany before 1945 and after 1990, current iso2 code DE refers to both)
# KOR is for Korea (to distinguish from South Korea after 1950, current iso2 code KR refers to both)
# CSK is for Czechoslovakia (to distinguish from Czech Republic after 1992, CZ, and Serbia and Montenegro, CS)
# VNM is for South Vietnam (to distinguish from Vietnam from 1955-1975, now VN refers to both)
country_codes = list(set(all_tech['Country Code']))
for code in country_codes:
    if len(code) != 2:
        print(code)
# Out:
# Europe
# KOR
# Asia
# World
# DEU
# Rest of World
# VNM
# North America
# CSK

# %%
# checking that spatial scale is either Global or National
set(all_tech['Spatial Scale'])
# Out:
# {'Global', 'National'}

# %%
# checking that all rows characterized as Global have Country Code that is World
set(all_tech[all_tech['Spatial Scale']=='Global']['Country Code'])
# Out:
# {'Rest of World', 'World'}

# %%
# checking that all rows characterized as Global have Country Name that is World
set(all_tech[all_tech['Spatial Scale']=='Global']['Country Name'])
# Out:
# {'Rest of World', 'World'}

# %%
set(all_tech[all_tech['Country Name']=='World']['Country Code'])
# Out:
# {'World'}

# %%
set(all_tech[all_tech['Country Name']=='World']['Spatial Scale'])
# Out:
# {'Global'}

# %%
set(all_tech[all_tech['Country Code']=='World']['Spatial Scale'])
# Out:
# {'Global'}

# %%
set(all_tech[all_tech['Country Name']=='World']['Country Name'])
# Out:
# {'World'}

# %%
country_names = list(set(all_tech['Country Name']))

# %%
# check that country codes that map onto multiple country names are all referring to the same entity
# e.g., make sure North Korea and South Korea aren't mapped onto the same code
country_code_dict = {}
for code in country_codes:
    country_code_dict[code] = None
    
for code in country_code_dict:
    name_list = list(set(all_tech[all_tech['Country Code']==code]['Country Name']))
    country_code_dict[code] = name_list

for code in country_code_dict:
    if len(country_code_dict[code]) > 1:
        print(code, country_code_dict[code])
# Out:
# KG ['Kyrgyzstan', 'Kyrgistan', 'Kyrgyz Republic']
# US ['United States', 'Boeing', 'USA', 'US', 'United States of America']
# AE ['United Arab Emirates', 'UAE']
# SU ['U.S.S.R.', 'USSR']
# TR ['Turkey', 'Türkiye', 'Turkiye']
# TT ['Trinidad and Tobago', 'Trinidad & Tobago']
# BF ['Burkina Faso', 'Burkina-Faso']
# FM ['Micronesia, Fed. Sts.', 'Micronesia (Federated States of)']
# MM ['Burma', 'Myanmar']
# LA ["Lao People's Democratic Republic", 'Laos', 'Lao PDR']
# KN ['Saint Kitts and Nevis', 'St. Kitts and Nevis']
# CZ ['Czechia', 'Czech Republic']
# MF ['St. Martin (French part)', 'Saint Martin (French Part)']
# NL ['Netherlands', 'Netherlands (Kingdom of the)']
# SZ ['Swaziland', 'Eswatini']
# EG ['Egypt', 'Egypt, Arab Rep.']
# YE ['Yemen, Rep.', 'Yemen']
# GM ['Gambia, The', 'Gambia']
# LC ['St. Lucia', 'Saint Lucia']
# CD ['Democratic Republic of Congo', 'Congo (Kinshasa)', 'Democratic Republic of the Congo', 'Congo, Dem. Rep.', 'Zaire']
# VN ['Viet Nam', 'Vietnam']
# VI ['United States Virgin Islands', 'Virgin Islands (U.S.)']
# MD ['Moldova', 'Republic of Moldova']
# PS ['State of Palestine', 'West Bank and Gaza']
# CN ['China', 'China, mainland']
# PH ['Phillipines', 'Philippines', 'Phillipine']
# BO ['Bolivia', 'Bolivia (Plurinational State of)']
# IR ['Iran (Islamic Republic of)', 'Iran, Islamic Rep.', 'Iran']
# KR ['Korea, Rep.', 'Korea, Republic of', 'Republic of Korea', 'South Korea']
# TZ ['Tanzania', 'United Republic of Tanzania']
# RU ['Russian Federation', 'Russia']
# TW ['China, Taiwan Province of', 'Taiwan', 'Chinese Taipei']
# CW ['Curacao', 'Curaçao']
# VNM ['South Vietnam', 'Southern Vietnam']
# BA ['Bosnia-Herzegovina', 'Bosnia and Herzegovina']
# SY ['Syria', 'Syrian Arab Republic']
# VC ['Saint Vincent and the Grenadines', 'St. Vincent and the Grenadines']
# VE ['Venezuela (Bolivarian Republic of)', 'Venezuela, RB', 'Venezuela']
# KP ['North Korea', "Democratic People's Republic of Korea", 'Korea, North', "Korea, Dem. People's Rep."]
# YU ['Yugoslavia', 'Yugoslav SFR']
# HK ['Hong Kong', 'China, Hong Kong SAR', 'China, Hong Kong Special Administrative Region', 'China Hong Kong SAR', 'Hong Kong SAR, China']
# CG ['Republic of the Congo', 'Congo', 'Congo, Rep.', 'Republic of Congo ']
# BS ['Bahamas', 'Bahamas, The']
# MK ['North Macedonia', 'The former Yugoslav Republic of Macedonia', 'Macedonia', 'Republic of North Macedonia']
# CI ["Cote d'Ivoire", "Côte d'Ivoire", 'Ivory Coast']
# SK ['Slovak Republic', 'Slovakia']
# BN ['Brunei Darussalam', 'Brunei']
# CV ['Cape Verde', 'Cabo Verde']
# GB ['UK', 'United Kingdom', 'United Kingdom of Great Britain and Northern Ireland']

# %%
# check that all countries map onto one code (i.e. 'Czechoslovakia' should not map onto both 'CZ' and 'CSK')
country_name_dict = {}
for country in country_names:
    country_name_dict[country] = None

for code in country_name_dict:
    code_list = list(set(all_tech[all_tech['Country Name']==code]['Country Code']))
    country_name_dict[code] = code_list

for country in country_name_dict:
    if len(country_name_dict[country]) > 1:
        print(country)

# %%
# check for monotonically increasing values where metric is cumulative
cum_idx = []
for idx in range(len(all_tech)):
    metric = all_tech.iloc[idx]['Metric']
    if 'Cumulative' in metric:
        cum_idx.append(idx)
        
for idx in cum_idx:
    row = all_tech.iloc[idx][9:]
    row.dropna(inplace=True)
    cum_sum = None
    for val in row:
        if cum_sum == None:
            cum_sum = val
            continue
        if val < cum_sum:
            tech = all_tech.iloc[idx]['Technology Name']
            country = all_tech.iloc[idx]['Country Name']
            print('error!', tech, country)
            break

# %%
# check for 0<x<1 where metric is share
share_idx = []
for idx in range(len(all_tech)):
    metric = all_tech.iloc[idx]['Metric']
    if 'Share' in metric:
        share_idx.append(idx)

for idx in share_idx:
    row = all_tech.iloc[idx][9:]
    row.dropna(inplace=True)
    for val in row:
        if val < 0 or val > 1:
            print('error!', tech, country)
            break
