# %%
import pandas as pd
from pandas import Series, DataFrame
import os
import locale
from locale import atof

# %%
path = 'cleaned data/'
clean_files = os.listdir(path)

# %%
csv = []
for file in clean_files:
    if '.csv' in file:
        name = path + file
        csv.append(name)

# %%
frame = pd.read_csv('cleaned data/frame.csv')
frame
# Out:
# Empty DataFrame
# Columns: [ID, Spatial Scale, Country Code, Country Name, Technology Name, Metric, Unit, Data Source, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, ...]
# Index: []
#
# [0 rows x 334 columns]

# %%
locale.setlocale(locale.LC_NUMERIC, '')
# Out:
# 'en_US.UTF-8'

# %%
# don't use default na, this erroneously converts 'NA' (iso code for Namibia) to a missing value
# I manually input all the default na vals except for 'NA' to prevent this
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
df_list = [frame]
for file in csv:
    file = pd.read_csv(file, thousands=',',keep_default_na=False, 
                       na_values=['-1.#IND', '1.#QNAN', '1.#IND', '-1.#QNAN', '#N/A N/A', '#N/A', 'N/A', 'n/a', 
                                  '<NA>', '#NA', 'NULL', 'null', 'NaN', '-NaN', 'nan', '-nan', 'None', ''])
    df_list.append(file)

# %%
all_tech_df = pd.concat(df_list)
all_tech_df
# Out:
#                                                    ID Spatial Scale  \
# 0   Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1   Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 0     Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 1   Sensible Heat Storage_Cumulative Rated Capacit...      National
# 0     Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ..                                                ...           ...
# 2              Tin Production_Annual production_World        Global
# 0         Objects Launched Into Space_Total Number_UA      National
# 0         Objects Launched Into Space_Total Number_TM      National
# 0          Liquefied Natural Gas_Annual Production_US      National
# 0         Objects Launched Into Space_Total Number_CO      National
#
#    Country Code   Country Name              Technology Name  \
# 0            TG           Togo  Lithium-Ion Battery Storage
# 1            TG           Togo  Lithium-Ion Battery Storage
# 0            ZA   South Africa        Sensible Heat Storage
# 1            ZA   South Africa        Sensible Heat Storage
# 0            DK        Denmark          Onshore Wind Energy
# ..          ...            ...                          ...
# 2         World          World               Tin Production
# 0            UA        Ukraine  Objects Launched Into Space
# 0            TM   Turkmenistan  Objects Launched Into Space
# 0            US  United States        Liquefied Natural Gas
# 0            CO       Colombia  Objects Launched Into Space
#
#                        Metric                Unit Data Source  1700  1701  \
# 0      Cumulative Rated Power                  kW       GESDB   NaN   NaN
# 1   Cumulative Rated Capacity                 kWh       GESDB   NaN   NaN
# 0      Cumulative Rated Power                  kW       GESDB   NaN   NaN
# 1   Cumulative Rated Capacity                 kWh       GESDB   NaN   NaN
# 0    Levelized Cost of Energy        2022 USD/kWh       IRENA   NaN   NaN
# ..                        ...                 ...         ...   ...   ...
# 2           Annual production         metric tons        USGS   NaN   NaN
# 0                Total Number                   -      UNOOSA   NaN   NaN
# 0                Total Number                   -      UNOOSA   NaN   NaN
# 0           Annual Production  billion cubic feet         EIA   NaN   NaN
# 0                Total Number                   -      UNOOSA   NaN   NaN
#
#     ...          2016          2017          2018           2019         2020  \
# 0   ...           NaN  1.900000e+02  2.900000e+02            NaN          NaN
# 1   ...           NaN  7.600000e+02  1.160000e+03            NaN          NaN
# 0   ...  2.550000e+05  3.550000e+05  4.550000e+05            NaN          NaN
# 1   ...  1.195000e+06  1.745000e+06  2.945000e+06            NaN          NaN
# 0   ...  5.929609e-02  4.898293e-02  4.679236e-02       0.048501     0.042769
# ..  ...           ...           ...           ...            ...          ...
# 2   ...  5.226023e+05  5.767229e+05  5.462801e+05  500615.785555          NaN
# 0   ...           NaN           NaN           NaN            NaN          NaN
# 0   ...           NaN           NaN           NaN            NaN          NaN
# 0   ...  1.868400e+02  7.075400e+02  1.083120e+03    1819.400000  2389.840000
# 0   ...           NaN           NaN  1.000000e+00            NaN          NaN
#
#        2021  2022  2023  2024  2025
# 0       NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN
# 0       NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN
# 0       NaN   NaN   NaN   NaN   NaN
# ..      ...   ...   ...   ...   ...
# 2       NaN   NaN   NaN   NaN   NaN
# 0       NaN   1.0   NaN   NaN   NaN
# 0       NaN   NaN   NaN   NaN   NaN
# 0   3560.82   NaN   NaN   NaN   NaN
# 0       NaN   NaN   NaN   NaN   NaN
#
# [8652 rows x 334 columns]

# %%
len(set(all_tech_df['Technology Name']))
# Out:
# 252

# %%
for x in set(all_tech_df['Technology Name']):
    print(x)
# Out:
# Ammonia Synthesis
# Electronic Ignition
# Neoprene Rubber
# Primary Magnesium
# Synthetic Filament Tow and Staple Fibers
# Geothermal Energy
# Silver
# Electric Bicycles
# Flue Gas Desulphurization (Wet and Dry)
# Central Heating
# Television Receivers
# Tin
# Jet Aircraft
# Vinyl Acetate
# Ethanolamine
# Microprocessor Clock Speed
# Raw Steel Production
# Steamships
# Rare Earth Mine Production
# Pumped Hydro Storage
# Aquaculture Production
# Fluid Catalytic Cracking Refineries
# Objects Launched Into Space
# Low-Density Polyethylene
# Nitric Acid
# Vacuum Cleaners
# Capillary DNA Sequencing
# Aniline
# Hydroelectricity
# Zinc
# Iron
# Videocassette Recorder
# IPV1 Vaccine
# Running Water
# Household Washing and Drying Machines
# Motorcycles and Scooters
# Telephones and Videophones
# Pentaerythritol
# Disk Brakes
# Lithium-Ion Cells
# Colour TV
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Natural Gas Power
# Railroad
# Acrylonitrile
# Herbicide-Tolerant Soybeans
# Salt Production
# Passenger Vehicles
# Sodium-Based Battery Storage
# Oil Refining Capacity
# Coal Power
# Vinyl Chloride
# Shotgun Sanger DNA Sequencing
# RCV1 Vaccine
# Cars
# Freezer
# Home Air Conditioning
# Solar Thermal Energy
# Polyvinylchloride
# Submarine Cables
# Gold
# Postal Traffic
# DTP1 Vaccine
# Oil Production
# BCG Vaccine
# Sensible Heat Storage
# Ethylene Glycol
# Air Conditioning Machines
# Nitrogenous Fertilizers
# HEPBB Vaccine
# Styrene
# Concentrating Solar Power
# POL3 Vaccine
# High-Density Polyethylene
# Paraxylene
# Hydropower
# Electric Range
# Lithium-Ion Battery Storage
# Sand and Gravel|Construction
# PCV3 Vaccine
# Public Roads
# Telegraph Traffic
# CFLs
# Household Internet Access
# Primary Copper
# DTP3 Vaccine
# Amazon Prime Users
# Flow Battery Storage
# Lead
# Podcasting
# YFV Vaccine
# Insect-Resistant Cotton
# Refrigerators
# Nitrogen Fertilizer
# Maleic Anhydride
# Primary Bauxite Production
# Sugar Cane Production
# Home Computers
# Carbon Capture and Sequestration
# Liquefied Natural Gas (LNG)
# Tablet
# Herbicide-Tolerant Corn
# DNA Sequencing (All Methods)
# Dishwashers
# Lead-Acid Battery Storage
# Radio
# Desalination Capacity
# Concentrated Solar Power
# Microcomputers
# Urea
# Crude Petroleum
# Transistors per Microprocessor
# Power Steering
# Ground Source Heat Pumps
# Cable TV
# Motor Gasoline
# Cotton Seed Production
# Offshore Wind Energy
# Renewable Power
# MCV2 Vaccine
# Phenol
# Hydrogen Storage
# Liquid Biofuels
# Polystyrene
# Crude Oil
# High-Speed Rail
# Combined Refrigerators-Freezers
# Magnetic Data Storage
# Soybean Production
# Sugar Output
# Households With Only Mobile Phones (No Landlines)
# Cellphones
# HIB3 Vaccine
# Heat Thermal Battery Storage
# Processor Performance
# Nickel
# Iron Ore
# Flush Toilet
# Passenger Cars
# Capture Fisheries
# ROTAC Vaccine
# HEPB3 Vaccine
# Gold Production
# Nuclear Energy
# Marine Energy
# Bicycles and Other Cycles
# Bioenergy
# Primary Aluminum Production
# Sodium Chlorate
# Bicycles
# Ebook Reader
# Household Refrigerators and Freezers
# Tin Production
# Titanium Sponge
# Nox Pollution Controls (Boilers)
# Compressed Air Energy Storage
# BisphenolA
# Oil Pipeline
# Graphite
# Latent Heat Storage
# Potassic Fertilizers
# MCV1 Vaccine
# Wet Flue Gas Desulfurization Systems
# Methanol
# Hydropower Mega-Dams
# Stationary Steam Engines
# Lithium Mine Production
# Internet Backbone Bandwidth
# Lead-Acid Battery
# Silver Production
# Herbicide-Tolerant Cotton
# Cobalt
# Flywheel Battery Storage
# Caustic Soda
# Synthetic Filament Yarn
# Copper|Refining
# Television
# Caprolactam
# Random Access Memory
# Nickel Production
# Sulphuric Acid
# Beer Production
# Space Launches
# Sand and Gravel|Industrial
# Sodium
# Ethylene
# Cyclohexane
# Shale Production
# Motorcycles
# Computing Growth
# Vacuums
# Onshore Wind Energy
# Vanadium Redox-Flow Battery
# Radial Tires
# Microwaves
# Corn Production
# Solar Photovoltaic
# Coal Production
# Automatic Transmission
# Washing Machines
# Artificial and Synthetic Fibers
# Liquefied Natural Gas
# Smartphone Usage
# Electro-Chemical Capacitor
# Electricity
# Natural Gas Pipeline
# Radio Receivers
# Nickel-Based Battery
# Nickel-Metal Hydride Battery
# Formaldehyde
# Compact Fluorescent Light Bulbs
# Benzene
# Polyester Fiber
# Telephones
# Phthalic Anhydride
# Refined Copper
# Zinc Production
# Natural Gas Production
# Laundry Dryers
# Biofuels Production
# Canals
# Electric Water Heaters and Immersion Heaters
# Beer
# Cow's Milk Production
# Cadmium Refining
# Stove
# Sodium-Sulphur Battery
# Potash Fertilizer
# Cement
# Insect-Resistant Corn
# Zinc-Based Battery
# Biogas
# Solid Biofuels
# Acrylic Fiber
# Microwave Ovens
# Crop Harvester
# Pumped Hydropower
# Social Media Usage
# Milk
# Nuclear Weapons
# Hydrochloric Acid
# Air-Source Heat Pumps
# Hydrofluoric Acid
# Real-Time Gross Settlement Adoption
# Copper|Mining
# Phosphate Fertilizer
# Water Heater
# Ethanol
# Internet Traffic
# Steam Locomotives
# Magnesium
# Caustic Soda Acid

# %%
all_tech_df[all_tech_df['Technology Name']=='Bicycles']
# Out:
#                                          ID Spatial Scale Country Code  \
# 2  Bicycles_Cumulative Total Capacity_World        Global        World
#
#   Country Name Technology Name                     Metric Unit  \
# 2        World        Bicycles  Cumulative Total Capacity   MW
#
#         Data Source  1700  1701  ...  2016  2017  2018  2019  2020  2021  \
# 2  Wilson & Grubler   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2022  2023  2024  2025
# 2   NaN   NaN   NaN   NaN
#
# [1 rows x 334 columns]

# %%
#all_tech_df['Technology Name'] = all_tech_df['Technology Name'].str.title()

# %%
all_tech_df.insert(8, 'Long Technology Name', all_tech_df['Metric'] + '|' + all_tech_df['Technology Name'])
all_tech_df
# Out:
#                                                    ID Spatial Scale  \
# 0   Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1   Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 0     Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 1   Sensible Heat Storage_Cumulative Rated Capacit...      National
# 0     Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ..                                                ...           ...
# 2              Tin Production_Annual production_World        Global
# 0         Objects Launched Into Space_Total Number_UA      National
# 0         Objects Launched Into Space_Total Number_TM      National
# 0          Liquefied Natural Gas_Annual Production_US      National
# 0         Objects Launched Into Space_Total Number_CO      National
#
#    Country Code   Country Name              Technology Name  \
# 0            TG           Togo  Lithium-Ion Battery Storage
# 1            TG           Togo  Lithium-Ion Battery Storage
# 0            ZA   South Africa        Sensible Heat Storage
# 1            ZA   South Africa        Sensible Heat Storage
# 0            DK        Denmark          Onshore Wind Energy
# ..          ...            ...                          ...
# 2         World          World               Tin Production
# 0            UA        Ukraine  Objects Launched Into Space
# 0            TM   Turkmenistan  Objects Launched Into Space
# 0            US  United States        Liquefied Natural Gas
# 0            CO       Colombia  Objects Launched Into Space
#
#                        Metric                Unit Data Source  \
# 0      Cumulative Rated Power                  kW       GESDB
# 1   Cumulative Rated Capacity                 kWh       GESDB
# 0      Cumulative Rated Power                  kW       GESDB
# 1   Cumulative Rated Capacity                 kWh       GESDB
# 0    Levelized Cost of Energy        2022 USD/kWh       IRENA
# ..                        ...                 ...         ...
# 2           Annual production         metric tons        USGS
# 0                Total Number                   -      UNOOSA
# 0                Total Number                   -      UNOOSA
# 0           Annual Production  billion cubic feet         EIA
# 0                Total Number                   -      UNOOSA
#
#                                  Long Technology Name  1700  ...  \
# 0   Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1   Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 0        Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 1     Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 0        Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ..                                                ...   ...  ...
# 2                    Annual production|Tin Production   NaN  ...
# 0            Total Number|Objects Launched Into Space   NaN  ...
# 0            Total Number|Objects Launched Into Space   NaN  ...
# 0             Annual Production|Liquefied Natural Gas   NaN  ...
# 0            Total Number|Objects Launched Into Space   NaN  ...
#
#             2016          2017          2018           2019         2020  \
# 0            NaN  1.900000e+02  2.900000e+02            NaN          NaN
# 1            NaN  7.600000e+02  1.160000e+03            NaN          NaN
# 0   2.550000e+05  3.550000e+05  4.550000e+05            NaN          NaN
# 1   1.195000e+06  1.745000e+06  2.945000e+06            NaN          NaN
# 0   5.929609e-02  4.898293e-02  4.679236e-02       0.048501     0.042769
# ..           ...           ...           ...            ...          ...
# 2   5.226023e+05  5.767229e+05  5.462801e+05  500615.785555          NaN
# 0            NaN           NaN           NaN            NaN          NaN
# 0            NaN           NaN           NaN            NaN          NaN
# 0   1.868400e+02  7.075400e+02  1.083120e+03    1819.400000  2389.840000
# 0            NaN           NaN  1.000000e+00            NaN          NaN
#
#        2021  2022  2023  2024  2025
# 0       NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN
# 0       NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN
# 0       NaN   NaN   NaN   NaN   NaN
# ..      ...   ...   ...   ...   ...
# 2       NaN   NaN   NaN   NaN   NaN
# 0       NaN   1.0   NaN   NaN   NaN
# 0       NaN   NaN   NaN   NaN   NaN
# 0   3560.82   NaN   NaN   NaN   NaN
# 0       NaN   NaN   NaN   NaN   NaN
#
# [8652 rows x 335 columns]

# %%
all_tech_df.reset_index(drop=True,inplace=True)
all_tech_df
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 8647             Tin Production_Annual production_World        Global
# 8648        Objects Launched Into Space_Total Number_UA      National
# 8649        Objects Launched Into Space_Total Number_TM      National
# 8650         Liquefied Natural Gas_Annual Production_US      National
# 8651        Objects Launched Into Space_Total Number_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 8647        World          World               Tin Production
# 8648           UA        Ukraine  Objects Launched Into Space
# 8649           TM   Turkmenistan  Objects Launched Into Space
# 8650           US  United States        Liquefied Natural Gas
# 8651           CO       Colombia  Objects Launched Into Space
#
#                          Metric                Unit Data Source  \
# 0        Cumulative Rated Power                  kW       GESDB
# 1     Cumulative Rated Capacity                 kWh       GESDB
# 2        Cumulative Rated Power                  kW       GESDB
# 3     Cumulative Rated Capacity                 kWh       GESDB
# 4      Levelized Cost of Energy        2022 USD/kWh       IRENA
# ...                         ...                 ...         ...
# 8647          Annual production         metric tons        USGS
# 8648               Total Number                   -      UNOOSA
# 8649               Total Number                   -      UNOOSA
# 8650          Annual Production  billion cubic feet         EIA
# 8651               Total Number                   -      UNOOSA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 8647                   Annual production|Tin Production   NaN  ...
# 8648           Total Number|Objects Launched Into Space   NaN  ...
# 8649           Total Number|Objects Launched Into Space   NaN  ...
# 8650            Annual Production|Liquefied Natural Gas   NaN  ...
# 8651           Total Number|Objects Launched Into Space   NaN  ...
#
#               2016          2017          2018           2019         2020  \
# 0              NaN  1.900000e+02  2.900000e+02            NaN          NaN
# 1              NaN  7.600000e+02  1.160000e+03            NaN          NaN
# 2     2.550000e+05  3.550000e+05  4.550000e+05            NaN          NaN
# 3     1.195000e+06  1.745000e+06  2.945000e+06            NaN          NaN
# 4     5.929609e-02  4.898293e-02  4.679236e-02       0.048501     0.042769
# ...            ...           ...           ...            ...          ...
# 8647  5.226023e+05  5.767229e+05  5.462801e+05  500615.785555          NaN
# 8648           NaN           NaN           NaN            NaN          NaN
# 8649           NaN           NaN           NaN            NaN          NaN
# 8650  1.868400e+02  7.075400e+02  1.083120e+03    1819.400000  2389.840000
# 8651           NaN           NaN  1.000000e+00            NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 8647      NaN   NaN   NaN   NaN   NaN
# 8648      NaN   1.0   NaN   NaN   NaN
# 8649      NaN   NaN   NaN   NaN   NaN
# 8650  3560.82   NaN   NaN   NaN   NaN
# 8651      NaN   NaN   NaN   NaN   NaN
#
# [8652 rows x 335 columns]

# %%
omit = []
for col in all_tech_df.columns:
    if len(col) != 4 or col == 'Unit':
         omit.append(col)
empty_rows = all_tech_df.drop(columns=omit)
empty_rows.dropna(how='all', inplace=True)
na_idx = []
for idx in all_tech_df.index:
    if idx not in empty_rows.index:
        na_idx.append(idx)
all_tech_df.drop(na_idx, inplace=True)
all_tech_df
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 8647             Tin Production_Annual production_World        Global
# 8648        Objects Launched Into Space_Total Number_UA      National
# 8649        Objects Launched Into Space_Total Number_TM      National
# 8650         Liquefied Natural Gas_Annual Production_US      National
# 8651        Objects Launched Into Space_Total Number_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 8647        World          World               Tin Production
# 8648           UA        Ukraine  Objects Launched Into Space
# 8649           TM   Turkmenistan  Objects Launched Into Space
# 8650           US  United States        Liquefied Natural Gas
# 8651           CO       Colombia  Objects Launched Into Space
#
#                          Metric                Unit Data Source  \
# 0        Cumulative Rated Power                  kW       GESDB
# 1     Cumulative Rated Capacity                 kWh       GESDB
# 2        Cumulative Rated Power                  kW       GESDB
# 3     Cumulative Rated Capacity                 kWh       GESDB
# 4      Levelized Cost of Energy        2022 USD/kWh       IRENA
# ...                         ...                 ...         ...
# 8647          Annual production         metric tons        USGS
# 8648               Total Number                   -      UNOOSA
# 8649               Total Number                   -      UNOOSA
# 8650          Annual Production  billion cubic feet         EIA
# 8651               Total Number                   -      UNOOSA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 8647                   Annual production|Tin Production   NaN  ...
# 8648           Total Number|Objects Launched Into Space   NaN  ...
# 8649           Total Number|Objects Launched Into Space   NaN  ...
# 8650            Annual Production|Liquefied Natural Gas   NaN  ...
# 8651           Total Number|Objects Launched Into Space   NaN  ...
#
#               2016          2017          2018           2019         2020  \
# 0              NaN  1.900000e+02  2.900000e+02            NaN          NaN
# 1              NaN  7.600000e+02  1.160000e+03            NaN          NaN
# 2     2.550000e+05  3.550000e+05  4.550000e+05            NaN          NaN
# 3     1.195000e+06  1.745000e+06  2.945000e+06            NaN          NaN
# 4     5.929609e-02  4.898293e-02  4.679236e-02       0.048501     0.042769
# ...            ...           ...           ...            ...          ...
# 8647  5.226023e+05  5.767229e+05  5.462801e+05  500615.785555          NaN
# 8648           NaN           NaN           NaN            NaN          NaN
# 8649           NaN           NaN           NaN            NaN          NaN
# 8650  1.868400e+02  7.075400e+02  1.083120e+03    1819.400000  2389.840000
# 8651           NaN           NaN  1.000000e+00            NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 8647      NaN   NaN   NaN   NaN   NaN
# 8648      NaN   1.0   NaN   NaN   NaN
# 8649      NaN   NaN   NaN   NaN   NaN
# 8650  3560.82   NaN   NaN   NaN   NaN
# 8651      NaN   NaN   NaN   NaN   NaN
#
# [8643 rows x 335 columns]

# %%
#all_tech_df['Metric'] = all_tech_df['Metric'].str.title()

# %%
all_tech_df['Metric'] = all_tech_df['Metric'].str.strip()

# %%
set(all_tech_df['Metric'])
# Out:
# {'Annual Production',
#  'Annual production',
#  'Average Capacity of Unit Additions',
#  'Computing Capacity',
#  'Cumulative Acreage',
#  'Cumulative Length',
#  'Cumulative Rated Capacity',
#  'Cumulative Rated Power',
#  'Cumulative Total Capacity',
#  'Installed Capacity',
#  'Installed electricity capacity',
#  'Levelized Cost of Energy',
#  'Net Total Capacity',
#  'Price',
#  'Share of Boilers',
#  'Share of Households',
#  'Share of Market',
#  'Share of Population',
#  'Total Capacity',
#  'Total Installed Cost',
#  'Total Length',
#  'Total Number'}

# %%
all_tech_df.to_csv('all_tech_version 2.0.csv', index=False)

# %%
# all_tech_df = all_tech_df[all_tech_df['Metric']!='Price']
# all_tech_df

# %%
#all_tech_df.to_csv('all_tech_version 1.5.csv', index=False)

# %%
# no_country = []
# for tech in set(all_tech_df['Technology Name']):
#     countries = list(set(all_tech_df[all_tech_df['Technology Name'] == tech]['Country Name']))
#     id_ = list(all_tech_df[all_tech_df['Technology Name'] == tech]['ID'])
#     if len(countries) <= 2:
#         no_country.extend(id_)

# %%
# all_tech_w_countrylvl = all_tech_df.set_index('ID', drop=True)
# all_tech_w_countrylvl.drop(index=no_country, inplace=True)
# all_tech_w_countrylvl

# %%
# all_tech_w_countrylvl.to_csv('all_tech_with_country-level.csv', index=False)
