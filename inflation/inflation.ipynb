# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
# https://fred.stlouisfed.org/tags/series?t=nipa%3Bprice+index
# https://fred.stlouisfed.org/series/A001RG3A086NBEA

# %%
# this is just a test! I then go and replicate this in each of the reading files for cost data

# %%
nipa = pd.read_excel('A001RG3A086NBEA.xls', header=10)
nipa
# Out:
#    observation_date  A001RG3A086NBEA
# 0        1929-01-01            9.371
# 1        1930-01-01            9.010
# 2        1931-01-01            8.120
# 3        1932-01-01            7.194
# 4        1933-01-01            7.001
# ..              ...              ...
# 89       2018-01-01          110.329
# 90       2019-01-01          112.284
# 91       2020-01-01          113.794
# 92       2021-01-01          118.900
# 93       2022-01-01          127.197
#
# [94 rows x 2 columns]

# %%
year_list = []
for x in nipa['observation_date']:
    x = int(str(x)[:4])
    year_list.append(x)
nipa['Year'] = year_list
nipa.set_index('Year', drop=True, inplace=True)
nipa.drop(columns='observation_date', inplace=True)
nipa = nipa.transpose()
nipa
# Out:
# Year              1929  1930  1931   1932   1933   1934  1935   1936   1937  \
# A001RG3A086NBEA  9.371  9.01  8.12  7.194  7.001  7.343  7.49  7.582  7.858
#
# Year              1938  ...     2013     2014     2015     2016    2017  \
# A001RG3A086NBEA  7.712  ...  101.765  103.661  104.652  105.691  107.73
#
# Year                2018     2019     2020   2021     2022
# A001RG3A086NBEA  110.329  112.284  113.794  118.9  127.197
#
# [1 rows x 94 columns]

# %%
# sorted(list(set(cost_data['Unit'])))
#  ['1958 USD',
#  '1958 USD/gal',
#  '1958 USD/lb',
#  '1966 USD/lb',
#  '1998 USD/metric ton',
#  '2021 USD/barrel',
#  '2021 USD/kW',
#  '2021 USD/kWh',
#  'USD/kilobase',
#  'USD/metric ton',
#  'USD/million Btu',
#  'million USD/unit',
#  'producer price index',
#  'thousand USD/hectolitre',
#  'thousand USD/metric ton',
#  'thousand USD/unit']

# %%
all_tech = pd.read_csv('all_tech_version 2.0.csv')
all_tech
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 8837             Tin Production_Annual production_World        Global
# 8838                     Space Launches_Total Number_UA      National
# 8839                     Space Launches_Total Number_TM      National
# 8840         Liquefied Natural Gas_Annual Production_US      National
# 8841                     Space Launches_Total Number_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# ...

# %%
usd_1998 = all_tech[all_tech['Unit']=='1998 USD/metric ton']
usd_1998
# Out:
#                                             ID Spatial Scale Country Code  \
# 690     Rare Earth Mine Production_Price_World        Global        World
# 1316    Sand and Gravel|Industrial_Price_World        Global        World
# 1339                          Lead_Price_World        Global        World
# 1904   Primary Aluminum Production_Price_World        Global        World
# 2635             Nickel Production_Price_World        Global        World
# 2670  Sand and Gravel|Construction_Price_World        Global        World
# 2739                        Cement_Price_World        Global        World
# 4046                        Cobalt_Price_World        Global        World
# 4067    Primary Bauxite Production_Price_World        Global        World
# 4101       Lithium Mine Production_Price_World        Global        World
# 4188               Zinc Production_Price_World        Global        World
# 4297               Gold Production_Price_World        Global        World
# ...

# %%
infl_1998_2022 = float(nipa[2022]/nipa[1998])
infl_1998_2022
# Out:
# 1.6912695457930007

# %%
for col in usd_1998.columns[9:]:
    usd_1998[col] = usd_1998[col] * infl_1998_2022
usd_1998['Unit'] = '2022 USD/metric ton'
usd_1998
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51635/2357449669.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usd_1998[col] = usd_1998[col] * infl_1998_2022
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51635/2357449669.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usd_1998['Unit'] = '2022 USD/metric ton'
#                                             ID Spatial Scale Country Code  \
# ...
