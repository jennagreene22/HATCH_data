# %%
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco
import os
import string

# %%
# https://doi.org/10.2968/066004008
# data digitized from 'GLOBAL NUCLEAR WEAPONS INVENTORIES, 1945-2010', pp. 81-82

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
nukes = pd.read_csv('raw data/NorrisKristensen_NuclearWeapons_TimeSeries.csv', index_col=0, 
                    usecols=[0,1,2,3,4,5,6,7,8])
nukes = nukes.transpose()
nukes
# Out:
# YEAR            1945  1946  1947  1948   1949   1950   1951   1952    1953  \
# UNITED STATES    2.0   9.0  13.0  50.0  170.0  299.0  438.0  841.0  1169.0
# RUSSIA           NaN   NaN   NaN   NaN    1.0    5.0   25.0   50.0   120.0
# UNITED KINGDOM   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN     1.0
# FRANCE           NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN     NaN
# CHINA            NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN     NaN
# ISRAEL           NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN     NaN
# INDIA            NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN     NaN
# PAKISTAN         NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN     NaN
#
# YEAR              1954  ...     2001     2002     2003     2004     2005  \
# UNITED STATES   1703.0  ...  10526.0  10457.0  10027.0   8570.0   8360.0
# RUSSIA           150.0  ...  21000.0  20000.0  19000.0  18000.0  17000.0
# ...

# %%
country_names = []
for country in nukes.index:
    country_names.append(country.title())
    
country_codes = []
for country in country_names:
    country_codes.append(coco.convert(names=country, to='iso2'))

# %%
nukes['Country Name'] = country_names
nukes['Country Code'] = country_codes
nukes['Metric'] = 'Total Number'
nukes['Unit'] = '-'
nukes['Data Source'] = 'Norris & Kristensen'
nukes['Spatial Scale'] = 'National'
nukes['Technology Name'] = 'Nuclear Weapons'
nukes['ID'] = nukes['Technology Name'] + '_' + nukes['Metric'] + '_' + nukes['Country Code']
nukes.set_index('ID', drop=True, inplace=True)
nukes.columns.name = None
nukes
# Out:
#                                  1945  1946  1947  1948   1949   1950   1951  \
# ID
# Nuclear Weapons_Total Number_US   2.0   9.0  13.0  50.0  170.0  299.0  438.0
# Nuclear Weapons_Total Number_RU   NaN   NaN   NaN   NaN    1.0    5.0   25.0
# Nuclear Weapons_Total Number_GB   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# Nuclear Weapons_Total Number_FR   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# Nuclear Weapons_Total Number_CN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# Nuclear Weapons_Total Number_IL   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# Nuclear Weapons_Total Number_IN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# Nuclear Weapons_Total Number_PK   NaN   NaN   NaN   NaN    NaN    NaN    NaN
#
#                                   1952    1953    1954  ...     2008     2009  \
# ID                                                      ...
# Nuclear Weapons_Total Number_US  841.0  1169.0  1703.0  ...   5273.0   5113.0
# ...

# %%
nukes.to_csv('cleaned data/nuclear_weapons.csv')
