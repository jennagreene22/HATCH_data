# %%
import pandas as pd
from pandas import Series, DataFrame
import os

# %%
# https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html
# Statistical Review of World Energy - all data, 1965-2021
# https://www.bp.com/content/dam/bp/business-sites/en/global/corporate/xlsx/energy-economics/statistical-review/bp-stats-review-2022-all-data.xlsx

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
## adjusting for inflation from 2021 USD to 2022
nipa = pd.read_excel('A001RG3A086NBEA.xls', header=10)

year_list = []
for x in nipa['observation_date']:
    x = int(str(x)[:4])
    year_list.append(x)
nipa['Year'] = year_list
nipa.set_index('Year', drop=True, inplace=True)
nipa.drop(columns='observation_date', inplace=True)
nipa = nipa.transpose()

infl_2021_2022 = float(nipa[2022]/nipa[2021])
infl_2021_2022
# Out:
# 1.069781328847771

# %%
# crude oil
# numbers appear nominal but bp doesn't say for sure
crude_oil = pd.read_excel('raw data/bp-stats-review-2022-all-data.xlsx', 
                          sheet_name='Oil crude prices since 1861', header=3, usecols=[0,2], skipfooter=5,
                         index_col=0)
crude_oil = crude_oil.transpose()
for col in crude_oil.columns:
    crude_oil[col] = crude_oil[col] * infl_2021_2022
crude_oil['Unit'] = '2022 USD/barrel'
crude_oil['Metric'] = 'Price'
crude_oil['Spatial Scale'] = 'Global'
crude_oil['Technology Name'] = 'Crude Oil'
crude_oil['Data Source'] = 'BP'
crude_oil['Country Name'] = 'World'
crude_oil['Country Code'] = 'World'
crude_oil['ID'] = crude_oil['Technology Name'] + '_' + crude_oil['Metric'] + '_' + crude_oil['Country Code']
crude_oil.set_index('ID', inplace=True)
crude_oil.columns.name = None
crude_oil.to_csv('cleaned data/crude_oil_price.csv')
crude_oil
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51903/141046637.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   crude_oil['Unit'] = '2022 USD/barrel'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51903/141046637.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   crude_oil['Metric'] = 'Price'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51903/141046637.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   crude_oil['Spatial Scale'] = 'Global'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51903/141046637.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   crude_oil['Technology Name'] = 'Crude Oil'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51903/141046637.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   crude_oil['Data Source'] = 'BP'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51903/141046637.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   crude_oil['Country Name'] = 'World'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51903/141046637.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   crude_oil['Country Code'] = 'World'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51903/141046637.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   crude_oil['ID'] = crude_oil['Technology Name'] + '_' + crude_oil['Metric'] + '_' + crude_oil['Country Code']
#                             1861       1862       1863      1864        1865  \
# ID
# Crude Oil_Price_World  15.038266  29.002371  70.546307  142.1028  118.711566
#
#                             1866       1867       1868       1869       1870  \
# ID
# Crude Oil_Price_World  70.434328  47.548104  75.199004  75.406163  84.172293
#
#                        ...       2019       2020       2021             Unit  \
# ID                     ...
# Crude Oil_Price_World  ...  69.538706  46.860568  75.860224  2022 USD/barrel
#
#                        Metric  Spatial Scale  Technology Name  Data Source  \
# ID
# Crude Oil_Price_World   Price         Global        Crude Oil           BP
#
#                        Country Name  Country Code
# ID
# Crude Oil_Price_World         World         World
#
# [1 rows x 168 columns]

# %%
# liquefied natural gas
# numbers appear nominal but bp doesn't say for sure
lng = pd.read_excel('raw data/bp-stats-review-2022-all-data.xlsx', sheet_name='Gas Prices ', usecols=[0,1],
                   header=4, index_col=0, skipfooter=8)
lng = lng.transpose()
lng['Technology Name'] = 'Liquefied Natural Gas (LNG)'
lng['Data Source'] = 'BP'
lng['Metric'] = 'Price'
lng['Unit'] = 'USD/million Btu'
lng['Country Name'] = 'Japan'
lng['Country Code'] = 'JP'
lng['Spatial Scale'] = 'National'
lng['ID'] = lng['Technology Name'] + '_' + lng['Metric'] + '_' + lng['Country Code']
lng.set_index('ID', inplace=True)
lng.to_csv('cleaned data/lng_price.csv')
lng
# Out:
#                                       1984      1985     1986      1987  \
# ID
# Liquefied Natural Gas (LNG)_Price_JP   5.1  5.234653  4.10198  3.352638
#
#                                           1988      1989      1990      1991  \
# ID
# Liquefied Natural Gas (LNG)_Price_JP  3.344109  3.279231  3.644573  3.985942
#
#                                           1992      1993  ...      2019  \
# ID                                                        ...
# Liquefied Natural Gas (LNG)_Price_JP  3.622635  3.522022  ...  9.944666
#
#                                           2020       2021  \
# ID
# Liquefied Natural Gas (LNG)_Price_JP  7.781412  10.072739
#
#                                                   Technology Name  \
# ID
# Liquefied Natural Gas (LNG)_Price_JP  Liquefied Natural Gas (LNG)
#
#                                       Data Source  Metric             Unit  \
# ID
# Liquefied Natural Gas (LNG)_Price_JP           BP   Price  USD/million Btu
#
#                                       Country Name  Country Code  \
# ID
# Liquefied Natural Gas (LNG)_Price_JP         Japan            JP
#
#                                       Spatial Scale
# ID
# Liquefied Natural Gas (LNG)_Price_JP       National
#
# [1 rows x 45 columns]

# %%
# natural gas
# numbers appear nominal but bp doesn't say for sure
nat_gas = pd.read_excel('raw data/bp-stats-review-2022-all-data.xlsx', sheet_name='Gas Prices ', header=3,
                        index_col=0, usecols=[0,3,6,7], skiprows=[4], na_values='-',skipfooter=8)
nat_gas = nat_gas.transpose()
nat_gas.loc['Rest of World'] = (nat_gas.iloc[0] + nat_gas.iloc[1] + nat_gas.iloc[2]) / 3
nat_gas['Technology Name'] = 'Natural Gas Production'
nat_gas['Data Source'] = 'BP'
nat_gas['Metric'] = 'Price'
nat_gas['Unit'] = 'USD/million Btu'
nat_gas['Country Name'] = ['Germany', 'US', 'Canada', 'Rest of World']
nat_gas['Country Code'] = ['DE', 'US', 'CA', 'Rest of World']
nat_gas['Spatial Scale'] = ['National', 'National','National','Global']
nat_gas['ID'] = nat_gas['Technology Name'] + '_' + nat_gas['Metric'] + '_' + nat_gas['Country Code']
nat_gas.set_index('ID', inplace=True)
nat_gas.to_csv('cleaned data/nat_gas_price.csv')
nat_gas
# Out:
#                                                 1984      1985      1986  \
# ID
# Natural Gas Production_Price_DE             3.995635  4.253587  3.928619
# Natural Gas Production_Price_US                  NaN       NaN       NaN
# Natural Gas Production_Price_CA                  NaN       NaN       NaN
# Natural Gas Production_Price_Rest of World       NaN       NaN       NaN
#
#                                                 1987      1988      1989  \
# ID
# Natural Gas Production_Price_DE             2.547503  2.220359  2.000514
# Natural Gas Production_Price_US                  NaN       NaN  1.696667
# Natural Gas Production_Price_CA                  NaN       NaN       NaN
# Natural Gas Production_Price_Rest of World       NaN       NaN       NaN
#
#                                                 1990      1991      1992  \
# ID
# Natural Gas Production_Price_DE             2.775893  3.233289  2.698698
# Natural Gas Production_Price_US             1.638333  1.486667  1.771667
# Natural Gas Production_Price_CA             1.050000  0.888333  0.979167
# Natural Gas Production_Price_Rest of World  1.821409  1.869430  1.816510
#
#                                                 1993  ...      2019      2020  \
# ID                                                    ...
# Natural Gas Production_Price_DE             2.511376  ...  5.029917  4.062832
# Natural Gas Production_Price_US             2.120833  ...  2.511900  1.988582
# Natural Gas Production_Price_CA             1.692500  ...  1.267677  1.581569
# Natural Gas Production_Price_Rest of World  2.108236  ...  2.936498  2.544328
#
#                                                 2021         Technology Name  \
# ID
# Natural Gas Production_Price_DE             8.936670  Natural Gas Production
# Natural Gas Production_Price_US             3.839473  Natural Gas Production
# Natural Gas Production_Price_CA             2.753414  Natural Gas Production
# Natural Gas Production_Price_Rest of World  5.176519  Natural Gas Production
#
#                                             Data Source  Metric  \
# ID
# Natural Gas Production_Price_DE                      BP   Price
# Natural Gas Production_Price_US                      BP   Price
# Natural Gas Production_Price_CA                      BP   Price
# Natural Gas Production_Price_Rest of World           BP   Price
#
#                                                        Unit   Country Name  \
# ID
# Natural Gas Production_Price_DE             USD/million Btu        Germany
# Natural Gas Production_Price_US             USD/million Btu             US
# Natural Gas Production_Price_CA             USD/million Btu         Canada
# Natural Gas Production_Price_Rest of World  USD/million Btu  Rest of World
#
#                                              Country Code  Spatial Scale
# ID
# Natural Gas Production_Price_DE                        DE       National
# Natural Gas Production_Price_US                        US       National
# Natural Gas Production_Price_CA                        CA       National
# Natural Gas Production_Price_Rest of World  Rest of World         Global
#
# [4 rows x 45 columns]

# %%
# coal
# numbers appear nominal but bp doesn't say for sure
coal = pd.read_excel('raw data/bp-stats-review-2022-all-data.xlsx', sheet_name='Coal Prices', header=1,
                     index_col=0, usecols=[0,1,2,6], na_values='-',skiprows=[2],skipfooter=6)
coal = coal.transpose()
coal.loc['Rest of World'] = (coal.iloc[0] + coal.iloc[1] + coal.iloc[2]) / 3
coal['Technology Name'] = 'Coal Production'
coal['Data Source'] = 'BP'
coal['Metric'] = 'Price'
coal['Unit'] = 'USD/metric ton'
coal['Country Name'] = ['Europe', 'North America', 'Asia', 'Rest of World']
coal['Country Code'] = ['Europe', 'North America', 'Asia', 'Rest of World']
coal['Spatial Scale'] = ['National', 'National','National','Global']
coal['ID'] = coal['Technology Name'] + '_' + coal['Metric'] + '_' + coal['Country Code']
coal.set_index('ID', inplace=True)
coal.to_csv('cleaned data/coal_price.csv')
coal
# Out:
# US dollars per tonne                      1987       1988     1989       1990  \
# ID
# Coal Production_Price_Europe         31.300000  39.940000  42.0800  43.480000
# Coal Production_Price_North America        NaN        NaN      NaN  31.591918
# Coal Production_Price_Asia           41.281667  42.465833  48.8625  50.814167
# Coal Production_Price_Rest of World        NaN        NaN      NaN  41.962028
#
# US dollars per tonne                      1991       1992       1993  \
# ID
# Coal Production_Price_Europe         42.800000  38.530000  33.680000
# Coal Production_Price_North America  29.010532  28.534539  29.853958
# Coal Production_Price_Asia           50.295833  48.454167  45.711667
# Coal Production_Price_Rest of World  40.702122  38.506235  36.415208
#
# US dollars per tonne                      1994       1995       1996  ...  \
# ID                                                                    ...
# Coal Production_Price_Europe         37.180000  44.500000  41.250000  ...
# Coal Production_Price_North America  31.716177  27.006350  29.862309  ...
# Coal Production_Price_Asia           43.661667  47.575000  49.535833  ...
# Coal Production_Price_Rest of World  37.519281  39.693783  40.216047  ...
#
# US dollars per tonne                       2019       2020        2021  \
# ID
# Coal Production_Price_Europe          60.855250  50.164269  121.699808
# Coal Production_Price_North America   57.163984  42.766370   68.538142
# Coal Production_Price_Asia           108.580833  80.500000  130.367266
# Coal Production_Price_Rest of World   75.533356  57.810213  106.868405
#
# US dollars per tonne                 Technology Name  Data Source  Metric  \
# ID
# Coal Production_Price_Europe         Coal Production           BP   Price
# Coal Production_Price_North America  Coal Production           BP   Price
# Coal Production_Price_Asia           Coal Production           BP   Price
# Coal Production_Price_Rest of World  Coal Production           BP   Price
#
# US dollars per tonne                           Unit   Country Name  \
# ID
# Coal Production_Price_Europe         USD/metric ton         Europe
# Coal Production_Price_North America  USD/metric ton  North America
# Coal Production_Price_Asia           USD/metric ton           Asia
# Coal Production_Price_Rest of World  USD/metric ton  Rest of World
#
# US dollars per tonne                  Country Code  Spatial Scale
# ID
# Coal Production_Price_Europe                Europe       National
# Coal Production_Price_North America  North America       National
# Coal Production_Price_Asia                    Asia       National
# Coal Production_Price_Rest of World  Rest of World         Global
#
# [4 rows x 42 columns]
