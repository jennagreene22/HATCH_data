# %%
import os
import pandas as pd
from pandas import Series, DataFrame
#import string
import country_converter as coco

# %%
## Get current working directory
print("Current working directory:", os.getcwd())

## Find path to raw data (for the raw files)
raw_data_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'raw_data/cost data/unisd'))

## Find path to folder for saving cleaned csv
cleaned_data_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'cleaned_data'))
# Out:
# Current working directory: /Users/jennagreene/Documents/GitHub/HATCH_data/reading_files

# %%
#os.chdir('/Users/ariana/desktop/historical_tech/raw data/cost data/unisd')
#os.listdir(raw_data_path)
unisd_files = []
for file in os.listdir(raw_data_path):
    if '.csv' in file:
        unisd_files.append(file)
unisd_files
# Out:
# ['Television receivers.csv',
#  'Radio receivers.csv',
#  'Potassic fertilizers.csv',
#  'Caustic soda.csv',
#  'Bicycles and other cycles.csv',
#  'Electric water heaters and immersion heaters.csv',
#  'Turbo-jets of a thrust not exceeding 25 kN.csv',
#  'Household washing and drying machines.csv',
#  'Telephones and videophones.csv',
#  'Motorcycles and scooters.csv',
#  'Synthetic filament tow and staple fibers.csv',
#  'Household refrigerators and freezers.csv',
#  'Microwave ovens.csv',
#  'Turbo-jets of a thrust exceeding 25 kN.csv',
#  'Beer.csv',
#  'Combined refrigerators-freezers.csv',
#  'Refined copper.csv',
#  'Air conditioning machines.csv',
#  'Vacuum cleaners.csv',
#  'Cars.csv',
#  'Synthetic filament yarn.csv',
#  'Nitrogenous fertilizers.csv']

# %% [markdown]
# Dara sources:
# - http://data.un.org/Default.aspx

# %%
def read_unisd(file):
    # load data and omit footnotes
    df = pd.read_csv(raw_data_path + "/" + file)
    
    end_idx = None
    for idx in range(len(df)):
        val = df.iloc[idx]['Unit']
        if val == 'Footnote':
            end_idx = idx
            break
    df = df[:end_idx]

    # drop footnote columns (alternating columns with data in '2000' and notes in '2000 Footnotes')
    drop_cols = []
    for col in df.columns:
        if 'Footnotes' in col:
            drop_cols.append(col)
    df.drop(columns=drop_cols, inplace=True)

    # drop rows where country doesn't have both mil. USD and thousand metric tons data
    all_countries = list(set(df['Country or Area']))
    countries_lt2_units = []
    for country in all_countries:
        country_units = list(set(df[df['Country or Area']==country]['Unit']))
        if len(country_units) != 2:
            countries_lt2_units.append(country)
    idx_lt2_units = []
    for idx in range(len(df)):
        val = df.iloc[idx]['Country or Area']
        if val in countries_lt2_units:
            idx_lt2_units.append(idx)
    df.drop(index=idx_lt2_units, inplace=True)
    
    # pull units before omitting col (need rows of just float in order to divide entire rows)
    df['country x unit'] = df['Country or Area'] + ' | ' + df['Unit']
    num = df['Unit'].iloc[0]
    denom = df['Unit'].iloc[1]
    unit = num + '/' + denom
    if unit=='Mil. USD/Units':
        unit='million USD/unit'
    elif unit=='Mil. USD/Thousand hectolitres':
        unit='thousand USD/hectolitre'
    elif unit=='Mil. USD/Thousand metric tons':
        unit='thousand USD/metric ton'
    elif unit=='Mil. USD/Thousand units':
        unit='thousand USD/unit'

    # calculate USD per metric ton and omit extra rows
    df.drop(columns=['Country or Area', 'Unit'], inplace=True)
    df.set_index('country x unit', drop=True, inplace=True)
    drop_rows = []
    i = 0 
    while i < len(df):
        new_row = df.iloc[i] / df.iloc[i + 1]
        df.iloc[i] = new_row
        drop_rows.append(df.iloc[i + 1].name)
        i += 2
    df.drop(index=drop_rows, inplace=True)
    df.dropna(how='all', inplace=True)
        
    # input summary data
    df['Unit'] = unit
    df['Data Source'] = 'UN Industrial Commodity Statistics Database'
    df['Metric'] = 'Price'
    df['Spatial Scale'] = 'National'
    if file=='Electric water heaters and immersion heaters.csv':
        df['Technology Name'] = 'Electric Water Heaters and Immersion Heaters'
    elif file=='Bicycles and other cycles.csv':
        df['Technology Name'] = 'Bicycles and Other Cycles'
    elif file=='Household washing and drying machines.csv':
        df['Technology Name'] = 'Household Washing and Drying Machines'
    elif file=='Telephones and videophones.csv':
        df['Technology Name'] = 'Telephones and Videophones'
    elif file=='Motorcycles and scooters.csv':
        df['Technology Name'] = 'Motorcycles and Scooters'
    elif file=='Synthetic filament tow and staple fibers.csv':
        df['Technology Name'] = 'Synthetic Filament Tow and Staple Fibers'
    elif file=='Household refrigerators and freezers.csv':
        df['Technology Name'] = 'Household Refrigerators and Freezers'
    elif file=='Turbo-jets of a thrust not exceeding 25 kN.csv':
        df['Technology Name'] = 'Turbo-Jets of a Thrust Not Exceeding 25 kN'
    else:
        df['Technology Name'] = file[:-4].title()
    country_list = []
    iso_list = []
    for idx in df.index:
        cutoff = idx.index(' |')
        name = idx[:cutoff]
        code = coco.convert(names=name, to='iso2')
        country_list.append(name)
        iso_list.append(code)
    df['Country Name'] = country_list
    df['Country Code'] = iso_list
    df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']
    df.set_index('ID', drop=True, inplace=True)
    return df

# %%
unisd_df = []
for file in unisd_files:

    df = read_unisd(file)
    unisd_df.append(df)

# %%
all_unisd = pd.concat(unisd_df)
all_unisd
# Out:
#                                   1995  1996  1997      1998  1999      2000  \
# ID
# Television Receivers_Price_AZ      NaN   NaN   NaN       NaN   NaN  0.000055
# Television Receivers_Price_BD      NaN   NaN   NaN       NaN   NaN       NaN
# Television Receivers_Price_BR      NaN   NaN   NaN       NaN   NaN  0.000171
# Television Receivers_Price_BG      NaN   NaN   NaN  0.000168   0.0  0.000000
# Television Receivers_Price_CZ      NaN   NaN   NaN       NaN   NaN       NaN
# ...                                ...   ...   ...       ...   ...       ...
# Nitrogenous Fertilizers_Price_TR   NaN   NaN   NaN       NaN   NaN       NaN
# Nitrogenous Fertilizers_Price_GB   NaN   NaN   NaN       NaN   NaN       NaN
# Nitrogenous Fertilizers_Price_UY   NaN   NaN   NaN       NaN   NaN       NaN
# Nitrogenous Fertilizers_Price_UZ   NaN   NaN   NaN       NaN   NaN       NaN
# Nitrogenous Fertilizers_Price_ZW   NaN   NaN   NaN       NaN   NaN       NaN
#
#                                       2001      2002      2003      2004  ...  \
# ID                                                                        ...
# Television Receivers_Price_AZ          NaN       NaN       NaN       NaN  ...
# Television Receivers_Price_BD     0.000153  0.000135  0.000137  0.000135  ...
# Television Receivers_Price_BR     0.000127  0.000133  0.000119  0.000121  ...
# Television Receivers_Price_BG          NaN       NaN       NaN       NaN  ...
# Television Receivers_Price_CZ          NaN       NaN       NaN       NaN  ...
# ...                                    ...       ...       ...       ...  ...
# Nitrogenous Fertilizers_Price_TR       NaN       NaN       NaN       NaN  ...
# Nitrogenous Fertilizers_Price_GB       NaN       NaN       NaN       NaN  ...
# Nitrogenous Fertilizers_Price_UY       NaN       NaN       NaN       NaN  ...
# Nitrogenous Fertilizers_Price_UZ       NaN       NaN       NaN       NaN  ...
# Nitrogenous Fertilizers_Price_ZW       NaN       NaN       NaN       NaN  ...
#
#                                       2014      2015      2016  \
# ID
# Television Receivers_Price_AZ     0.000042  0.000037       NaN
# Television Receivers_Price_BD          NaN       NaN       NaN
# Television Receivers_Price_BR     0.000217  0.000166       NaN
# Television Receivers_Price_BG          NaN       NaN       NaN
# Television Receivers_Price_CZ          NaN  0.000383       NaN
# ...                                    ...       ...       ...
# Nitrogenous Fertilizers_Price_TR  0.317629  0.281149  0.232374
# Nitrogenous Fertilizers_Price_GB       NaN       NaN       NaN
# Nitrogenous Fertilizers_Price_UY       NaN       NaN       NaN
# Nitrogenous Fertilizers_Price_UZ       NaN       NaN  0.441300
# Nitrogenous Fertilizers_Price_ZW       NaN       NaN       NaN
#
#                                                      Unit  \
# ID
# Television Receivers_Price_AZ            million USD/unit
# Television Receivers_Price_BD            million USD/unit
# Television Receivers_Price_BR            million USD/unit
# Television Receivers_Price_BG            million USD/unit
# Television Receivers_Price_CZ            million USD/unit
# ...                                                   ...
# Nitrogenous Fertilizers_Price_TR  thousand USD/metric ton
# Nitrogenous Fertilizers_Price_GB  thousand USD/metric ton
# Nitrogenous Fertilizers_Price_UY  thousand USD/metric ton
# Nitrogenous Fertilizers_Price_UZ  thousand USD/metric ton
# Nitrogenous Fertilizers_Price_ZW  thousand USD/metric ton
#
#                                                                   Data Source  \
# ID
# Television Receivers_Price_AZ     UN Industrial Commodity Statistics Database
# Television Receivers_Price_BD     UN Industrial Commodity Statistics Database
# Television Receivers_Price_BR     UN Industrial Commodity Statistics Database
# Television Receivers_Price_BG     UN Industrial Commodity Statistics Database
# Television Receivers_Price_CZ     UN Industrial Commodity Statistics Database
# ...                                                                       ...
# Nitrogenous Fertilizers_Price_TR  UN Industrial Commodity Statistics Database
# Nitrogenous Fertilizers_Price_GB  UN Industrial Commodity Statistics Database
# Nitrogenous Fertilizers_Price_UY  UN Industrial Commodity Statistics Database
# Nitrogenous Fertilizers_Price_UZ  UN Industrial Commodity Statistics Database
# Nitrogenous Fertilizers_Price_ZW  UN Industrial Commodity Statistics Database
#
#                                   Metric  Spatial Scale  \
# ID
# Television Receivers_Price_AZ      Price       National
# Television Receivers_Price_BD      Price       National
# Television Receivers_Price_BR      Price       National
# Television Receivers_Price_BG      Price       National
# Television Receivers_Price_CZ      Price       National
# ...                                  ...            ...
# Nitrogenous Fertilizers_Price_TR   Price       National
# Nitrogenous Fertilizers_Price_GB   Price       National
# Nitrogenous Fertilizers_Price_UY   Price       National
# Nitrogenous Fertilizers_Price_UZ   Price       National
# Nitrogenous Fertilizers_Price_ZW   Price       National
#
#                                           Technology Name    Country Name  \
# ID
# Television Receivers_Price_AZ        Television Receivers      Azerbaijan
# Television Receivers_Price_BD        Television Receivers      Bangladesh
# Television Receivers_Price_BR        Television Receivers          Brazil
# Television Receivers_Price_BG        Television Receivers        Bulgaria
# Television Receivers_Price_CZ        Television Receivers         Czechia
# ...                                                   ...             ...
# Nitrogenous Fertilizers_Price_TR  Nitrogenous Fertilizers          Turkey
# Nitrogenous Fertilizers_Price_GB  Nitrogenous Fertilizers  United Kingdom
# Nitrogenous Fertilizers_Price_UY  Nitrogenous Fertilizers         Uruguay
# Nitrogenous Fertilizers_Price_UZ  Nitrogenous Fertilizers      Uzbekistan
# Nitrogenous Fertilizers_Price_ZW  Nitrogenous Fertilizers        Zimbabwe
#
#                                   Country Code
# ID
# Television Receivers_Price_AZ               AZ
# Television Receivers_Price_BD               BD
# Television Receivers_Price_BR               BR
# Television Receivers_Price_BG               BG
# Television Receivers_Price_CZ               CZ
# ...                                        ...
# Nitrogenous Fertilizers_Price_TR            TR
# Nitrogenous Fertilizers_Price_GB            GB
# Nitrogenous Fertilizers_Price_UY            UY
# Nitrogenous Fertilizers_Price_UZ            UZ
# Nitrogenous Fertilizers_Price_ZW            ZW
#
# [549 rows x 29 columns]

# %%
set(all_unisd['Unit'])
# Out:
# {'million USD/unit',
#  'thousand USD/hectolitre',
#  'thousand USD/metric ton',
#  'thousand USD/unit'}

# %%
output_file = 'unisd.csv'
output_file_path = os.path.join(cleaned_data_path, output_file)

all_unisd.to_csv(output_file_path)
print("Data saved to:", output_file_path)
# Out:
# Data saved to: /Users/jennagreene/Documents/GitHub/HATCH_data/cleaned_data/unisd.csv
