# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
# https://data.nber.org/data-appendix/w15319/
# https://data.nber.org/data-appendix/w15319/FinalCHAT_72909.csv
# https://www.nber.org/system/files/working_papers/w15319/w15319.pdf

# %%
os.chdir('/Users/ariana/desktop/historical_tech')

# %%
chat = pd.read_csv('raw data/FinalCHAT_72909.csv')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3727645712.py:1: DtypeWarning: Columns (46,51,55,56,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   chat = pd.read_csv('raw data/FinalCHAT_72909.csv')

# %%
chat_dict = pd.read_excel('raw data/chat_dictionary.xlsx', skipfooter=2)
chat_dict
# Out:
#         VARIABLE NAME                                         DEFINITION   \
# 0         ag_harvester  Number of self‐propelled machines that reap an...
# 1    ag_milkingmachine  Number of installations consisting of several ...
# 2           ag_tractor  Number of wheel and crawler tractors (excludin...
# 3                  atm  Number of electromechanical devices that permi...
# 4          aviationpkm  Civil aviation passenger‐KM traveled on schedu...
# ..                 ...                                                ...
# 106   pctivprimeenroll                     Primary school enrollment rate
# 107    pctivsecenroll                   Secondary school enrollment rate
# 108    pctivprivateinv               Private investment as a share of GDP
# 109     pctivpublicinv                Public investment as a share of GDP
# 110      pctivliteracy  Percent literate (usually calculated on the ba...
#
#                                          SOURCE
# 0                                 FAOSTAT (2004)
# 1                                 FAOSTAT (2004)
# 2                                 FAOSTAT (2004)
# 3    BIS (various years) and ECB (various years)
# 4                                Mitchell (1998)
# ..                                           ...
# 106                           Mitchell and Banks
# 107                           Mitchell and Banks
# 108                      Penn World Table (2007)
# 109                      Penn World Table (2007)
# 110                                 Banks (2004)
#
# [111 rows x 3 columns]

# %%
var_names = list(chat.columns[2:])
var_names
# Out:
# ['ag_harvester',
#  'ag_milkingmachine',
#  'ag_tractor',
#  'atm',
#  'aviationpkm',
#  'aviationtkm',
#  'bed_acute',
#  'bed_hosp',
#  'bed_longterm',
#  'cabletv',
#  'cellphone',
#  'cheque',
#  'computer',
#  'creditdebit',
#  'eft',
#  'elecprod',
#  'fert_total',
#  'internetuser',
#  'irrigatedarea',
#  'kidney_dialpat',
#  'kidney_homedialpat',
#  'loom_auto',
#  'loom_total',
#  'mail',
#  'med_catscanner',
#  'med_lithotriptor',
#  'med_mammograph',
#  'med_mriunit',
#  'med_radiationequip',
#  'newspaper',
#  'pctdaysurg_cataract',
#  'pctdaysurg_cholecyst',
#  'pctdaysurg_hernia',
#  'pctdaysurg_lapcholecyst',
#  'pctdaysurg_tonsil',
#  'pctdaysurg_varicosevein',
#  'pcthomedialysis',
#  'pctimmunizdpt',
#  'pctimmunizmeas',
#  'pctirrigated',
#  'pctmvbyarea',
#  'pest_total',
#  'pos',
#  'radio',
#  'railline',
#  'railp',
#  'railpkm',
#  'railt',
#  'railtkm',
#  'ship_all',
#  'ship_motor',
#  'ship_sail',
#  'ship_steam',
#  'ship_steammotor',
#  'shipton_all',
#  'shipton_motor',
#  'shipton_sail',
#  'shipton_steam',
#  'shipton_steammotor',
#  'spindle_mule',
#  'spindle_ring',
#  'steel_acidbess',
#  'steel_basicbess',
#  'steel_bof',
#  'steel_eaf',
#  'steel_ohf',
#  'steel_other',
#  'steel_stainless',
#  'surg_appendectomy',
#  'surg_breastcnsv',
#  'surg_cardcath',
#  'surg_cataract',
#  'surg_cholecyst',
#  'surg_corbypass',
#  'surg_corinterven',
#  'surg_corstent',
#  'surg_csection',
#  'surg_hernia',
#  'surg_hipreplace',
#  'surg_hysterectomy',
#  'surg_kneereplace',
#  'surg_lapcholecyst',
#  'surg_mastectomy',
#  'surg_pacemaker',
#  'surg_prostatetrans',
#  'surg_prostatextrans',
#  'surg_tonsil',
#  'surg_varicosevein',
#  'telegram',
#  'telephone',
#  'transplant_bonemarrow',
#  'transplant_heart',
#  'transplant_kidney',
#  'transplant_liver',
#  'transplant_lung',
#  'tv',
#  'txtlmat_artif',
#  'txtlmat_otherraw',
#  'txtlmat_synth',
#  'txtlmat_totalraw',
#  'vehicle_car',
#  'vehicle_com',
#  'visitorbeds',
#  'visitorrooms',
#  'xlpopulation',
#  'xlrealgdp',
#  'pctivprimeenroll',
#  'pctivsecenroll',
#  'pctivprivateinv',
#  'pctivpublicinv',
#  'pctivliteracy']

# %%
def read_chat(col_num, tech_name, unit='-', metric='Cumulative total capacity'):
    chat = pd.read_csv('raw data/FinalCHAT_72909.csv', usecols=[0,1,col_num], dtype={col_num:float},
                      na_values=' ')
    chat.replace('Venezuala', 'Venezuela', inplace=True)
    chat = chat[chat['country_name']!='Indochina']
    country_list = list(set(chat['country_name']))
    chat_df = []
    for country in country_list:
        df = chat[chat['country_name']==country]
        df.set_index('year', drop=True, inplace=True)
        df = df.transpose()
        df['Country Name'] = country
        if country == 'North Vietnam':
            country_code = 'VD'
        elif country == 'South Vietnam':
            country_code = 'VNM'
        elif country == 'Czechoslovakia':
            country_code = 'CSK'
        else:
            country_code = coco.convert(names=country, to='iso2')
        df['Country Code'] = country_code
        df.drop(index='country_name', inplace=True)
        chat_df.append(df)
    chat_all = pd.concat(chat_df)
    chat_all['Data Source'] = 'CHAT'
    chat_all['Spatial Scale'] = 'National'
    chat_all['Unit'] = unit
    chat_all['Metric'] = metric
    chat_all['Technology Name'] = tech_name
    chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
    chat_all.set_index('ID', drop=True, inplace=True)
    chat_all.columns.name = None
    omit = []
    for col in chat_all.columns:
        if type(col) != int:
            omit.append(col)
    empty_rows = chat_all.drop(columns=omit)
    empty_rows.dropna(how='all', inplace=True)
    na_idx = []
    for country in chat_all.index:
        if country not in empty_rows.index:
            na_idx.append(country)
    chat_all.drop(na_idx, inplace=True)
    file_name = 'cleaned data/chat_' + tech_name + '.csv'
    chat_all.to_csv(file_name)
    return chat_all

# %%
ag_harvester = read_chat(2, 'Crop Harvester', metric='Total Number')
ag_harvester
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Crop Harvester_Total Number_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop Harvester_Total Number_BZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop Harvester_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop Harvester_Total Number_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop Harvester_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...  ...  ...  ...
# Crop Harvester_Total Number_KH  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop Harvester_Total Number_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop Harvester_Total Number_VN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop Harvester_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop Harvester_Total Number_GM  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                1759  ... 2006 2007 2008    Country Name  \
# ID                                   ...
# Crop Harvester_Total Number_AU  NaN  ...  NaN  NaN  NaN       Australia
# Crop Harvester_Total Number_BZ  NaN  ...  NaN  NaN  NaN          Belize
# Crop Harvester_Total Number_NL  NaN  ...  NaN  NaN  NaN     Netherlands
# Crop Harvester_Total Number_MA  NaN  ...  NaN  NaN  NaN         Morocco
# Crop Harvester_Total Number_GB  NaN  ...  NaN  NaN  NaN  United Kingdom
# ...                             ...  ...  ...  ...  ...             ...
# Crop Harvester_Total Number_KH  NaN  ...  NaN  NaN  NaN        Cambodia
# Crop Harvester_Total Number_ES  NaN  ...  NaN  NaN  NaN           Spain
# Crop Harvester_Total Number_VN  NaN  ...  NaN  NaN  NaN         Vietnam
# Crop Harvester_Total Number_CL  NaN  ...  NaN  NaN  NaN           Chile
# Crop Harvester_Total Number_GM  NaN  ...  NaN  NaN  NaN          Gambia
#
#                                Country Code Data Source Spatial Scale Unit  \
# ID
# Crop Harvester_Total Number_AU           AU        CHAT      National    -
# Crop Harvester_Total Number_BZ           BZ        CHAT      National    -
# Crop Harvester_Total Number_NL           NL        CHAT      National    -
# Crop Harvester_Total Number_MA           MA        CHAT      National    -
# Crop Harvester_Total Number_GB           GB        CHAT      National    -
# ...                                     ...         ...           ...  ...
# Crop Harvester_Total Number_KH           KH        CHAT      National    -
# Crop Harvester_Total Number_ES           ES        CHAT      National    -
# Crop Harvester_Total Number_VN           VN        CHAT      National    -
# Crop Harvester_Total Number_CL           CL        CHAT      National    -
# Crop Harvester_Total Number_GM           GM        CHAT      National    -
#
#                                       Metric Technology Name
# ID
# Crop Harvester_Total Number_AU  Total Number  Crop Harvester
# Crop Harvester_Total Number_BZ  Total Number  Crop Harvester
# Crop Harvester_Total Number_NL  Total Number  Crop Harvester
# Crop Harvester_Total Number_MA  Total Number  Crop Harvester
# Crop Harvester_Total Number_GB  Total Number  Crop Harvester
# ...                                      ...             ...
# Crop Harvester_Total Number_KH  Total Number  Crop Harvester
# Crop Harvester_Total Number_ES  Total Number  Crop Harvester
# Crop Harvester_Total Number_VN  Total Number  Crop Harvester
# Crop Harvester_Total Number_CL  Total Number  Crop Harvester
# Crop Harvester_Total Number_GM  Total Number  Crop Harvester
#
# [119 rows x 266 columns]

# %%
steam_ships = read_chat(54, 'Steamships', metric='Total Number')
steam_ships
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Steamships_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_BE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_NO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_CU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_MX  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_DK  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_HU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_IE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_DE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_IT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_AT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_RU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_GR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_FR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_SE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_FI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steamships_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008    Country Name Country Code  \
# ID                          ...
# Steamships_Total Number_NL  ...  NaN  NaN  NaN     Netherlands           NL
# Steamships_Total Number_GB  ...  NaN  NaN  NaN  United Kingdom           GB
# Steamships_Total Number_BE  ...  NaN  NaN  NaN         Belgium           BE
# Steamships_Total Number_NO  ...  NaN  NaN  NaN          Norway           NO
# Steamships_Total Number_CU  ...  NaN  NaN  NaN            Cuba           CU
# Steamships_Total Number_MX  ...  NaN  NaN  NaN          Mexico           MX
# Steamships_Total Number_DK  ...  NaN  NaN  NaN         Denmark           DK
# Steamships_Total Number_HU  ...  NaN  NaN  NaN         Hungary           HU
# Steamships_Total Number_IE  ...  NaN  NaN  NaN         Ireland           IE
# Steamships_Total Number_DE  ...  NaN  NaN  NaN         Germany           DE
# Steamships_Total Number_IT  ...  NaN  NaN  NaN           Italy           IT
# Steamships_Total Number_AT  ...  NaN  NaN  NaN         Austria           AT
# Steamships_Total Number_RU  ...  NaN  NaN  NaN          Russia           RU
# Steamships_Total Number_GR  ...  NaN  NaN  NaN          Greece           GR
# Steamships_Total Number_CA  ...  NaN  NaN  NaN          Canada           CA
# Steamships_Total Number_FR  ...  NaN  NaN  NaN          France           FR
# Steamships_Total Number_SE  ...  NaN  NaN  NaN          Sweden           SE
# Steamships_Total Number_FI  ...  NaN  NaN  NaN         Finland           FI
# Steamships_Total Number_ES  ...  NaN  NaN  NaN           Spain           ES
# Steamships_Total Number_CL  ...  NaN  NaN  NaN           Chile           CL
#
#                            Data Source Spatial Scale Unit        Metric  \
# ID
# Steamships_Total Number_NL        CHAT      National    -  Total Number
# Steamships_Total Number_GB        CHAT      National    -  Total Number
# Steamships_Total Number_BE        CHAT      National    -  Total Number
# Steamships_Total Number_NO        CHAT      National    -  Total Number
# Steamships_Total Number_CU        CHAT      National    -  Total Number
# Steamships_Total Number_MX        CHAT      National    -  Total Number
# Steamships_Total Number_DK        CHAT      National    -  Total Number
# Steamships_Total Number_HU        CHAT      National    -  Total Number
# Steamships_Total Number_IE        CHAT      National    -  Total Number
# Steamships_Total Number_DE        CHAT      National    -  Total Number
# Steamships_Total Number_IT        CHAT      National    -  Total Number
# Steamships_Total Number_AT        CHAT      National    -  Total Number
# Steamships_Total Number_RU        CHAT      National    -  Total Number
# Steamships_Total Number_GR        CHAT      National    -  Total Number
# Steamships_Total Number_CA        CHAT      National    -  Total Number
# Steamships_Total Number_FR        CHAT      National    -  Total Number
# Steamships_Total Number_SE        CHAT      National    -  Total Number
# Steamships_Total Number_FI        CHAT      National    -  Total Number
# Steamships_Total Number_ES        CHAT      National    -  Total Number
# Steamships_Total Number_CL        CHAT      National    -  Total Number
#
#                            Technology Name
# ID
# Steamships_Total Number_NL      Steamships
# Steamships_Total Number_GB      Steamships
# Steamships_Total Number_BE      Steamships
# Steamships_Total Number_NO      Steamships
# Steamships_Total Number_CU      Steamships
# Steamships_Total Number_MX      Steamships
# Steamships_Total Number_DK      Steamships
# Steamships_Total Number_HU      Steamships
# Steamships_Total Number_IE      Steamships
# Steamships_Total Number_DE      Steamships
# Steamships_Total Number_IT      Steamships
# Steamships_Total Number_AT      Steamships
# Steamships_Total Number_RU      Steamships
# Steamships_Total Number_GR      Steamships
# Steamships_Total Number_CA      Steamships
# Steamships_Total Number_FR      Steamships
# Steamships_Total Number_SE      Steamships
# Steamships_Total Number_FI      Steamships
# Steamships_Total Number_ES      Steamships
# Steamships_Total Number_CL      Steamships
#
# [20 rows x 266 columns]

# %%
telephones = read_chat(91, 'Telephones', metric='Total Number')
telephones
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Telephones_Total Number_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_BZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Telephones_Total Number_NE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_AF  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_GM  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_AO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008    Country Name Country Code  \
# ID                          ...
# Telephones_Total Number_AU  ...  NaN  NaN  NaN       Australia           AU
# Telephones_Total Number_BZ  ...  NaN  NaN  NaN          Belize           BZ
# Telephones_Total Number_NL  ...  NaN  NaN  NaN     Netherlands           NL
# Telephones_Total Number_MA  ...  NaN  NaN  NaN         Morocco           MA
# Telephones_Total Number_GB  ...  NaN  NaN  NaN  United Kingdom           GB
# ...                         ...  ...  ...  ...             ...          ...
# Telephones_Total Number_NE  ...  NaN  NaN  NaN           Niger           NE
# Telephones_Total Number_AF  ...  NaN  NaN  NaN     Afghanistan           AF
# Telephones_Total Number_CL  ...  NaN  NaN  NaN           Chile           CL
# Telephones_Total Number_GM  ...  NaN  NaN  NaN          Gambia           GM
# Telephones_Total Number_AO  ...  NaN  NaN  NaN          Angola           AO
#
#                            Data Source Spatial Scale Unit        Metric  \
# ID
# Telephones_Total Number_AU        CHAT      National    -  Total Number
# Telephones_Total Number_BZ        CHAT      National    -  Total Number
# Telephones_Total Number_NL        CHAT      National    -  Total Number
# Telephones_Total Number_MA        CHAT      National    -  Total Number
# Telephones_Total Number_GB        CHAT      National    -  Total Number
# ...                                ...           ...  ...           ...
# Telephones_Total Number_NE        CHAT      National    -  Total Number
# Telephones_Total Number_AF        CHAT      National    -  Total Number
# Telephones_Total Number_CL        CHAT      National    -  Total Number
# Telephones_Total Number_GM        CHAT      National    -  Total Number
# Telephones_Total Number_AO        CHAT      National    -  Total Number
#
#                            Technology Name
# ID
# Telephones_Total Number_AU      Telephones
# Telephones_Total Number_BZ      Telephones
# Telephones_Total Number_NL      Telephones
# Telephones_Total Number_MA      Telephones
# Telephones_Total Number_GB      Telephones
# ...                                    ...
# Telephones_Total Number_NE      Telephones
# Telephones_Total Number_AF      Telephones
# Telephones_Total Number_CL      Telephones
# Telephones_Total Number_GM      Telephones
# Telephones_Total Number_AO      Telephones
#
# [156 rows x 266 columns]

# %%
rail = read_chat(46, 'Railroad', unit='kilometers',metric='Total Length')
rail
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                          1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Railroad_Total Length_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Total Length_BZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Total Length_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Total Length_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Total Length_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Railroad_Total Length_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Total Length_VN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Total Length_MW  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Total Length_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Total Length_AO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                           ... 2006 2007 2008    Country Name Country Code  \
# ID                        ...
# Railroad_Total Length_AU  ...  NaN  NaN  NaN       Australia           AU
# Railroad_Total Length_BZ  ...  NaN  NaN  NaN          Belize           BZ
# Railroad_Total Length_NL  ...  NaN  NaN  NaN     Netherlands           NL
# Railroad_Total Length_MA  ...  NaN  NaN  NaN         Morocco           MA
# Railroad_Total Length_GB  ...  NaN  NaN  NaN  United Kingdom           GB
# ...                       ...  ...  ...  ...             ...          ...
# Railroad_Total Length_ES  ...  NaN  NaN  NaN           Spain           ES
# Railroad_Total Length_VN  ...  NaN  NaN  NaN         Vietnam           VN
# Railroad_Total Length_MW  ...  NaN  NaN  NaN          Malawi           MW
# Railroad_Total Length_CL  ...  NaN  NaN  NaN           Chile           CL
# Railroad_Total Length_AO  ...  NaN  NaN  NaN          Angola           AO
#
#                          Data Source Spatial Scale        Unit        Metric  \
# ID
# Railroad_Total Length_AU        CHAT      National  kilometers  Total Length
# Railroad_Total Length_BZ        CHAT      National  kilometers  Total Length
# Railroad_Total Length_NL        CHAT      National  kilometers  Total Length
# Railroad_Total Length_MA        CHAT      National  kilometers  Total Length
# Railroad_Total Length_GB        CHAT      National  kilometers  Total Length
# ...                              ...           ...         ...           ...
# Railroad_Total Length_ES        CHAT      National  kilometers  Total Length
# Railroad_Total Length_VN        CHAT      National  kilometers  Total Length
# Railroad_Total Length_MW        CHAT      National  kilometers  Total Length
# Railroad_Total Length_CL        CHAT      National  kilometers  Total Length
# Railroad_Total Length_AO        CHAT      National  kilometers  Total Length
#
#                          Technology Name
# ID
# Railroad_Total Length_AU        Railroad
# Railroad_Total Length_BZ        Railroad
# Railroad_Total Length_NL        Railroad
# Railroad_Total Length_MA        Railroad
# Railroad_Total Length_GB        Railroad
# ...                                  ...
# Railroad_Total Length_ES        Railroad
# Railroad_Total Length_VN        Railroad
# Railroad_Total Length_MW        Railroad
# Railroad_Total Length_CL        Railroad
# Railroad_Total Length_AO        Railroad
#
# [128 rows x 266 columns]

# %%
tv = read_chat(97, 'Television', metric='Total Number')
tv
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Television_Total Number_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_BZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Television_Total Number_NE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_AF  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_GM  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_AO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008    Country Name Country Code  \
# ID                          ...
# Television_Total Number_AU  ...  NaN  NaN  NaN       Australia           AU
# Television_Total Number_BZ  ...  NaN  NaN  NaN          Belize           BZ
# Television_Total Number_NL  ...  NaN  NaN  NaN     Netherlands           NL
# Television_Total Number_MA  ...  NaN  NaN  NaN         Morocco           MA
# Television_Total Number_GB  ...  NaN  NaN  NaN  United Kingdom           GB
# ...                         ...  ...  ...  ...             ...          ...
# Television_Total Number_NE  ...  NaN  NaN  NaN           Niger           NE
# Television_Total Number_AF  ...  NaN  NaN  NaN     Afghanistan           AF
# Television_Total Number_CL  ...  NaN  NaN  NaN           Chile           CL
# Television_Total Number_GM  ...  NaN  NaN  NaN          Gambia           GM
# Television_Total Number_AO  ...  NaN  NaN  NaN          Angola           AO
#
#                            Data Source Spatial Scale Unit        Metric  \
# ID
# Television_Total Number_AU        CHAT      National    -  Total Number
# Television_Total Number_BZ        CHAT      National    -  Total Number
# Television_Total Number_NL        CHAT      National    -  Total Number
# Television_Total Number_MA        CHAT      National    -  Total Number
# Television_Total Number_GB        CHAT      National    -  Total Number
# ...                                ...           ...  ...           ...
# Television_Total Number_NE        CHAT      National    -  Total Number
# Television_Total Number_AF        CHAT      National    -  Total Number
# Television_Total Number_CL        CHAT      National    -  Total Number
# Television_Total Number_GM        CHAT      National    -  Total Number
# Television_Total Number_AO        CHAT      National    -  Total Number
#
#                            Technology Name
# ID
# Television_Total Number_AU      Television
# Television_Total Number_BZ      Television
# Television_Total Number_NL      Television
# Television_Total Number_MA      Television
# Television_Total Number_GB      Television
# ...                                    ...
# Television_Total Number_NE      Television
# Television_Total Number_AF      Television
# Television_Total Number_CL      Television
# Television_Total Number_GM      Television
# Television_Total Number_AO      Television
#
# [156 rows x 266 columns]

# %%
# Radio	CHAT database (radio)
radio = read_chat(45, 'Radio', metric='Total Number')
radio
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                       1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  ...  \
# ID                                                                       ...
# Radio_Total Number_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_BZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# ...                    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Radio_Total Number_NE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_AF  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_GM  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_AO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#                       2006 2007 2008    Country Name Country Code Data Source  \
# ID
# Radio_Total Number_AU  NaN  NaN  NaN       Australia           AU        CHAT
# Radio_Total Number_BZ  NaN  NaN  NaN          Belize           BZ        CHAT
# Radio_Total Number_NL  NaN  NaN  NaN     Netherlands           NL        CHAT
# Radio_Total Number_MA  NaN  NaN  NaN         Morocco           MA        CHAT
# Radio_Total Number_GB  NaN  NaN  NaN  United Kingdom           GB        CHAT
# ...                    ...  ...  ...             ...          ...         ...
# Radio_Total Number_NE  NaN  NaN  NaN           Niger           NE        CHAT
# Radio_Total Number_AF  NaN  NaN  NaN     Afghanistan           AF        CHAT
# Radio_Total Number_CL  NaN  NaN  NaN           Chile           CL        CHAT
# Radio_Total Number_GM  NaN  NaN  NaN          Gambia           GM        CHAT
# Radio_Total Number_AO  NaN  NaN  NaN          Angola           AO        CHAT
#
#                       Spatial Scale Unit        Metric Technology Name
# ID
# Radio_Total Number_AU      National    -  Total Number           Radio
# Radio_Total Number_BZ      National    -  Total Number           Radio
# Radio_Total Number_NL      National    -  Total Number           Radio
# Radio_Total Number_MA      National    -  Total Number           Radio
# Radio_Total Number_GB      National    -  Total Number           Radio
# ...                             ...  ...           ...             ...
# Radio_Total Number_NE      National    -  Total Number           Radio
# Radio_Total Number_AF      National    -  Total Number           Radio
# Radio_Total Number_CL      National    -  Total Number           Radio
# Radio_Total Number_GM      National    -  Total Number           Radio
# Radio_Total Number_AO      National    -  Total Number           Radio
#
# [156 rows x 266 columns]

# %%
# Passenger Cars	CHAT (vehicle_car)
cars = read_chat(102, 'Passenger Vehicles', metric='Total Number')
cars
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                    1750 1751 1752 1753 1754 1755 1756 1757  \
# ID
# Passenger Vehicles_Total Number_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Vehicles_Total Number_BZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Vehicles_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Vehicles_Total Number_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Vehicles_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# Passenger Vehicles_Total Number_NE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Vehicles_Total Number_AF  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Vehicles_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Vehicles_Total Number_GM  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Vehicles_Total Number_AO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                    1758 1759  ... 2006 2007 2008  \
# ID                                            ...
# Passenger Vehicles_Total Number_AU  NaN  NaN  ...  NaN  NaN  NaN
# Passenger Vehicles_Total Number_BZ  NaN  NaN  ...  NaN  NaN  NaN
# Passenger Vehicles_Total Number_NL  NaN  NaN  ...  NaN  NaN  NaN
# Passenger Vehicles_Total Number_MA  NaN  NaN  ...  NaN  NaN  NaN
# Passenger Vehicles_Total Number_GB  NaN  NaN  ...  NaN  NaN  NaN
# ...                                 ...  ...  ...  ...  ...  ...
# Passenger Vehicles_Total Number_NE  NaN  NaN  ...  NaN  NaN  NaN
# Passenger Vehicles_Total Number_AF  NaN  NaN  ...  NaN  NaN  NaN
# Passenger Vehicles_Total Number_CL  NaN  NaN  ...  NaN  NaN  NaN
# Passenger Vehicles_Total Number_GM  NaN  NaN  ...  NaN  NaN  NaN
# Passenger Vehicles_Total Number_AO  NaN  NaN  ...  NaN  NaN  NaN
#
#                                       Country Name Country Code Data Source  \
# ID
# Passenger Vehicles_Total Number_AU       Australia           AU        CHAT
# Passenger Vehicles_Total Number_BZ          Belize           BZ        CHAT
# Passenger Vehicles_Total Number_NL     Netherlands           NL        CHAT
# Passenger Vehicles_Total Number_MA         Morocco           MA        CHAT
# Passenger Vehicles_Total Number_GB  United Kingdom           GB        CHAT
# ...                                            ...          ...         ...
# Passenger Vehicles_Total Number_NE           Niger           NE        CHAT
# Passenger Vehicles_Total Number_AF     Afghanistan           AF        CHAT
# Passenger Vehicles_Total Number_CL           Chile           CL        CHAT
# Passenger Vehicles_Total Number_GM          Gambia           GM        CHAT
# Passenger Vehicles_Total Number_AO          Angola           AO        CHAT
#
#                                    Spatial Scale Unit        Metric  \
# ID
# Passenger Vehicles_Total Number_AU      National    -  Total Number
# Passenger Vehicles_Total Number_BZ      National    -  Total Number
# Passenger Vehicles_Total Number_NL      National    -  Total Number
# Passenger Vehicles_Total Number_MA      National    -  Total Number
# Passenger Vehicles_Total Number_GB      National    -  Total Number
# ...                                          ...  ...           ...
# Passenger Vehicles_Total Number_NE      National    -  Total Number
# Passenger Vehicles_Total Number_AF      National    -  Total Number
# Passenger Vehicles_Total Number_CL      National    -  Total Number
# Passenger Vehicles_Total Number_GM      National    -  Total Number
# Passenger Vehicles_Total Number_AO      National    -  Total Number
#
#                                        Technology Name
# ID
# Passenger Vehicles_Total Number_AU  Passenger Vehicles
# Passenger Vehicles_Total Number_BZ  Passenger Vehicles
# Passenger Vehicles_Total Number_NL  Passenger Vehicles
# Passenger Vehicles_Total Number_MA  Passenger Vehicles
# Passenger Vehicles_Total Number_GB  Passenger Vehicles
# ...                                                ...
# Passenger Vehicles_Total Number_NE  Passenger Vehicles
# Passenger Vehicles_Total Number_AF  Passenger Vehicles
# Passenger Vehicles_Total Number_CL  Passenger Vehicles
# Passenger Vehicles_Total Number_GM  Passenger Vehicles
# Passenger Vehicles_Total Number_AO  Passenger Vehicles
#
# [154 rows x 266 columns]

# %%
# Telegraph Traffic	CHAT (telegram)

telegram = read_chat(90, 'Telegraph Traffic', metric='Total Number')
telegram
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                   1750 1751 1752 1753 1754 1755 1756 1757  \
# ID
# Telegraph Traffic_Total Number_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_BE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                                ...  ...  ...  ...  ...  ...  ...  ...
# Telegraph Traffic_Total Number_GY  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_MW  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_AO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                   1758 1759  ... 2006 2007 2008  \
# ID                                           ...
# Telegraph Traffic_Total Number_AU  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_NL  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_MA  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_GB  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_BE  NaN  NaN  ...  NaN  NaN  NaN
# ...                                ...  ...  ...  ...  ...  ...
# Telegraph Traffic_Total Number_GY  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_ES  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_MW  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_CL  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_AO  NaN  NaN  ...  NaN  NaN  NaN
#
#                                      Country Name Country Code Data Source  \
# ID
# Telegraph Traffic_Total Number_AU       Australia           AU        CHAT
# Telegraph Traffic_Total Number_NL     Netherlands           NL        CHAT
# Telegraph Traffic_Total Number_MA         Morocco           MA        CHAT
# Telegraph Traffic_Total Number_GB  United Kingdom           GB        CHAT
# Telegraph Traffic_Total Number_BE         Belgium           BE        CHAT
# ...                                           ...          ...         ...
# Telegraph Traffic_Total Number_GY          Guyana           GY        CHAT
# Telegraph Traffic_Total Number_ES           Spain           ES        CHAT
# Telegraph Traffic_Total Number_MW          Malawi           MW        CHAT
# Telegraph Traffic_Total Number_CL           Chile           CL        CHAT
# Telegraph Traffic_Total Number_AO          Angola           AO        CHAT
#
#                                   Spatial Scale Unit        Metric  \
# ID
# Telegraph Traffic_Total Number_AU      National    -  Total Number
# Telegraph Traffic_Total Number_NL      National    -  Total Number
# Telegraph Traffic_Total Number_MA      National    -  Total Number
# Telegraph Traffic_Total Number_GB      National    -  Total Number
# Telegraph Traffic_Total Number_BE      National    -  Total Number
# ...                                         ...  ...           ...
# Telegraph Traffic_Total Number_GY      National    -  Total Number
# Telegraph Traffic_Total Number_ES      National    -  Total Number
# Telegraph Traffic_Total Number_MW      National    -  Total Number
# Telegraph Traffic_Total Number_CL      National    -  Total Number
# Telegraph Traffic_Total Number_AO      National    -  Total Number
#
#                                      Technology Name
# ID
# Telegraph Traffic_Total Number_AU  Telegraph Traffic
# Telegraph Traffic_Total Number_NL  Telegraph Traffic
# Telegraph Traffic_Total Number_MA  Telegraph Traffic
# Telegraph Traffic_Total Number_GB  Telegraph Traffic
# Telegraph Traffic_Total Number_BE  Telegraph Traffic
# ...                                              ...
# Telegraph Traffic_Total Number_GY  Telegraph Traffic
# Telegraph Traffic_Total Number_ES  Telegraph Traffic
# Telegraph Traffic_Total Number_MW  Telegraph Traffic
# Telegraph Traffic_Total Number_CL  Telegraph Traffic
# Telegraph Traffic_Total Number_AO  Telegraph Traffic
#
# [76 rows x 266 columns]

# %%
# Postal traffic	CHAT (mail)

mail = read_chat(25, 'Postal Traffic', metric='Total Number')
mail
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Postal Traffic_Total Number_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_BE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...  ...  ...  ...
# Postal Traffic_Total Number_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_VN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_MW  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_AO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                1759  ... 2006 2007 2008    Country Name  \
# ID                                   ...
# Postal Traffic_Total Number_AU  NaN  ...  NaN  NaN  NaN       Australia
# Postal Traffic_Total Number_NL  NaN  ...  NaN  NaN  NaN     Netherlands
# Postal Traffic_Total Number_MA  NaN  ...  NaN  NaN  NaN         Morocco
# Postal Traffic_Total Number_GB  NaN  ...  NaN  NaN  NaN  United Kingdom
# Postal Traffic_Total Number_BE  NaN  ...  NaN  NaN  NaN         Belgium
# ...                             ...  ...  ...  ...  ...             ...
# Postal Traffic_Total Number_ES  NaN  ...  NaN  NaN  NaN           Spain
# Postal Traffic_Total Number_VN  NaN  ...  NaN  NaN  NaN         Vietnam
# Postal Traffic_Total Number_MW  NaN  ...  NaN  NaN  NaN          Malawi
# Postal Traffic_Total Number_CL  NaN  ...  NaN  NaN  NaN           Chile
# Postal Traffic_Total Number_AO  NaN  ...  NaN  NaN  NaN          Angola
#
#                                Country Code Data Source Spatial Scale Unit  \
# ID
# Postal Traffic_Total Number_AU           AU        CHAT      National    -
# Postal Traffic_Total Number_NL           NL        CHAT      National    -
# Postal Traffic_Total Number_MA           MA        CHAT      National    -
# Postal Traffic_Total Number_GB           GB        CHAT      National    -
# Postal Traffic_Total Number_BE           BE        CHAT      National    -
# ...                                     ...         ...           ...  ...
# Postal Traffic_Total Number_ES           ES        CHAT      National    -
# Postal Traffic_Total Number_VN           VN        CHAT      National    -
# Postal Traffic_Total Number_MW           MW        CHAT      National    -
# Postal Traffic_Total Number_CL           CL        CHAT      National    -
# Postal Traffic_Total Number_AO           AO        CHAT      National    -
#
#                                       Metric Technology Name
# ID
# Postal Traffic_Total Number_AU  Total Number  Postal Traffic
# Postal Traffic_Total Number_NL  Total Number  Postal Traffic
# Postal Traffic_Total Number_MA  Total Number  Postal Traffic
# Postal Traffic_Total Number_GB  Total Number  Postal Traffic
# Postal Traffic_Total Number_BE  Total Number  Postal Traffic
# ...                                      ...             ...
# Postal Traffic_Total Number_ES  Total Number  Postal Traffic
# Postal Traffic_Total Number_VN  Total Number  Postal Traffic
# Postal Traffic_Total Number_MW  Total Number  Postal Traffic
# Postal Traffic_Total Number_CL  Total Number  Postal Traffic
# Postal Traffic_Total Number_AO  Total Number  Postal Traffic
#
# [80 rows x 266 columns]

# %%
# Cellphones	CHAT (cellphone)

cells = read_chat(12, 'Cellphones', metric='Total Number')
cells
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_50802/3458257207.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Cellphones_Total Number_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_BZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_MA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Cellphones_Total Number_NE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_AF  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_GM  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_AO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008    Country Name Country Code  \
# ID                          ...
# Cellphones_Total Number_AU  ...  NaN  NaN  NaN       Australia           AU
# Cellphones_Total Number_BZ  ...  NaN  NaN  NaN          Belize           BZ
# Cellphones_Total Number_NL  ...  NaN  NaN  NaN     Netherlands           NL
# Cellphones_Total Number_MA  ...  NaN  NaN  NaN         Morocco           MA
# Cellphones_Total Number_GB  ...  NaN  NaN  NaN  United Kingdom           GB
# ...                         ...  ...  ...  ...             ...          ...
# Cellphones_Total Number_NE  ...  NaN  NaN  NaN           Niger           NE
# Cellphones_Total Number_AF  ...  NaN  NaN  NaN     Afghanistan           AF
# Cellphones_Total Number_CL  ...  NaN  NaN  NaN           Chile           CL
# Cellphones_Total Number_GM  ...  NaN  NaN  NaN          Gambia           GM
# Cellphones_Total Number_AO  ...  NaN  NaN  NaN          Angola           AO
#
#                            Data Source Spatial Scale Unit        Metric  \
# ID
# Cellphones_Total Number_AU        CHAT      National    -  Total Number
# Cellphones_Total Number_BZ        CHAT      National    -  Total Number
# Cellphones_Total Number_NL        CHAT      National    -  Total Number
# Cellphones_Total Number_MA        CHAT      National    -  Total Number
# Cellphones_Total Number_GB        CHAT      National    -  Total Number
# ...                                ...           ...  ...           ...
# Cellphones_Total Number_NE        CHAT      National    -  Total Number
# Cellphones_Total Number_AF        CHAT      National    -  Total Number
# Cellphones_Total Number_CL        CHAT      National    -  Total Number
# Cellphones_Total Number_GM        CHAT      National    -  Total Number
# Cellphones_Total Number_AO        CHAT      National    -  Total Number
#
#                            Technology Name
# ID
# Cellphones_Total Number_AU      Cellphones
# Cellphones_Total Number_BZ      Cellphones
# Cellphones_Total Number_NL      Cellphones
# Cellphones_Total Number_MA      Cellphones
# Cellphones_Total Number_GB      Cellphones
# ...                                    ...
# Cellphones_Total Number_NE      Cellphones
# Cellphones_Total Number_AF      Cellphones
# Cellphones_Total Number_CL      Cellphones
# Cellphones_Total Number_GM      Cellphones
# Cellphones_Total Number_AO      Cellphones
#
# [153 rows x 266 columns]

# %%
for var_def in chat_dict[chat_dict[chat_dict.columns[0]]=='telephone'][chat_dict.columns[1]]:
    print(var_def)
# Out:
# Number of mainline telephone lines connecting a customer's equipment to the public switched telephone network as of year end

# %%
for var_idx in chat_dict[chat_dict[chat_dict.columns[0]]=='ag_harvester'].index:
    print(var_idx)
# Out:
# 0

# %%
chat_dict.iloc[89]
# Out:
# VARIABLE NAME                                             telephone
# DEFINITION        Number of mainline telephone lines connecting ...
# SOURCE                           Mitchell (1998), WORLD BANK (2007)
# Name: 89, dtype: object
