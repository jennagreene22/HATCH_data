# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
# https://www.fhwa.dot.gov/policyinformation/statistics/2020/vmt421c.cfm
# https://www.fhwa.dot.gov/policyinformation/statistics/2020/xls/vmt421c.xls

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
dot = pd.read_csv('raw data/vmt421c.csv', header=1, index_col=0, usecols=[0,1])
dot
# Out:
#              Publicroadmileage
# Record Year
# 1900                   2320000
# 1901                   2325000
# 1902                   2330000
# 1903                   2340000
# 1904                   2351000
# ...                        ...
# 2016                   4140108
# 2017                   4184471
# 2018                   4195274
# 2019                   4189483
# 2020                   4192479
#
# [121 rows x 1 columns]

# %%
dot = dot.transpose()
dot
# Out:
# Record Year           1900     1901     1902     1903     1904     1905  \
# Publicroadmileage  2320000  2325000  2330000  2340000  2351000  2360000
#
# Record Year           1906     1907     1908     1909  ...     2011     2012  \
# Publicroadmileage  2370000  2382000  2395000  2410000  ...  4094447  4092730
#
# Record Year           2013     2014     2015     2016     2017     2018  \
# Publicroadmileage  4115462  4194257  4171417  4140108  4184471  4195274
#
# Record Year           2019     2020
# Publicroadmileage  4189483  4192479
#
# [1 rows x 121 columns]

# %%
dot['Country Name'] = 'United States'
dot['Country Code'] = 'US'
dot['Unit'] = 'miles'
dot['Metric'] = 'Total Length'
dot['Spatial Scale'] = 'National'
dot['Technology Name'] = 'Public Roads'
dot['Data Source'] = 'FHWA'
dot['ID'] = dot['Technology Name'] + '_' + dot['Metric'] + '_' + dot['Country Code']
dot.set_index('ID', drop=True, inplace=True)
dot
# Out:
# Record Year                      1900     1901     1902     1903     1904  \
# ID
# Public Roads_Total Length_US  2320000  2325000  2330000  2340000  2351000
#
# Record Year                      1905     1906     1907     1908     1909  \
# ID
# Public Roads_Total Length_US  2360000  2370000  2382000  2395000  2410000
#
# Record Year                   ...     2018     2019     2020   Country Name  \
# ID                            ...
# Public Roads_Total Length_US  ...  4195274  4189483  4192479  United States
#
# Record Year                   Country Code   Unit        Metric  \
# ID
# Public Roads_Total Length_US            US  miles  Total Length
#
# Record Year                   Spatial Scale  Technology Name  Data Source
# ID
# Public Roads_Total Length_US       National     Public Roads         FHWA
#
# [1 rows x 128 columns]

# %%
dot.to_csv('cleaned data/dot.csv')
