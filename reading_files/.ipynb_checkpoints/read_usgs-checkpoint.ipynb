# %%
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco
import string
import os
import numpy as np

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
# https://www.usgs.gov/centers/national-minerals-information-center/historical-global-statistics-mineral-and-material
# Data Series 896

# %%
def read_usgs_896(tech_name, file_name, sheet_name=0):
    df = pd.read_excel(file_name, sheet_name=sheet_name, header=3,
                       na_values=['XX','--', 'W', '(3/)', '(4/)','-- '])
    drop_idx = []
    for idx in df.index:
        country = df[df.columns[0]].iloc[idx]
        drop_list = ['Limonite', 'Other', 'Puerto Rico', 'United States: Puerto Rico', 'Leeward and Windward Islands ']
        if country in drop_list:
            drop_idx.append(idx)
    df.drop(index=drop_idx, inplace=True)
    df.reset_index(drop=True, inplace=True)
    for idx in df.index:
        country = df[df.columns[0]].iloc[idx]
        if country == 'World':
            world_idx = idx + 1
    df = df[:world_idx]
    countries = []
    for country in df[df.columns[0]]:
        country = country.strip(string.digits)
        country = country.strip()
        countries.append(country)
    df['Country Name'] = countries
    df.drop(columns=df.columns[0], inplace=True)
    iso2 = []
    spatial_scale = []
    for country in df['Country Name']:
        if country == 'Serbia and Montenegro':
            iso2.append('CS')
            spatial_scale.append('National')
        elif country == 'Czechoslovakia':
            iso2.append('CSK')
            spatial_scale.append('National')
        elif country == 'U.S.S.R.':
            iso2.append('SU')
            spatial_scale.append('National')
        elif country == 'Yugoslavia':
            iso2.append('YU')
            spatial_scale.append('National')
        elif country == 'Netherlands Antilles':
            iso2.append('AN')
            spatial_scale.append('National')
        elif country == 'World':
            iso2.append('World')
            spatial_scale.append('Global')
        else:
            iso2.append(coco.convert(names=country, to='iso2'))
            spatial_scale.append('National')
    df['Country Code'] = iso2
    df['Spatial Scale'] = spatial_scale
    df['Data Source'] = 'USGS'
    df['Unit'] = 'metric tons'
    df['Metric'] = 'Annual production'
    df['Technology Name'] = tech_name
    df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']
    df.set_index('ID', inplace=True)
    omit = []
    for col in df.columns:
        if len(str(col)) > 4 or col == 'Unit':
            omit.append(col)
    empty_rows = df.drop(columns=omit)
    empty_rows.dropna(how='all', inplace=True)
    na_idx = []
    for country in df.index:
        if country not in empty_rows.index:
            na_idx.append(country)
    df.drop(na_idx, inplace=True)
    # drop US/world entries that we're getting longer time series for in data series 140 below
    dup_list = ['Primary Aluminum Production_Annual production_US', 
                'Primary Aluminum Production_Annual production_World',
                'Primary Bauxite Production_Annual production_World','Cadmium Refining_Annual production_US',
                'Cadmium Refining_Annual production_World','Lead_Annual production_US',
                'Lead_Annual production_World','Salt Production_Annual production_US',
                'Iron Ore_Annual production_US','Iron Ore_Annual production_World',
                'Raw Steel Production_Annual production_US','Raw Steel Production_Annual production_World']
    for idx in df.index:
        if idx in dup_list:
            df.drop(idx, inplace=True)
    file_name = 'cleaned data/ds896_' + tech_name + '.csv'
    df.to_csv(file_name)
    return df

# %%
# Aluminum and Bauxite
aluminum = read_usgs_896('Primary Aluminum Production', 'raw data/usgs/ds896-aluminum.xlsx', 'Aluminum, primary production')
bauxite = read_usgs_896('Primary Bauxite Production', 'raw data/usgs/ds896-aluminum.xlsx', 'Bauxite')

bauxite
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#                                                        1990        1991  \
# ID
# Primary Bauxite Production_Annual production_AL     26000.0     20000.0
# Primary Bauxite Production_Annual production_AU  41400000.0  40500000.0
# Primary Bauxite Production_Annual production_BA         NaN         NaN
# Primary Bauxite Production_Annual production_BR   9680000.0  10400000.0
# Primary Bauxite Production_Annual production_CN   2400000.0   2600000.0
# Primary Bauxite Production_Annual production_HR         NaN         NaN
# Primary Bauxite Production_Annual production_DO     85000.0      7000.0
# Primary Bauxite Production_Annual production_FJ         NaN         NaN
# Primary Bauxite Production_Annual production_FR    490000.0      9000.0
# Primary Bauxite Production_Annual production_GH    381000.0    353000.0
# Primary Bauxite Production_Annual production_GR   2500000.0   2130000.0
# Primary Bauxite Production_Annual production_GN  15800000.0  15500000.0
# Primary Bauxite Production_Annual production_GY   1420000.0   2200000.0
# Primary Bauxite Production_Annual production_HU   2560000.0   2040000.0
# Primary Bauxite Production_Annual production_IN   4850000.0   4740000.0
# Primary Bauxite Production_Annual production_ID   1210000.0   1410000.0
# Primary Bauxite Production_Annual production_IR    100000.0    100000.0
# Primary Bauxite Production_Annual production_IT         NaN      9000.0
# Primary Bauxite Production_Annual production_JM  10900000.0  11600000.0
# Primary Bauxite Production_Annual production_KZ         NaN         NaN
# Primary Bauxite Production_Annual production_MY    398000.0    376000.0
# Primary Bauxite Production_Annual production_ME         NaN         NaN
# Primary Bauxite Production_Annual production_MZ      7000.0      8000.0
# Primary Bauxite Production_Annual production_PK      3000.0      4000.0
# Primary Bauxite Production_Annual production_RO    243000.0    200000.0
# Primary Bauxite Production_Annual production_RU         NaN         NaN
# Primary Bauxite Production_Annual production_CS         NaN         NaN
# Primary Bauxite Production_Annual production_SL   1430000.0   1290000.0
# Primary Bauxite Production_Annual production_ES      1000.0      1000.0
# Primary Bauxite Production_Annual production_SR   3280000.0   3200000.0
# Primary Bauxite Production_Annual production_TZ         NaN         NaN
# Primary Bauxite Production_Annual production_TR    773000.0    489000.0
# Primary Bauxite Production_Annual production_SU   9250000.0   7870000.0
# Primary Bauxite Production_Annual production_VE    771000.0   1990000.0
# Primary Bauxite Production_Annual production_VN         NaN         NaN
# Primary Bauxite Production_Annual production_YU   2950000.0   1910000.0
#
#                                                        1992        1993  \
# ID
# Primary Bauxite Production_Annual production_AL      4000.0      2000.0
# Primary Bauxite Production_Annual production_AU  39700000.0  41300000.0
# Primary Bauxite Production_Annual production_BA    200000.0    100000.0
# Primary Bauxite Production_Annual production_BR   9370000.0  10000000.0
# Primary Bauxite Production_Annual production_CN   2700000.0   3500000.0
# Primary Bauxite Production_Annual production_HR      7000.0      2000.0
# Primary Bauxite Production_Annual production_DO         NaN         NaN
# Primary Bauxite Production_Annual production_FJ         NaN         NaN
# Primary Bauxite Production_Annual production_FR         NaN         NaN
# Primary Bauxite Production_Annual production_GH    338000.0    365000.0
# Primary Bauxite Production_Annual production_GR   2080000.0   2210000.0
# Primary Bauxite Production_Annual production_GN  13800000.0  15300000.0
# Primary Bauxite Production_Annual production_GY   2380000.0   2130000.0
# Primary Bauxite Production_Annual production_HU   1720000.0   1560000.0
# Primary Bauxite Production_Annual production_IN   4900000.0   5280000.0
# Primary Bauxite Production_Annual production_ID    804000.0   1320000.0
# Primary Bauxite Production_Annual production_IR    100000.0    100000.0
# Primary Bauxite Production_Annual production_IT     98000.0     90000.0
# Primary Bauxite Production_Annual production_JM  11300000.0  11300000.0
# Primary Bauxite Production_Annual production_KZ   3040000.0   3000000.0
# Primary Bauxite Production_Annual production_MY    331000.0     69000.0
# Primary Bauxite Production_Annual production_ME         NaN         NaN
# Primary Bauxite Production_Annual production_MZ      8000.0      6000.0
# Primary Bauxite Production_Annual production_PK      3000.0      5000.0
# Primary Bauxite Production_Annual production_RO    175000.0    186000.0
# Primary Bauxite Production_Annual production_RU   4580000.0   4260000.0
# Primary Bauxite Production_Annual production_CS    792000.0    102000.0
# Primary Bauxite Production_Annual production_SL   1250000.0   1170000.0
# Primary Bauxite Production_Annual production_ES         NaN         NaN
# Primary Bauxite Production_Annual production_SR   3250000.0   3420000.0
# Primary Bauxite Production_Annual production_TZ         NaN         NaN
# Primary Bauxite Production_Annual production_TR    613000.0    538000.0
# Primary Bauxite Production_Annual production_SU         NaN         NaN
# Primary Bauxite Production_Annual production_VE   1050000.0   2530000.0
# Primary Bauxite Production_Annual production_VN         NaN         NaN
# Primary Bauxite Production_Annual production_YU         NaN         NaN
#
#                                                        1994        1995  \
# ID
# Primary Bauxite Production_Annual production_AL      2000.0      1000.0
# Primary Bauxite Production_Annual production_AU  41700000.0  42700000.0
# Primary Bauxite Production_Annual production_BA     75000.0     75000.0
# Primary Bauxite Production_Annual production_BR   8670000.0  10200000.0
# Primary Bauxite Production_Annual production_CN   3700000.0   5000000.0
# Primary Bauxite Production_Annual production_HR      1000.0      2000.0
# Primary Bauxite Production_Annual production_DO         NaN         NaN
# Primary Bauxite Production_Annual production_FJ         NaN         NaN
# Primary Bauxite Production_Annual production_FR         NaN         NaN
# Primary Bauxite Production_Annual production_GH    452000.0    523000.0
# Primary Bauxite Production_Annual production_GR   2200000.0   2200000.0
# Primary Bauxite Production_Annual production_GN  13300000.0  15800000.0
# Primary Bauxite Production_Annual production_GY   1730000.0   2030000.0
# Primary Bauxite Production_Annual production_HU    836000.0   1020000.0
# Primary Bauxite Production_Annual production_IN   4810000.0   5240000.0
# Primary Bauxite Production_Annual production_ID   1340000.0    899000.0
# Primary Bauxite Production_Annual production_IR     68000.0    148000.0
# Primary Bauxite Production_Annual production_IT     23000.0     11000.0
# Primary Bauxite Production_Annual production_JM  11600000.0  10900000.0
# Primary Bauxite Production_Annual production_KZ   2430000.0   3070000.0
# Primary Bauxite Production_Annual production_MY    162000.0    184000.0
# Primary Bauxite Production_Annual production_ME         NaN         NaN
# Primary Bauxite Production_Annual production_MZ     10000.0     11000.0
# Primary Bauxite Production_Annual production_PK      5000.0      3000.0
# Primary Bauxite Production_Annual production_RO    184000.0    174000.0
# Primary Bauxite Production_Annual production_RU   3000000.0   3100000.0
# Primary Bauxite Production_Annual production_CS         NaN     60000.0
# Primary Bauxite Production_Annual production_SL    735000.0         NaN
# Primary Bauxite Production_Annual production_ES         NaN         NaN
# Primary Bauxite Production_Annual production_SR   3770000.0   3530000.0
# Primary Bauxite Production_Annual production_TZ         NaN         NaN
# Primary Bauxite Production_Annual production_TR    445000.0    232000.0
# Primary Bauxite Production_Annual production_SU         NaN         NaN
# Primary Bauxite Production_Annual production_VE   4420000.0   5020000.0
# Primary Bauxite Production_Annual production_VN         NaN         NaN
# Primary Bauxite Production_Annual production_YU         NaN         NaN
#
#                                                        1996        1997  \
# ID
# Primary Bauxite Production_Annual production_AL      1000.0      1000.0
# Primary Bauxite Production_Annual production_AU  43100000.0  44500000.0
# Primary Bauxite Production_Annual production_BA     75000.0     75000.0
# Primary Bauxite Production_Annual production_BR  11000000.0  11700000.0
# Primary Bauxite Production_Annual production_CN   6200000.0   8000000.0
# Primary Bauxite Production_Annual production_HR         NaN         NaN
# Primary Bauxite Production_Annual production_DO         NaN         NaN
# Primary Bauxite Production_Annual production_FJ         NaN         NaN
# Primary Bauxite Production_Annual production_FR         NaN         NaN
# Primary Bauxite Production_Annual production_GH    473000.0    519000.0
# Primary Bauxite Production_Annual production_GR   2450000.0   1880000.0
# Primary Bauxite Production_Annual production_GN  15600000.0  16400000.0
# Primary Bauxite Production_Annual production_GY   2480000.0   2470000.0
# Primary Bauxite Production_Annual production_HU   1040000.0    743000.0
# Primary Bauxite Production_Annual production_IN   5760000.0   6020000.0
# Primary Bauxite Production_Annual production_ID    842000.0    809000.0
# Primary Bauxite Production_Annual production_IR    150000.0     92000.0
# Primary Bauxite Production_Annual production_IT         NaN         NaN
# Primary Bauxite Production_Annual production_JM  11900000.0  12000000.0
# Primary Bauxite Production_Annual production_KZ   3140000.0   3380000.0
# Primary Bauxite Production_Annual production_MY    219000.0    279000.0
# Primary Bauxite Production_Annual production_ME         NaN         NaN
# Primary Bauxite Production_Annual production_MZ     11000.0      8000.0
# Primary Bauxite Production_Annual production_PK      4000.0      5000.0
# Primary Bauxite Production_Annual production_RO    175000.0    127000.0
# Primary Bauxite Production_Annual production_RU   3300000.0   3350000.0
# Primary Bauxite Production_Annual production_CS    323000.0    470000.0
# Primary Bauxite Production_Annual production_SL         NaN         NaN
# Primary Bauxite Production_Annual production_ES         NaN         NaN
# Primary Bauxite Production_Annual production_SR   3700000.0   3880000.0
# Primary Bauxite Production_Annual production_TZ         NaN         NaN
# Primary Bauxite Production_Annual production_TR    545000.0    369000.0
# Primary Bauxite Production_Annual production_SU         NaN         NaN
# Primary Bauxite Production_Annual production_VE   4830000.0   4970000.0
# Primary Bauxite Production_Annual production_VN         NaN         NaN
# Primary Bauxite Production_Annual production_YU         NaN         NaN
#
#                                                        1998        1999  ...  \
# ID                                                                       ...
# Primary Bauxite Production_Annual production_AL         NaN         NaN  ...
# Primary Bauxite Production_Annual production_AU  44600000.0  48400000.0  ...
# Primary Bauxite Production_Annual production_BA     75000.0     75000.0  ...
# Primary Bauxite Production_Annual production_BR  12000000.0  14400000.0  ...
# Primary Bauxite Production_Annual production_CN   8200000.0   8500000.0  ...
# Primary Bauxite Production_Annual production_HR         NaN         NaN  ...
# Primary Bauxite Production_Annual production_DO         NaN         NaN  ...
# Primary Bauxite Production_Annual production_FJ         NaN         NaN  ...
# Primary Bauxite Production_Annual production_FR         NaN         NaN  ...
# Primary Bauxite Production_Annual production_GH    341000.0    355000.0  ...
# Primary Bauxite Production_Annual production_GR   1820000.0   1880000.0  ...
# Primary Bauxite Production_Annual production_GN  15600000.0  15600000.0  ...
# Primary Bauxite Production_Annual production_GY   2270000.0   2360000.0  ...
# Primary Bauxite Production_Annual production_HU   1140000.0    935000.0  ...
# Primary Bauxite Production_Annual production_IN   6100000.0   6710000.0  ...
# Primary Bauxite Production_Annual production_ID   1060000.0   1120000.0  ...
# Primary Bauxite Production_Annual production_IR    336000.0    912000.0  ...
# Primary Bauxite Production_Annual production_IT         NaN         NaN  ...
# Primary Bauxite Production_Annual production_JM  12600000.0  11700000.0  ...
# Primary Bauxite Production_Annual production_KZ   3440000.0   3610000.0  ...
# Primary Bauxite Production_Annual production_MY    160000.0    224000.0  ...
# Primary Bauxite Production_Annual production_ME         NaN         NaN  ...
# Primary Bauxite Production_Annual production_MZ      6000.0      8000.0  ...
# Primary Bauxite Production_Annual production_PK      5000.0     11000.0  ...
# Primary Bauxite Production_Annual production_RO    162000.0         NaN  ...
# Primary Bauxite Production_Annual production_RU   3450000.0   3750000.0  ...
# Primary Bauxite Production_Annual production_CS    226000.0    500000.0  ...
# Primary Bauxite Production_Annual production_SL         NaN         NaN  ...
# Primary Bauxite Production_Annual production_ES         NaN         NaN  ...
# Primary Bauxite Production_Annual production_SR   3930000.0   3720000.0  ...
# Primary Bauxite Production_Annual production_TZ         NaN         NaN  ...
# Primary Bauxite Production_Annual production_TR    458000.0    208000.0  ...
# Primary Bauxite Production_Annual production_SU         NaN         NaN  ...
# Primary Bauxite Production_Annual production_VE   4830000.0   4170000.0  ...
# Primary Bauxite Production_Annual production_VN         NaN         NaN  ...
# Primary Bauxite Production_Annual production_YU         NaN         NaN  ...
#
#                                                        2010        2011  \
# ID
# Primary Bauxite Production_Annual production_AL         NaN         NaN
# Primary Bauxite Production_Annual production_AU  68400000.0  70000000.0
# Primary Bauxite Production_Annual production_BA    844000.0    708000.0
# Primary Bauxite Production_Annual production_BR  32000000.0  33700000.0
# Primary Bauxite Production_Annual production_CN  44000000.0  45000000.0
# Primary Bauxite Production_Annual production_HR         NaN         NaN
# Primary Bauxite Production_Annual production_DO         NaN         NaN
# Primary Bauxite Production_Annual production_FJ         NaN     50000.0
# Primary Bauxite Production_Annual production_FR         NaN         NaN
# Primary Bauxite Production_Annual production_GH    595000.0    408000.0
# Primary Bauxite Production_Annual production_GR   1900000.0   1900000.0
# Primary Bauxite Production_Annual production_GN  15300000.0  15300000.0
# Primary Bauxite Production_Annual production_GY   1080000.0   1820000.0
# Primary Bauxite Production_Annual production_HU    307000.0    278000.0
# Primary Bauxite Production_Annual production_IN  18000000.0  19000000.0
# Primary Bauxite Production_Annual production_ID  27000000.0  40000000.0
# Primary Bauxite Production_Annual production_IR    681000.0    600000.0
# Primary Bauxite Production_Annual production_IT         NaN         NaN
# Primary Bauxite Production_Annual production_JM   8540000.0  10200000.0
# Primary Bauxite Production_Annual production_KZ   5310000.0   5500000.0
# Primary Bauxite Production_Annual production_MY    124000.0    188000.0
# Primary Bauxite Production_Annual production_ME     61200.0     60000.0
# Primary Bauxite Production_Annual production_MZ      8560.0     10400.0
# Primary Bauxite Production_Annual production_PK      9580.0     10000.0
# Primary Bauxite Production_Annual production_RO         NaN         NaN
# Primary Bauxite Production_Annual production_RU   5690000.0   5940000.0
# Primary Bauxite Production_Annual production_CS         NaN         NaN
# Primary Bauxite Production_Annual production_SL   1090000.0   1300000.0
# Primary Bauxite Production_Annual production_ES         NaN         NaN
# Primary Bauxite Production_Annual production_SR   3100000.0   3240000.0
# Primary Bauxite Production_Annual production_TZ     30300.0     28500.0
# Primary Bauxite Production_Annual production_TR   1310000.0   1020000.0
# Primary Bauxite Production_Annual production_SU         NaN         NaN
# Primary Bauxite Production_Annual production_VE   2500000.0   2460000.0
# Primary Bauxite Production_Annual production_VN     80000.0    100000.0
# Primary Bauxite Production_Annual production_YU         NaN         NaN
#
#                                                        2012  \
# ID
# Primary Bauxite Production_Annual production_AL         NaN
# Primary Bauxite Production_Annual production_AU  76300000.0
# Primary Bauxite Production_Annual production_BA    700000.0
# Primary Bauxite Production_Annual production_BR  34000000.0
# Primary Bauxite Production_Annual production_CN  47000000.0
# Primary Bauxite Production_Annual production_HR         NaN
# Primary Bauxite Production_Annual production_DO         NaN
# Primary Bauxite Production_Annual production_FJ    500000.0
# Primary Bauxite Production_Annual production_FR         NaN
# Primary Bauxite Production_Annual production_GH    790000.0
# Primary Bauxite Production_Annual production_GR   2100000.0
# Primary Bauxite Production_Annual production_GN  17800000.0
# Primary Bauxite Production_Annual production_GY   2210000.0
# Primary Bauxite Production_Annual production_HU    250000.0
# Primary Bauxite Production_Annual production_IN  19000000.0
# Primary Bauxite Production_Annual production_ID  29000000.0
# Primary Bauxite Production_Annual production_IR    600000.0
# Primary Bauxite Production_Annual production_IT         NaN
# Primary Bauxite Production_Annual production_JM   9340000.0
# Primary Bauxite Production_Annual production_KZ   5170000.0
# Primary Bauxite Production_Annual production_MY    200000.0
# Primary Bauxite Production_Annual production_ME     60000.0
# Primary Bauxite Production_Annual production_MZ     13000.0
# Primary Bauxite Production_Annual production_PK     12000.0
# Primary Bauxite Production_Annual production_RO         NaN
# Primary Bauxite Production_Annual production_RU   5700000.0
# Primary Bauxite Production_Annual production_CS         NaN
# Primary Bauxite Production_Annual production_SL    776000.0
# Primary Bauxite Production_Annual production_ES         NaN
# Primary Bauxite Production_Annual production_SR   3400000.0
# Primary Bauxite Production_Annual production_TZ     20000.0
# Primary Bauxite Production_Annual production_TR   1100000.0
# Primary Bauxite Production_Annual production_SU         NaN
# Primary Bauxite Production_Annual production_VE   2000000.0
# Primary Bauxite Production_Annual production_VN    100000.0
# Primary Bauxite Production_Annual production_YU         NaN
#
#                                                            Country Name  \
# ID
# Primary Bauxite Production_Annual production_AL                 Albania
# Primary Bauxite Production_Annual production_AU               Australia
# Primary Bauxite Production_Annual production_BA  Bosnia and Herzegovina
# Primary Bauxite Production_Annual production_BR                  Brazil
# Primary Bauxite Production_Annual production_CN                   China
# Primary Bauxite Production_Annual production_HR                 Croatia
# Primary Bauxite Production_Annual production_DO      Dominican Republic
# Primary Bauxite Production_Annual production_FJ                    Fiji
# Primary Bauxite Production_Annual production_FR                  France
# Primary Bauxite Production_Annual production_GH                   Ghana
# Primary Bauxite Production_Annual production_GR                  Greece
# Primary Bauxite Production_Annual production_GN                  Guinea
# Primary Bauxite Production_Annual production_GY                  Guyana
# Primary Bauxite Production_Annual production_HU                 Hungary
# Primary Bauxite Production_Annual production_IN                   India
# Primary Bauxite Production_Annual production_ID               Indonesia
# Primary Bauxite Production_Annual production_IR                    Iran
# Primary Bauxite Production_Annual production_IT                   Italy
# Primary Bauxite Production_Annual production_JM                 Jamaica
# Primary Bauxite Production_Annual production_KZ              Kazakhstan
# Primary Bauxite Production_Annual production_MY                Malaysia
# Primary Bauxite Production_Annual production_ME              Montenegro
# Primary Bauxite Production_Annual production_MZ              Mozambique
# Primary Bauxite Production_Annual production_PK                Pakistan
# Primary Bauxite Production_Annual production_RO                 Romania
# Primary Bauxite Production_Annual production_RU                  Russia
# Primary Bauxite Production_Annual production_CS   Serbia and Montenegro
# Primary Bauxite Production_Annual production_SL            Sierra Leone
# Primary Bauxite Production_Annual production_ES                   Spain
# Primary Bauxite Production_Annual production_SR                Suriname
# Primary Bauxite Production_Annual production_TZ                Tanzania
# Primary Bauxite Production_Annual production_TR                  Turkey
# Primary Bauxite Production_Annual production_SU                U.S.S.R.
# Primary Bauxite Production_Annual production_VE               Venezuela
# Primary Bauxite Production_Annual production_VN                 Vietnam
# Primary Bauxite Production_Annual production_YU              Yugoslavia
#
#                                                  Country Code  Spatial Scale  \
# ID
# Primary Bauxite Production_Annual production_AL            AL       National
# Primary Bauxite Production_Annual production_AU            AU       National
# Primary Bauxite Production_Annual production_BA            BA       National
# Primary Bauxite Production_Annual production_BR            BR       National
# Primary Bauxite Production_Annual production_CN            CN       National
# Primary Bauxite Production_Annual production_HR            HR       National
# Primary Bauxite Production_Annual production_DO            DO       National
# Primary Bauxite Production_Annual production_FJ            FJ       National
# Primary Bauxite Production_Annual production_FR            FR       National
# Primary Bauxite Production_Annual production_GH            GH       National
# Primary Bauxite Production_Annual production_GR            GR       National
# Primary Bauxite Production_Annual production_GN            GN       National
# Primary Bauxite Production_Annual production_GY            GY       National
# Primary Bauxite Production_Annual production_HU            HU       National
# Primary Bauxite Production_Annual production_IN            IN       National
# Primary Bauxite Production_Annual production_ID            ID       National
# Primary Bauxite Production_Annual production_IR            IR       National
# Primary Bauxite Production_Annual production_IT            IT       National
# Primary Bauxite Production_Annual production_JM            JM       National
# Primary Bauxite Production_Annual production_KZ            KZ       National
# Primary Bauxite Production_Annual production_MY            MY       National
# Primary Bauxite Production_Annual production_ME            ME       National
# Primary Bauxite Production_Annual production_MZ            MZ       National
# Primary Bauxite Production_Annual production_PK            PK       National
# Primary Bauxite Production_Annual production_RO            RO       National
# Primary Bauxite Production_Annual production_RU            RU       National
# Primary Bauxite Production_Annual production_CS            CS       National
# Primary Bauxite Production_Annual production_SL            SL       National
# Primary Bauxite Production_Annual production_ES            ES       National
# Primary Bauxite Production_Annual production_SR            SR       National
# Primary Bauxite Production_Annual production_TZ            TZ       National
# Primary Bauxite Production_Annual production_TR            TR       National
# Primary Bauxite Production_Annual production_SU            SU       National
# Primary Bauxite Production_Annual production_VE            VE       National
# Primary Bauxite Production_Annual production_VN            VN       National
# Primary Bauxite Production_Annual production_YU            YU       National
#
#                                                  Data Source         Unit  \
# ID
# Primary Bauxite Production_Annual production_AL         USGS  metric tons
# Primary Bauxite Production_Annual production_AU         USGS  metric tons
# Primary Bauxite Production_Annual production_BA         USGS  metric tons
# Primary Bauxite Production_Annual production_BR         USGS  metric tons
# Primary Bauxite Production_Annual production_CN         USGS  metric tons
# Primary Bauxite Production_Annual production_HR         USGS  metric tons
# Primary Bauxite Production_Annual production_DO         USGS  metric tons
# Primary Bauxite Production_Annual production_FJ         USGS  metric tons
# Primary Bauxite Production_Annual production_FR         USGS  metric tons
# Primary Bauxite Production_Annual production_GH         USGS  metric tons
# Primary Bauxite Production_Annual production_GR         USGS  metric tons
# Primary Bauxite Production_Annual production_GN         USGS  metric tons
# Primary Bauxite Production_Annual production_GY         USGS  metric tons
# Primary Bauxite Production_Annual production_HU         USGS  metric tons
# Primary Bauxite Production_Annual production_IN         USGS  metric tons
# Primary Bauxite Production_Annual production_ID         USGS  metric tons
# Primary Bauxite Production_Annual production_IR         USGS  metric tons
# Primary Bauxite Production_Annual production_IT         USGS  metric tons
# Primary Bauxite Production_Annual production_JM         USGS  metric tons
# Primary Bauxite Production_Annual production_KZ         USGS  metric tons
# Primary Bauxite Production_Annual production_MY         USGS  metric tons
# Primary Bauxite Production_Annual production_ME         USGS  metric tons
# Primary Bauxite Production_Annual production_MZ         USGS  metric tons
# Primary Bauxite Production_Annual production_PK         USGS  metric tons
# Primary Bauxite Production_Annual production_RO         USGS  metric tons
# Primary Bauxite Production_Annual production_RU         USGS  metric tons
# Primary Bauxite Production_Annual production_CS         USGS  metric tons
# Primary Bauxite Production_Annual production_SL         USGS  metric tons
# Primary Bauxite Production_Annual production_ES         USGS  metric tons
# Primary Bauxite Production_Annual production_SR         USGS  metric tons
# Primary Bauxite Production_Annual production_TZ         USGS  metric tons
# Primary Bauxite Production_Annual production_TR         USGS  metric tons
# Primary Bauxite Production_Annual production_SU         USGS  metric tons
# Primary Bauxite Production_Annual production_VE         USGS  metric tons
# Primary Bauxite Production_Annual production_VN         USGS  metric tons
# Primary Bauxite Production_Annual production_YU         USGS  metric tons
#
#                                                             Metric  \
# ID
# Primary Bauxite Production_Annual production_AL  Annual production
# Primary Bauxite Production_Annual production_AU  Annual production
# Primary Bauxite Production_Annual production_BA  Annual production
# Primary Bauxite Production_Annual production_BR  Annual production
# Primary Bauxite Production_Annual production_CN  Annual production
# Primary Bauxite Production_Annual production_HR  Annual production
# Primary Bauxite Production_Annual production_DO  Annual production
# Primary Bauxite Production_Annual production_FJ  Annual production
# Primary Bauxite Production_Annual production_FR  Annual production
# Primary Bauxite Production_Annual production_GH  Annual production
# Primary Bauxite Production_Annual production_GR  Annual production
# Primary Bauxite Production_Annual production_GN  Annual production
# Primary Bauxite Production_Annual production_GY  Annual production
# Primary Bauxite Production_Annual production_HU  Annual production
# Primary Bauxite Production_Annual production_IN  Annual production
# Primary Bauxite Production_Annual production_ID  Annual production
# Primary Bauxite Production_Annual production_IR  Annual production
# Primary Bauxite Production_Annual production_IT  Annual production
# Primary Bauxite Production_Annual production_JM  Annual production
# Primary Bauxite Production_Annual production_KZ  Annual production
# Primary Bauxite Production_Annual production_MY  Annual production
# Primary Bauxite Production_Annual production_ME  Annual production
# Primary Bauxite Production_Annual production_MZ  Annual production
# Primary Bauxite Production_Annual production_PK  Annual production
# Primary Bauxite Production_Annual production_RO  Annual production
# Primary Bauxite Production_Annual production_RU  Annual production
# Primary Bauxite Production_Annual production_CS  Annual production
# Primary Bauxite Production_Annual production_SL  Annual production
# Primary Bauxite Production_Annual production_ES  Annual production
# Primary Bauxite Production_Annual production_SR  Annual production
# Primary Bauxite Production_Annual production_TZ  Annual production
# Primary Bauxite Production_Annual production_TR  Annual production
# Primary Bauxite Production_Annual production_SU  Annual production
# Primary Bauxite Production_Annual production_VE  Annual production
# Primary Bauxite Production_Annual production_VN  Annual production
# Primary Bauxite Production_Annual production_YU  Annual production
#
#                                                             Technology Name
# ID
# Primary Bauxite Production_Annual production_AL  Primary Bauxite Production
# Primary Bauxite Production_Annual production_AU  Primary Bauxite Production
# Primary Bauxite Production_Annual production_BA  Primary Bauxite Production
# Primary Bauxite Production_Annual production_BR  Primary Bauxite Production
# Primary Bauxite Production_Annual production_CN  Primary Bauxite Production
# Primary Bauxite Production_Annual production_HR  Primary Bauxite Production
# Primary Bauxite Production_Annual production_DO  Primary Bauxite Production
# Primary Bauxite Production_Annual production_FJ  Primary Bauxite Production
# Primary Bauxite Production_Annual production_FR  Primary Bauxite Production
# Primary Bauxite Production_Annual production_GH  Primary Bauxite Production
# Primary Bauxite Production_Annual production_GR  Primary Bauxite Production
# Primary Bauxite Production_Annual production_GN  Primary Bauxite Production
# Primary Bauxite Production_Annual production_GY  Primary Bauxite Production
# Primary Bauxite Production_Annual production_HU  Primary Bauxite Production
# Primary Bauxite Production_Annual production_IN  Primary Bauxite Production
# Primary Bauxite Production_Annual production_ID  Primary Bauxite Production
# Primary Bauxite Production_Annual production_IR  Primary Bauxite Production
# Primary Bauxite Production_Annual production_IT  Primary Bauxite Production
# Primary Bauxite Production_Annual production_JM  Primary Bauxite Production
# Primary Bauxite Production_Annual production_KZ  Primary Bauxite Production
# Primary Bauxite Production_Annual production_MY  Primary Bauxite Production
# Primary Bauxite Production_Annual production_ME  Primary Bauxite Production
# Primary Bauxite Production_Annual production_MZ  Primary Bauxite Production
# Primary Bauxite Production_Annual production_PK  Primary Bauxite Production
# Primary Bauxite Production_Annual production_RO  Primary Bauxite Production
# Primary Bauxite Production_Annual production_RU  Primary Bauxite Production
# Primary Bauxite Production_Annual production_CS  Primary Bauxite Production
# Primary Bauxite Production_Annual production_SL  Primary Bauxite Production
# Primary Bauxite Production_Annual production_ES  Primary Bauxite Production
# Primary Bauxite Production_Annual production_SR  Primary Bauxite Production
# Primary Bauxite Production_Annual production_TZ  Primary Bauxite Production
# Primary Bauxite Production_Annual production_TR  Primary Bauxite Production
# Primary Bauxite Production_Annual production_SU  Primary Bauxite Production
# Primary Bauxite Production_Annual production_VE  Primary Bauxite Production
# Primary Bauxite Production_Annual production_VN  Primary Bauxite Production
# Primary Bauxite Production_Annual production_YU  Primary Bauxite Production
#
# [36 rows x 30 columns]

# %%
# Cadmium
# Omit East/West Germany since there's only one year of data for each
cadmium = read_usgs_896('Cadmium Refining', 'raw data/usgs/ds896-cadmium.xlsx')
cadmium = cadmium[(cadmium['Country Name']!='Germany: Eastern states') & (cadmium['Country Name']!='Germany: Western states')]
cadmium.to_csv('cleaned data/ds896_Cadmium Refining.csv')

cadmium
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#                                          1990    1991    1992    1993    1994  \
# ID
# Cadmium Refining_Annual production_DZ    65.0    78.0    56.0    18.0    59.0
# Cadmium Refining_Annual production_AR    55.0    49.0    37.0    25.0    27.0
# Cadmium Refining_Annual production_AU   638.0  1080.0  1000.0   951.0   910.0
# Cadmium Refining_Annual production_AT    44.0    19.0     NaN     NaN     NaN
# Cadmium Refining_Annual production_BE  1960.0  1810.0  1550.0  1570.0  1560.0
# Cadmium Refining_Annual production_BR   200.0   200.0   200.0   200.0   300.0
# Cadmium Refining_Annual production_BG   309.0   232.0   194.0   265.0   286.0
# Cadmium Refining_Annual production_CA  1470.0  1830.0  1960.0  1940.0  2170.0
# Cadmium Refining_Annual production_CN  1100.0  1200.0  1150.0  1160.0  1280.0
# Cadmium Refining_Annual production_CD   127.0    65.0    84.0    12.0     1.0
# Cadmium Refining_Annual production_FI   569.0   593.0   590.0   785.0   548.0
# Cadmium Refining_Annual production_FR   187.0   271.0   252.0   137.0     6.0
# Cadmium Refining_Annual production_DE     NaN  1050.0   961.0  1060.0  1150.0
# Cadmium Refining_Annual production_IN   277.0   271.0   313.0   255.0   216.0
# Cadmium Refining_Annual production_IT   691.0   658.0   742.0   517.0   475.0
# Cadmium Refining_Annual production_JP  2450.0  2890.0  2990.0  2830.0  2630.0
# Cadmium Refining_Annual production_KZ     NaN     NaN  1000.0   800.0  1100.0
# Cadmium Refining_Annual production_KP   100.0   100.0   100.0   100.0   100.0
# Cadmium Refining_Annual production_KR   750.0   750.0   750.0   400.0   400.0
# Cadmium Refining_Annual production_MK     NaN     NaN     NaN     NaN     NaN
# Cadmium Refining_Annual production_MX   882.0   688.0   602.0   797.0   646.0
# Cadmium Refining_Annual production_NA    69.0    67.0    33.0    13.0    19.0
# Cadmium Refining_Annual production_NL   590.0   549.0   594.0   526.0   307.0
# Cadmium Refining_Annual production_NO   286.0   227.0   247.0   213.0   288.0
# Cadmium Refining_Annual production_PE   265.0   138.0   399.0   472.0   510.0
# Cadmium Refining_Annual production_PL   373.0   364.0   132.0   149.0    61.0
# Cadmium Refining_Annual production_RO    40.0    10.0    10.0    10.0     4.0
# Cadmium Refining_Annual production_RU     NaN     NaN   800.0   700.0   600.0
# Cadmium Refining_Annual production_CS     NaN     NaN     8.0     6.0     3.0
# Cadmium Refining_Annual production_ZA    57.0   103.0    60.0    70.0     NaN
# Cadmium Refining_Annual production_ES   355.0   344.0   361.0   365.0   387.0
# Cadmium Refining_Annual production_TH     NaN   373.0   635.0   449.0   643.0
# Cadmium Refining_Annual production_TR    46.0    22.0    23.0    31.0    22.0
# Cadmium Refining_Annual production_UA     NaN     NaN     5.0     7.0    10.0
# Cadmium Refining_Annual production_SU  2800.0  2500.0     NaN     NaN     NaN
# Cadmium Refining_Annual production_GB   438.0   449.0   383.0   458.0   469.0
# Cadmium Refining_Annual production_YU   362.0   250.0     NaN     NaN     NaN
#
#                                          1995    1996    1997    1998    1999  \
# ID
# Cadmium Refining_Annual production_DZ    75.0    75.0    75.0    70.0    10.0
# Cadmium Refining_Annual production_AR    43.0    40.0    45.0    34.0     NaN
# Cadmium Refining_Annual production_AU   838.0   639.0   632.0   585.0   462.0
# Cadmium Refining_Annual production_AT     NaN     NaN     NaN     NaN     NaN
# Cadmium Refining_Annual production_BE  1710.0  1580.0  1420.0  1320.0  1240.0
# Cadmium Refining_Annual production_BR   300.0   300.0   300.0   300.0   300.0
# Cadmium Refining_Annual production_BG   250.0   250.0   280.0   250.0   150.0
# Cadmium Refining_Annual production_CA  2350.0  2540.0  2260.0  2090.0  1910.0
# Cadmium Refining_Annual production_CN  1450.0  1570.0  1980.0  2130.0  2150.0
# Cadmium Refining_Annual production_CD     NaN     NaN     NaN     NaN     NaN
# Cadmium Refining_Annual production_FI   539.0   648.0   650.0   520.0   700.0
# Cadmium Refining_Annual production_FR     NaN    92.0   309.0   177.0   195.0
# Cadmium Refining_Annual production_DE  1150.0  1150.0  1150.0  1020.0  1150.0
# Cadmium Refining_Annual production_IN   254.0   271.0   298.0   304.0   269.0
# Cadmium Refining_Annual production_IT   308.0   296.0   287.0   328.0   360.0
# Cadmium Refining_Annual production_JP  2650.0  2340.0  2470.0  2340.0  2570.0
# Cadmium Refining_Annual production_KZ   794.0   800.0   745.0  1620.0  1250.0
# Cadmium Refining_Annual production_KP   100.0   100.0   100.0   100.0   100.0
# Cadmium Refining_Annual production_KR  1670.0   501.0   570.0  1180.0  1790.0
# Cadmium Refining_Annual production_MK     NaN     NaN     NaN     NaN     NaN
# Cadmium Refining_Annual production_MX   689.0   784.0  1220.0  1220.0  1280.0
# Cadmium Refining_Annual production_NA    15.0    14.0     2.0     NaN     NaN
# Cadmium Refining_Annual production_NL   704.0   603.0   718.0   739.0   731.0
# Cadmium Refining_Annual production_NO   315.0   274.0   290.0   270.0   211.0
# Cadmium Refining_Annual production_PE   560.0   405.0   474.0   535.0   466.0
# Cadmium Refining_Annual production_PL     NaN     NaN    22.0     NaN     NaN
# Cadmium Refining_Annual production_RO     5.0     5.0     5.0     NaN     NaN
# Cadmium Refining_Annual production_RU   725.0   730.0   790.0   800.0   900.0
# Cadmium Refining_Annual production_CS    11.0    79.0    80.0    17.0     NaN
# Cadmium Refining_Annual production_ZA     NaN     NaN     NaN     NaN     NaN
# Cadmium Refining_Annual production_ES   397.0   307.0   301.0   196.0     NaN
# Cadmium Refining_Annual production_TH   365.0   385.0   238.0   238.0     NaN
# Cadmium Refining_Annual production_TR    23.0    42.0    89.0    69.0    64.0
# Cadmium Refining_Annual production_UA    15.0    25.0    25.0    25.0    25.0
# Cadmium Refining_Annual production_SU     NaN     NaN     NaN     NaN     NaN
# Cadmium Refining_Annual production_GB   549.0   541.0   455.0   440.0   547.0
# Cadmium Refining_Annual production_YU     NaN     NaN     NaN     NaN     NaN
#
#                                        ...    2010    2011    2012  \
# ID                                     ...
# Cadmium Refining_Annual production_DZ  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_AR  ...    32.0    31.0    30.0
# Cadmium Refining_Annual production_AU  ...   350.0   390.0   380.0
# Cadmium Refining_Annual production_AT  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_BE  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_BR  ...   200.0   200.0   200.0
# Cadmium Refining_Annual production_BG  ...   420.0   420.0   420.0
# Cadmium Refining_Annual production_CA  ...  1360.0  1200.0  1100.0
# Cadmium Refining_Annual production_CN  ...  7360.0  7000.0  7300.0
# Cadmium Refining_Annual production_CD  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_FI  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_FR  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_DE  ...   290.0   300.0   300.0
# Cadmium Refining_Annual production_IN  ...   632.0   616.0   620.0
# Cadmium Refining_Annual production_IT  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_JP  ...  2050.0  1760.0  1800.0
# Cadmium Refining_Annual production_KZ  ...  1400.0  1300.0  1300.0
# Cadmium Refining_Annual production_KP  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_KR  ...  4170.0  3010.0  3000.0
# Cadmium Refining_Annual production_MK  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_MX  ...  1460.0  1490.0  1620.0
# Cadmium Refining_Annual production_NA  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_NL  ...   560.0   570.0   560.0
# Cadmium Refining_Annual production_NO  ...   300.0   309.0   310.0
# Cadmium Refining_Annual production_PE  ...   357.0   572.0   684.0
# Cadmium Refining_Annual production_PL  ...   451.0   526.0   530.0
# Cadmium Refining_Annual production_RO  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_RU  ...   700.0   700.0   700.0
# Cadmium Refining_Annual production_CS  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_ZA  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_ES  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_TH  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_TR  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_UA  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_SU  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_GB  ...     NaN     NaN     NaN
# Cadmium Refining_Annual production_YU  ...     NaN     NaN     NaN
#
#                                                 Country Name  Country Code  \
# ID
# Cadmium Refining_Annual production_DZ                Algeria            DZ
# Cadmium Refining_Annual production_AR              Argentina            AR
# Cadmium Refining_Annual production_AU              Australia            AU
# Cadmium Refining_Annual production_AT                Austria            AT
# Cadmium Refining_Annual production_BE                Belgium            BE
# Cadmium Refining_Annual production_BR                 Brazil            BR
# Cadmium Refining_Annual production_BG               Bulgaria            BG
# Cadmium Refining_Annual production_CA                 Canada            CA
# Cadmium Refining_Annual production_CN                  China            CN
# Cadmium Refining_Annual production_CD       Congo (Kinshasa)            CD
# Cadmium Refining_Annual production_FI                Finland            FI
# Cadmium Refining_Annual production_FR                 France            FR
# Cadmium Refining_Annual production_DE                Germany            DE
# Cadmium Refining_Annual production_IN                  India            IN
# Cadmium Refining_Annual production_IT                  Italy            IT
# Cadmium Refining_Annual production_JP                  Japan            JP
# Cadmium Refining_Annual production_KZ             Kazakhstan            KZ
# Cadmium Refining_Annual production_KP           Korea, North            KP
# Cadmium Refining_Annual production_KR     Korea, Republic of            KR
# Cadmium Refining_Annual production_MK              Macedonia            MK
# Cadmium Refining_Annual production_MX                 Mexico            MX
# Cadmium Refining_Annual production_NA                Namibia            NA
# Cadmium Refining_Annual production_NL            Netherlands            NL
# Cadmium Refining_Annual production_NO                 Norway            NO
# Cadmium Refining_Annual production_PE                   Peru            PE
# Cadmium Refining_Annual production_PL                 Poland            PL
# Cadmium Refining_Annual production_RO                Romania            RO
# Cadmium Refining_Annual production_RU                 Russia            RU
# Cadmium Refining_Annual production_CS  Serbia and Montenegro            CS
# Cadmium Refining_Annual production_ZA           South Africa            ZA
# Cadmium Refining_Annual production_ES                  Spain            ES
# Cadmium Refining_Annual production_TH               Thailand            TH
# Cadmium Refining_Annual production_TR                 Turkey            TR
# Cadmium Refining_Annual production_UA                Ukraine            UA
# Cadmium Refining_Annual production_SU               U.S.S.R.            SU
# Cadmium Refining_Annual production_GB         United Kingdom            GB
# Cadmium Refining_Annual production_YU             Yugoslavia            YU
#
#                                        Spatial Scale  Data Source  \
# ID
# Cadmium Refining_Annual production_DZ       National         USGS
# Cadmium Refining_Annual production_AR       National         USGS
# Cadmium Refining_Annual production_AU       National         USGS
# Cadmium Refining_Annual production_AT       National         USGS
# Cadmium Refining_Annual production_BE       National         USGS
# Cadmium Refining_Annual production_BR       National         USGS
# Cadmium Refining_Annual production_BG       National         USGS
# Cadmium Refining_Annual production_CA       National         USGS
# Cadmium Refining_Annual production_CN       National         USGS
# Cadmium Refining_Annual production_CD       National         USGS
# Cadmium Refining_Annual production_FI       National         USGS
# Cadmium Refining_Annual production_FR       National         USGS
# Cadmium Refining_Annual production_DE       National         USGS
# Cadmium Refining_Annual production_IN       National         USGS
# Cadmium Refining_Annual production_IT       National         USGS
# Cadmium Refining_Annual production_JP       National         USGS
# Cadmium Refining_Annual production_KZ       National         USGS
# Cadmium Refining_Annual production_KP       National         USGS
# Cadmium Refining_Annual production_KR       National         USGS
# Cadmium Refining_Annual production_MK       National         USGS
# Cadmium Refining_Annual production_MX       National         USGS
# Cadmium Refining_Annual production_NA       National         USGS
# Cadmium Refining_Annual production_NL       National         USGS
# Cadmium Refining_Annual production_NO       National         USGS
# Cadmium Refining_Annual production_PE       National         USGS
# Cadmium Refining_Annual production_PL       National         USGS
# Cadmium Refining_Annual production_RO       National         USGS
# Cadmium Refining_Annual production_RU       National         USGS
# Cadmium Refining_Annual production_CS       National         USGS
# Cadmium Refining_Annual production_ZA       National         USGS
# Cadmium Refining_Annual production_ES       National         USGS
# Cadmium Refining_Annual production_TH       National         USGS
# Cadmium Refining_Annual production_TR       National         USGS
# Cadmium Refining_Annual production_UA       National         USGS
# Cadmium Refining_Annual production_SU       National         USGS
# Cadmium Refining_Annual production_GB       National         USGS
# Cadmium Refining_Annual production_YU       National         USGS
#
#                                               Unit             Metric  \
# ID
# Cadmium Refining_Annual production_DZ  metric tons  Annual production
# Cadmium Refining_Annual production_AR  metric tons  Annual production
# Cadmium Refining_Annual production_AU  metric tons  Annual production
# Cadmium Refining_Annual production_AT  metric tons  Annual production
# Cadmium Refining_Annual production_BE  metric tons  Annual production
# Cadmium Refining_Annual production_BR  metric tons  Annual production
# Cadmium Refining_Annual production_BG  metric tons  Annual production
# Cadmium Refining_Annual production_CA  metric tons  Annual production
# Cadmium Refining_Annual production_CN  metric tons  Annual production
# Cadmium Refining_Annual production_CD  metric tons  Annual production
# Cadmium Refining_Annual production_FI  metric tons  Annual production
# Cadmium Refining_Annual production_FR  metric tons  Annual production
# Cadmium Refining_Annual production_DE  metric tons  Annual production
# Cadmium Refining_Annual production_IN  metric tons  Annual production
# Cadmium Refining_Annual production_IT  metric tons  Annual production
# Cadmium Refining_Annual production_JP  metric tons  Annual production
# Cadmium Refining_Annual production_KZ  metric tons  Annual production
# Cadmium Refining_Annual production_KP  metric tons  Annual production
# Cadmium Refining_Annual production_KR  metric tons  Annual production
# Cadmium Refining_Annual production_MK  metric tons  Annual production
# Cadmium Refining_Annual production_MX  metric tons  Annual production
# Cadmium Refining_Annual production_NA  metric tons  Annual production
# Cadmium Refining_Annual production_NL  metric tons  Annual production
# Cadmium Refining_Annual production_NO  metric tons  Annual production
# Cadmium Refining_Annual production_PE  metric tons  Annual production
# Cadmium Refining_Annual production_PL  metric tons  Annual production
# Cadmium Refining_Annual production_RO  metric tons  Annual production
# Cadmium Refining_Annual production_RU  metric tons  Annual production
# Cadmium Refining_Annual production_CS  metric tons  Annual production
# Cadmium Refining_Annual production_ZA  metric tons  Annual production
# Cadmium Refining_Annual production_ES  metric tons  Annual production
# Cadmium Refining_Annual production_TH  metric tons  Annual production
# Cadmium Refining_Annual production_TR  metric tons  Annual production
# Cadmium Refining_Annual production_UA  metric tons  Annual production
# Cadmium Refining_Annual production_SU  metric tons  Annual production
# Cadmium Refining_Annual production_GB  metric tons  Annual production
# Cadmium Refining_Annual production_YU  metric tons  Annual production
#
#                                         Technology Name
# ID
# Cadmium Refining_Annual production_DZ  Cadmium Refining
# Cadmium Refining_Annual production_AR  Cadmium Refining
# Cadmium Refining_Annual production_AU  Cadmium Refining
# Cadmium Refining_Annual production_AT  Cadmium Refining
# Cadmium Refining_Annual production_BE  Cadmium Refining
# Cadmium Refining_Annual production_BR  Cadmium Refining
# Cadmium Refining_Annual production_BG  Cadmium Refining
# Cadmium Refining_Annual production_CA  Cadmium Refining
# Cadmium Refining_Annual production_CN  Cadmium Refining
# Cadmium Refining_Annual production_CD  Cadmium Refining
# Cadmium Refining_Annual production_FI  Cadmium Refining
# Cadmium Refining_Annual production_FR  Cadmium Refining
# Cadmium Refining_Annual production_DE  Cadmium Refining
# Cadmium Refining_Annual production_IN  Cadmium Refining
# Cadmium Refining_Annual production_IT  Cadmium Refining
# Cadmium Refining_Annual production_JP  Cadmium Refining
# Cadmium Refining_Annual production_KZ  Cadmium Refining
# Cadmium Refining_Annual production_KP  Cadmium Refining
# Cadmium Refining_Annual production_KR  Cadmium Refining
# Cadmium Refining_Annual production_MK  Cadmium Refining
# Cadmium Refining_Annual production_MX  Cadmium Refining
# Cadmium Refining_Annual production_NA  Cadmium Refining
# Cadmium Refining_Annual production_NL  Cadmium Refining
# Cadmium Refining_Annual production_NO  Cadmium Refining
# Cadmium Refining_Annual production_PE  Cadmium Refining
# Cadmium Refining_Annual production_PL  Cadmium Refining
# Cadmium Refining_Annual production_RO  Cadmium Refining
# Cadmium Refining_Annual production_RU  Cadmium Refining
# Cadmium Refining_Annual production_CS  Cadmium Refining
# Cadmium Refining_Annual production_ZA  Cadmium Refining
# Cadmium Refining_Annual production_ES  Cadmium Refining
# Cadmium Refining_Annual production_TH  Cadmium Refining
# Cadmium Refining_Annual production_TR  Cadmium Refining
# Cadmium Refining_Annual production_UA  Cadmium Refining
# Cadmium Refining_Annual production_SU  Cadmium Refining
# Cadmium Refining_Annual production_GB  Cadmium Refining
# Cadmium Refining_Annual production_YU  Cadmium Refining
#
# [37 rows x 30 columns]

# %%
# Copper mining and refining
copper_mining = read_usgs_896('Copper|Mining', 'raw data/usgs/ds896-copper.xlsx', 'Mine')
copper_mining = copper_mining[copper_mining['    Mine production']=='Mine: Total']
copper_mining.drop(columns='    Mine production', inplace=True)
copper_mining.to_csv('cleaned data/ds896_Copper|Mining.csv')

copper_refining = read_usgs_896('Copper|Refining', 'raw data/usgs/ds896-copper.xlsx', 'Refinery')
copper_refining = copper_refining[copper_refining['Refinery production']=='Refinery: Total']
copper_refining.drop(columns='Refinery production', inplace=True)
copper_refining.to_csv('cleaned data/ds896_Copper|Refining.csv')

copper_refining
# Out:
#                                                1990        1991        1992  \
# ID
# Copper|Refining_Annual production_AL        10900.0      4400.0      1500.0
# Copper|Refining_Annual production_AR        10900.0     12000.0     15000.0
# Copper|Refining_Annual production_AU       274000.0    279000.0    303000.0
# Copper|Refining_Annual production_AT        49700.0     52800.0     54700.0
# Copper|Refining_Annual production_BE       332000.0    298000.0    367000.0
# Copper|Refining_Annual production_BR       202000.0    141000.0    158000.0
# Copper|Refining_Annual production_BG        24300.0     12800.0     18000.0
# Copper|Refining_Annual production_MM            NaN         NaN         NaN
# Copper|Refining_Annual production_CA       516000.0    538000.0    539000.0
# Copper|Refining_Annual production_CL      1190000.0   1230000.0   1240000.0
# Copper|Refining_Annual production_CN       560000.0    560000.0    659000.0
# Copper|Refining_Annual production_CD       141000.0    104000.0     47500.0
# Copper|Refining_Annual production_CY            NaN         NaN         NaN
# Copper|Refining_Annual production_CZ            NaN         NaN         NaN
# Copper|Refining_Annual production_CSK       25400.0     25900.0     28600.0
# Copper|Refining_Annual production_EG         3600.0      3600.0      4000.0
# Copper|Refining_Annual production_FI        65100.0     64500.0     70900.0
# Copper|Refining_Annual production_FR        44000.0     43600.0     42800.0
# Copper|Refining_Annual production_DE       533000.0    522000.0    582000.0
# Copper|Refining_Annual production_HU        12800.0     12000.0     12000.0
# Copper|Refining_Annual production_IN        41600.0     47200.0     46800.0
# Copper|Refining_Annual production_ID            NaN         NaN         NaN
# Copper|Refining_Annual production_IR        47800.0     79700.0    102000.0
# Copper|Refining_Annual production_IT        83000.0     83400.0     76000.0
# Copper|Refining_Annual production_JP      1010000.0   1080000.0   1160000.0
# Copper|Refining_Annual production_KZ            NaN         NaN    320000.0
# Copper|Refining_Annual production_KP        35000.0     24000.0     25000.0
# Copper|Refining_Annual production_KR       186000.0    203000.0    211000.0
# Copper|Refining_Annual production_LA            NaN         NaN         NaN
# Copper|Refining_Annual production_MX       153000.0    159000.0    191000.0
# Copper|Refining_Annual production_MN            NaN         NaN         NaN
# Copper|Refining_Annual production_NO        36500.0     38400.0     39300.0
# Copper|Refining_Annual production_OM        12000.0     11400.0     16200.0
# Copper|Refining_Annual production_PE       228000.0    286000.0    253000.0
# Copper|Refining_Annual production_PH       126000.0    115000.0    146000.0
# Copper|Refining_Annual production_PL       346000.0    429000.0    454000.0
# Copper|Refining_Annual production_PT         1000.0       300.0         NaN
# Copper|Refining_Annual production_RO        44300.0     33800.0     24100.0
# Copper|Refining_Annual production_RU            NaN         NaN    575000.0
# Copper|Refining_Annual production_RS            NaN         NaN         NaN
# Copper|Refining_Annual production_CS            NaN         NaN    115000.0
# Copper|Refining_Annual production_SK            NaN         NaN         NaN
# Copper|Refining_Annual production_ZA       133000.0    127000.0    120000.0
# Copper|Refining_Annual production_ES       166000.0    190000.0    179000.0
# Copper|Refining_Annual production_SE        97300.0     96600.0    102000.0
# Copper|Refining_Annual production_TW        22100.0     12000.0     12000.0
# Copper|Refining_Annual production_TH            NaN         NaN         NaN
# Copper|Refining_Annual production_TR        84200.0     80800.0    104000.0
# Copper|Refining_Annual production_UA            NaN         NaN         NaN
# Copper|Refining_Annual production_SU      1230000.0   1070000.0         NaN
# Copper|Refining_Annual production_GB       122000.0     70100.0     42100.0
# Copper|Refining_Annual production_US      2020000.0   2000000.0   2140000.0
# Copper|Refining_Annual production_UZ            NaN         NaN     80000.0
# Copper|Refining_Annual production_VN            NaN         NaN         NaN
# Copper|Refining_Annual production_YU       151000.0    134000.0         NaN
# Copper|Refining_Annual production_ZM       438000.0    402000.0    472000.0
# Copper|Refining_Annual production_ZW        22500.0     22000.0     17900.0
# Copper|Refining_Annual production_World  10800000.0  10700000.0  11200000.0
#
#                                                1993        1994        1995  \
# ID
# Copper|Refining_Annual production_AL         1500.0      1000.0      1000.0
# Copper|Refining_Annual production_AR        15000.0     16000.0     16000.0
# Copper|Refining_Annual production_AU       309000.0    336000.0    266000.0
# Copper|Refining_Annual production_AT        52700.0     52500.0     53500.0
# Copper|Refining_Annual production_BE       379000.0    375000.0    376000.0
# Copper|Refining_Annual production_BR       161000.0    170000.0    165000.0
# Copper|Refining_Annual production_BG        26300.0     26500.0     29100.0
# Copper|Refining_Annual production_MM            NaN         NaN         NaN
# Copper|Refining_Annual production_CA       562000.0    550000.0    573000.0
# Copper|Refining_Annual production_CL      1270000.0   1280000.0   1490000.0
# Copper|Refining_Annual production_CN       730000.0    736000.0   1080000.0
# Copper|Refining_Annual production_CD        34100.0     29000.0     33000.0
# Copper|Refining_Annual production_CY            NaN         NaN         NaN
# Copper|Refining_Annual production_CZ          500.0         NaN         NaN
# Copper|Refining_Annual production_CSK           NaN         NaN         NaN
# Copper|Refining_Annual production_EG         4600.0      4300.0      4400.0
# Copper|Refining_Annual production_FI        73700.0     69200.0     73700.0
# Copper|Refining_Annual production_FR        44400.0     41800.0     42500.0
# Copper|Refining_Annual production_DE       632000.0    592000.0    616000.0
# Copper|Refining_Annual production_HU        11000.0     11000.0     11000.0
# Copper|Refining_Annual production_IN        36800.0     49000.0     39600.0
# Copper|Refining_Annual production_ID            NaN         NaN         NaN
# Copper|Refining_Annual production_IR        84900.0     90200.0     90400.0
# Copper|Refining_Annual production_IT        90300.0     84000.0     98000.0
# Copper|Refining_Annual production_JP      1190000.0   1120000.0   1190000.0
# Copper|Refining_Annual production_KZ       317000.0    280000.0    256000.0
# Copper|Refining_Annual production_KP        27000.0     27000.0     27000.0
# Copper|Refining_Annual production_KR       220000.0    246000.0    237000.0
# Copper|Refining_Annual production_LA            NaN         NaN         NaN
# Copper|Refining_Annual production_MX       171000.0    197000.0    212000.0
# Copper|Refining_Annual production_MN            NaN         NaN         NaN
# Copper|Refining_Annual production_NO        37200.0     39400.0     34300.0
# Copper|Refining_Annual production_OM        20500.0     24200.0     21300.0
# Copper|Refining_Annual production_PE       259000.0    265000.0    295000.0
# Copper|Refining_Annual production_PH       166000.0    155000.0    158000.0
# Copper|Refining_Annual production_PL       461000.0    425000.0    435000.0
# Copper|Refining_Annual production_PT            NaN         NaN         NaN
# Copper|Refining_Annual production_RO        25000.0     26700.0     27000.0
# Copper|Refining_Annual production_RU       526000.0    502000.0    560000.0
# Copper|Refining_Annual production_RS            NaN         NaN         NaN
# Copper|Refining_Annual production_CS        51300.0     72100.0     78500.0
# Copper|Refining_Annual production_SK        28000.0     25000.0     21500.0
# Copper|Refining_Annual production_ZA       128000.0    130000.0    124000.0
# Copper|Refining_Annual production_ES       179000.0    188000.0    164000.0
# Copper|Refining_Annual production_SE        98800.0    103000.0    105000.0
# Copper|Refining_Annual production_TW        10000.0     10000.0      8000.0
# Copper|Refining_Annual production_TH            NaN         NaN         NaN
# Copper|Refining_Annual production_TR        92400.0     82700.0    100000.0
# Copper|Refining_Annual production_UA            NaN         NaN         NaN
# Copper|Refining_Annual production_SU            NaN         NaN         NaN
# Copper|Refining_Annual production_GB        46600.0     46700.0     78500.0
# Copper|Refining_Annual production_US      2250000.0   2230000.0   2280000.0
# Copper|Refining_Annual production_UZ        75000.0     90000.0     95000.0
# Copper|Refining_Annual production_VN            NaN         NaN         NaN
# Copper|Refining_Annual production_YU            NaN         NaN         NaN
# Copper|Refining_Annual production_ZM       412000.0    352000.0    328000.0
# Copper|Refining_Annual production_ZW        16400.0     15400.0     13100.0
# Copper|Refining_Annual production_World  11300000.0  11200000.0  11900000.0
#
#                                                1996        1997        1998  \
# ID
# Copper|Refining_Annual production_AL         1540.0         NaN      1150.0
# Copper|Refining_Annual production_AR        16000.0     16000.0     16000.0
# Copper|Refining_Annual production_AU       311000.0    270000.0    285000.0
# Copper|Refining_Annual production_AT        58000.0     67000.0     78000.0
# Copper|Refining_Annual production_BE       354000.0    373000.0    368000.0
# Copper|Refining_Annual production_BR       172000.0    177000.0    167000.0
# Copper|Refining_Annual production_BG        22300.0     34500.0     36400.0
# Copper|Refining_Annual production_MM            NaN         NaN      6700.0
# Copper|Refining_Annual production_CA       559000.0    560000.0    564000.0
# Copper|Refining_Annual production_CL      1750000.0   2120000.0   2330000.0
# Copper|Refining_Annual production_CN      1120000.0   1180000.0   1210000.0
# Copper|Refining_Annual production_CD        40100.0     37700.0     38200.0
# Copper|Refining_Annual production_CY         1500.0      4440.0      4940.0
# Copper|Refining_Annual production_CZ            NaN         NaN         NaN
# Copper|Refining_Annual production_CSK           NaN         NaN         NaN
# Copper|Refining_Annual production_EG         4600.0      5000.0      6000.0
# Copper|Refining_Annual production_FI       111000.0    116000.0    123000.0
# Copper|Refining_Annual production_FR        39100.0     35600.0     22400.0
# Copper|Refining_Annual production_DE       671000.0    674000.0    696000.0
# Copper|Refining_Annual production_HU        11000.0     12000.0     12000.0
# Copper|Refining_Annual production_IN        39300.0     36200.0    107000.0
# Copper|Refining_Annual production_ID            NaN         NaN         NaN
# Copper|Refining_Annual production_IR       101000.0    113000.0    139000.0
# Copper|Refining_Annual production_IT        85800.0     85700.0     29100.0
# Copper|Refining_Annual production_JP      1250000.0   1280000.0   1280000.0
# Copper|Refining_Annual production_KZ       267000.0    301000.0    325000.0
# Copper|Refining_Annual production_KP        28000.0     18000.0     16000.0
# Copper|Refining_Annual production_KR       248000.0    265000.0    373000.0
# Copper|Refining_Annual production_LA            NaN         NaN         NaN
# Copper|Refining_Annual production_MX       242000.0    297000.0    447000.0
# Copper|Refining_Annual production_MN            NaN      2750.0      2320.0
# Copper|Refining_Annual production_NO        28500.0     32600.0     31700.0
# Copper|Refining_Annual production_OM        24200.0     23600.0     22700.0
# Copper|Refining_Annual production_PE       338000.0    384000.0    411000.0
# Copper|Refining_Annual production_PH       156000.0    147000.0    152000.0
# Copper|Refining_Annual production_PL       425000.0    441000.0    447000.0
# Copper|Refining_Annual production_PT            NaN         NaN         NaN
# Copper|Refining_Annual production_RO        34300.0     26900.0     23000.0
# Copper|Refining_Annual production_RU       600000.0    600000.0    620000.0
# Copper|Refining_Annual production_RS            NaN         NaN         NaN
# Copper|Refining_Annual production_CS       104000.0    114000.0     94300.0
# Copper|Refining_Annual production_SK        28000.0     31400.0     24100.0
# Copper|Refining_Annual production_ZA       123000.0    130000.0    126000.0
# Copper|Refining_Annual production_ES       264000.0    292000.0    304000.0
# Copper|Refining_Annual production_SE       125000.0    128000.0    125000.0
# Copper|Refining_Annual production_TW         6000.0      4000.0      4000.0
# Copper|Refining_Annual production_TH            NaN         NaN         NaN
# Copper|Refining_Annual production_TR       101000.0    111000.0     91800.0
# Copper|Refining_Annual production_UA            NaN         NaN         NaN
# Copper|Refining_Annual production_SU            NaN         NaN         NaN
# Copper|Refining_Annual production_GB        56600.0     60400.0     52000.0
# Copper|Refining_Annual production_US      2350000.0   2470000.0   2490000.0
# Copper|Refining_Annual production_UZ       100000.0    110000.0     94900.0
# Copper|Refining_Annual production_VN            NaN         NaN         NaN
# Copper|Refining_Annual production_YU            NaN         NaN         NaN
# Copper|Refining_Annual production_ZM       334000.0    332000.0    330000.0
# Copper|Refining_Annual production_ZW        20100.0      7890.0      5340.0
# Copper|Refining_Annual production_World  12700000.0  13500000.0  14100000.0
#
#                                                1999  ...        2009  \
# ID                                                   ...
# Copper|Refining_Annual production_AL          342.0  ...         NaN
# Copper|Refining_Annual production_AR        16000.0  ...     16000.0
# Copper|Refining_Annual production_AU       419000.0  ...    446000.0
# Copper|Refining_Annual production_AT        77000.0  ...     96200.0
# Copper|Refining_Annual production_BE       388000.0  ...    374000.0
# Copper|Refining_Annual production_BR       193000.0  ...    231000.0
# Copper|Refining_Annual production_BG        21000.0  ...    197000.0
# Copper|Refining_Annual production_MM        26700.0  ...      3500.0
# Copper|Refining_Annual production_CA       549000.0  ...    336000.0
# Copper|Refining_Annual production_CL      2670000.0  ...   3280000.0
# Copper|Refining_Annual production_CN      1170000.0  ...   4170000.0
# Copper|Refining_Annual production_CD        31200.0  ...    167000.0
# Copper|Refining_Annual production_CY         5000.0  ...      2380.0
# Copper|Refining_Annual production_CZ            NaN  ...         NaN
# Copper|Refining_Annual production_CSK           NaN  ...         NaN
# Copper|Refining_Annual production_EG         6000.0  ...      3000.0
# Copper|Refining_Annual production_FI       115000.0  ...    106000.0
# Copper|Refining_Annual production_FR         1800.0  ...         NaN
# Copper|Refining_Annual production_DE       696000.0  ...    669000.0
# Copper|Refining_Annual production_HU        12000.0  ...         NaN
# Copper|Refining_Annual production_IN       208000.0  ...    715000.0
# Copper|Refining_Annual production_ID        90800.0  ...    289000.0
# Copper|Refining_Annual production_IR       142000.0  ...    210000.0
# Copper|Refining_Annual production_IT        28500.0  ...      6500.0
# Copper|Refining_Annual production_JP      1340000.0  ...   1440000.0
# Copper|Refining_Annual production_KZ       362000.0  ...    313000.0
# Copper|Refining_Annual production_KP        16000.0  ...     15000.0
# Copper|Refining_Annual production_KR       450000.0  ...    532000.0
# Copper|Refining_Annual production_LA            NaN  ...     67600.0
# Copper|Refining_Annual production_MX       426000.0  ...    261000.0
# Copper|Refining_Annual production_MN         1550.0  ...      2470.0
# Copper|Refining_Annual production_NO        33300.0  ...     30000.0
# Copper|Refining_Annual production_OM        17200.0  ...     12000.0
# Copper|Refining_Annual production_PE       433000.0  ...    423000.0
# Copper|Refining_Annual production_PH       148000.0  ...    178000.0
# Copper|Refining_Annual production_PL       471000.0  ...    502000.0
# Copper|Refining_Annual production_PT            NaN  ...         NaN
# Copper|Refining_Annual production_RO        29000.0  ...      4000.0
# Copper|Refining_Annual production_RU       760000.0  ...    862000.0
# Copper|Refining_Annual production_RS            NaN  ...     28000.0
# Copper|Refining_Annual production_CS        49900.0  ...         NaN
# Copper|Refining_Annual production_SK        21000.0  ...         NaN
# Copper|Refining_Annual production_ZA       116000.0  ...     89500.0
# Copper|Refining_Annual production_ES       316000.0  ...    329000.0
# Copper|Refining_Annual production_SE       115000.0  ...    206000.0
# Copper|Refining_Annual production_TW         4000.0  ...      4500.0
# Copper|Refining_Annual production_TH            NaN  ...       490.0
# Copper|Refining_Annual production_TR        60500.0  ...     34000.0
# Copper|Refining_Annual production_UA            NaN  ...     20000.0
# Copper|Refining_Annual production_SU            NaN  ...         NaN
# Copper|Refining_Annual production_GB        50000.0  ...         NaN
# Copper|Refining_Annual production_US      2120000.0  ...   1160000.0
# Copper|Refining_Annual production_UZ        70000.0  ...     80000.0
# Copper|Refining_Annual production_VN            NaN  ...      6000.0
# Copper|Refining_Annual production_YU            NaN  ...         NaN
# Copper|Refining_Annual production_ZM       319000.0  ...    414000.0
# Copper|Refining_Annual production_ZW         8020.0  ...      3000.0
# Copper|Refining_Annual production_World  14600000.0  ...  18300000.0
#
#                                                2010        2011  \
# ID
# Copper|Refining_Annual production_AL            NaN         NaN
# Copper|Refining_Annual production_AR        16000.0     16000.0
# Copper|Refining_Annual production_AU       424000.0    477000.0
# Copper|Refining_Annual production_AT       114000.0    113000.0
# Copper|Refining_Annual production_BE       381000.0    394000.0
# Copper|Refining_Annual production_BR       233000.0    228000.0
# Copper|Refining_Annual production_BG       215000.0    227000.0
# Copper|Refining_Annual production_MM        12000.0     12000.0
# Copper|Refining_Annual production_CA       319000.0    274000.0
# Copper|Refining_Annual production_CL      3240000.0   3090000.0
# Copper|Refining_Annual production_CN      4670000.0   5270000.0
# Copper|Refining_Annual production_CD       262000.0    355000.0
# Copper|Refining_Annual production_CY         2400.0      2400.0
# Copper|Refining_Annual production_CZ            NaN         NaN
# Copper|Refining_Annual production_CSK           NaN         NaN
# Copper|Refining_Annual production_EG         3000.0      3000.0
# Copper|Refining_Annual production_FI       113000.0    117000.0
# Copper|Refining_Annual production_FR            NaN         NaN
# Copper|Refining_Annual production_DE       704000.0    709000.0
# Copper|Refining_Annual production_HU            NaN         NaN
# Copper|Refining_Annual production_IN       664000.0    673000.0
# Copper|Refining_Annual production_ID       278000.0    257000.0
# Copper|Refining_Annual production_IR       220000.0    227000.0
# Copper|Refining_Annual production_IT         2000.0      2000.0
# Copper|Refining_Annual production_JP      1550000.0   1330000.0
# Copper|Refining_Annual production_KZ       323000.0    338000.0
# Copper|Refining_Annual production_KP        15000.0     15000.0
# Copper|Refining_Annual production_KR       565000.0    595000.0
# Copper|Refining_Annual production_LA        64200.0     78900.0
# Copper|Refining_Annual production_MX       247000.0    400000.0
# Copper|Refining_Annual production_MN         2750.0      2390.0
# Copper|Refining_Annual production_NO        40000.0     40000.0
# Copper|Refining_Annual production_OM        14000.0     14000.0
# Copper|Refining_Annual production_PE       394000.0    368000.0
# Copper|Refining_Annual production_PH       176000.0    164000.0
# Copper|Refining_Annual production_PL       547000.0    571000.0
# Copper|Refining_Annual production_PT            NaN         NaN
# Copper|Refining_Annual production_RO         4000.0      4000.0
# Copper|Refining_Annual production_RU       874000.0    890000.0
# Copper|Refining_Annual production_RS        21000.0     29300.0
# Copper|Refining_Annual production_CS            NaN         NaN
# Copper|Refining_Annual production_SK            NaN         NaN
# Copper|Refining_Annual production_ZA        81100.0     80000.0
# Copper|Refining_Annual production_ES       347000.0    354000.0
# Copper|Refining_Annual production_SE       190000.0    219000.0
# Copper|Refining_Annual production_TW         4500.0      4500.0
# Copper|Refining_Annual production_TH          490.0       500.0
# Copper|Refining_Annual production_TR        55000.0     85000.0
# Copper|Refining_Annual production_UA        20000.0     20000.0
# Copper|Refining_Annual production_SU            NaN         NaN
# Copper|Refining_Annual production_GB            NaN         NaN
# Copper|Refining_Annual production_US      1100000.0   1030000.0
# Copper|Refining_Annual production_UZ        90000.0     90000.0
# Copper|Refining_Annual production_VN         8000.0      8000.0
# Copper|Refining_Annual production_YU            NaN         NaN
# Copper|Refining_Annual production_ZM       530000.0    516000.0
# Copper|Refining_Annual production_ZW         5000.0      5000.0
# Copper|Refining_Annual production_World  19100000.0  19700000.0
#
#                                                   Country Name  Country Code  \
# ID
# Copper|Refining_Annual production_AL                   Albania            AL
# Copper|Refining_Annual production_AR                 Argentina            AR
# Copper|Refining_Annual production_AU                 Australia            AU
# Copper|Refining_Annual production_AT                   Austria            AT
# Copper|Refining_Annual production_BE                   Belgium            BE
# Copper|Refining_Annual production_BR                    Brazil            BR
# Copper|Refining_Annual production_BG                  Bulgaria            BG
# Copper|Refining_Annual production_MM                     Burma            MM
# Copper|Refining_Annual production_CA                    Canada            CA
# Copper|Refining_Annual production_CL                     Chile            CL
# Copper|Refining_Annual production_CN                     China            CN
# Copper|Refining_Annual production_CD          Congo (Kinshasa)            CD
# Copper|Refining_Annual production_CY                    Cyprus            CY
# Copper|Refining_Annual production_CZ            Czech Republic            CZ
# Copper|Refining_Annual production_CSK           Czechoslovakia           CSK
# Copper|Refining_Annual production_EG                     Egypt            EG
# Copper|Refining_Annual production_FI                   Finland            FI
# Copper|Refining_Annual production_FR                    France            FR
# Copper|Refining_Annual production_DE                   Germany            DE
# Copper|Refining_Annual production_HU                   Hungary            HU
# Copper|Refining_Annual production_IN                     India            IN
# Copper|Refining_Annual production_ID                 Indonesia            ID
# Copper|Refining_Annual production_IR                      Iran            IR
# Copper|Refining_Annual production_IT                     Italy            IT
# Copper|Refining_Annual production_JP                     Japan            JP
# Copper|Refining_Annual production_KZ                Kazakhstan            KZ
# Copper|Refining_Annual production_KP              Korea, North            KP
# Copper|Refining_Annual production_KR        Korea, Republic of            KR
# Copper|Refining_Annual production_LA                      Laos            LA
# Copper|Refining_Annual production_MX                    Mexico            MX
# Copper|Refining_Annual production_MN                  Mongolia            MN
# Copper|Refining_Annual production_NO                    Norway            NO
# Copper|Refining_Annual production_OM                      Oman            OM
# Copper|Refining_Annual production_PE                      Peru            PE
# Copper|Refining_Annual production_PH               Philippines            PH
# Copper|Refining_Annual production_PL                    Poland            PL
# Copper|Refining_Annual production_PT                  Portugal            PT
# Copper|Refining_Annual production_RO                   Romania            RO
# Copper|Refining_Annual production_RU                    Russia            RU
# Copper|Refining_Annual production_RS                    Serbia            RS
# Copper|Refining_Annual production_CS     Serbia and Montenegro            CS
# Copper|Refining_Annual production_SK                  Slovakia            SK
# Copper|Refining_Annual production_ZA              South Africa            ZA
# Copper|Refining_Annual production_ES                     Spain            ES
# Copper|Refining_Annual production_SE                    Sweden            SE
# Copper|Refining_Annual production_TW                    Taiwan            TW
# Copper|Refining_Annual production_TH                  Thailand            TH
# Copper|Refining_Annual production_TR                    Turkey            TR
# Copper|Refining_Annual production_UA                   Ukraine            UA
# Copper|Refining_Annual production_SU                  U.S.S.R.            SU
# Copper|Refining_Annual production_GB            United Kingdom            GB
# Copper|Refining_Annual production_US             United States            US
# Copper|Refining_Annual production_UZ                Uzbekistan            UZ
# Copper|Refining_Annual production_VN                   Vietnam            VN
# Copper|Refining_Annual production_YU                Yugoslavia            YU
# Copper|Refining_Annual production_ZM                    Zambia            ZM
# Copper|Refining_Annual production_ZW                  Zimbabwe            ZW
# Copper|Refining_Annual production_World                  World         World
#
#                                          Spatial Scale  Data Source  \
# ID
# Copper|Refining_Annual production_AL          National         USGS
# Copper|Refining_Annual production_AR          National         USGS
# Copper|Refining_Annual production_AU          National         USGS
# Copper|Refining_Annual production_AT          National         USGS
# Copper|Refining_Annual production_BE          National         USGS
# Copper|Refining_Annual production_BR          National         USGS
# Copper|Refining_Annual production_BG          National         USGS
# Copper|Refining_Annual production_MM          National         USGS
# Copper|Refining_Annual production_CA          National         USGS
# Copper|Refining_Annual production_CL          National         USGS
# Copper|Refining_Annual production_CN          National         USGS
# Copper|Refining_Annual production_CD          National         USGS
# Copper|Refining_Annual production_CY          National         USGS
# Copper|Refining_Annual production_CZ          National         USGS
# Copper|Refining_Annual production_CSK         National         USGS
# Copper|Refining_Annual production_EG          National         USGS
# Copper|Refining_Annual production_FI          National         USGS
# Copper|Refining_Annual production_FR          National         USGS
# Copper|Refining_Annual production_DE          National         USGS
# Copper|Refining_Annual production_HU          National         USGS
# Copper|Refining_Annual production_IN          National         USGS
# Copper|Refining_Annual production_ID          National         USGS
# Copper|Refining_Annual production_IR          National         USGS
# Copper|Refining_Annual production_IT          National         USGS
# Copper|Refining_Annual production_JP          National         USGS
# Copper|Refining_Annual production_KZ          National         USGS
# Copper|Refining_Annual production_KP          National         USGS
# Copper|Refining_Annual production_KR          National         USGS
# Copper|Refining_Annual production_LA          National         USGS
# Copper|Refining_Annual production_MX          National         USGS
# Copper|Refining_Annual production_MN          National         USGS
# Copper|Refining_Annual production_NO          National         USGS
# Copper|Refining_Annual production_OM          National         USGS
# Copper|Refining_Annual production_PE          National         USGS
# Copper|Refining_Annual production_PH          National         USGS
# Copper|Refining_Annual production_PL          National         USGS
# Copper|Refining_Annual production_PT          National         USGS
# Copper|Refining_Annual production_RO          National         USGS
# Copper|Refining_Annual production_RU          National         USGS
# Copper|Refining_Annual production_RS          National         USGS
# Copper|Refining_Annual production_CS          National         USGS
# Copper|Refining_Annual production_SK          National         USGS
# Copper|Refining_Annual production_ZA          National         USGS
# Copper|Refining_Annual production_ES          National         USGS
# Copper|Refining_Annual production_SE          National         USGS
# Copper|Refining_Annual production_TW          National         USGS
# Copper|Refining_Annual production_TH          National         USGS
# Copper|Refining_Annual production_TR          National         USGS
# Copper|Refining_Annual production_UA          National         USGS
# Copper|Refining_Annual production_SU          National         USGS
# Copper|Refining_Annual production_GB          National         USGS
# Copper|Refining_Annual production_US          National         USGS
# Copper|Refining_Annual production_UZ          National         USGS
# Copper|Refining_Annual production_VN          National         USGS
# Copper|Refining_Annual production_YU          National         USGS
# Copper|Refining_Annual production_ZM          National         USGS
# Copper|Refining_Annual production_ZW          National         USGS
# Copper|Refining_Annual production_World         Global         USGS
#
#                                                 Unit             Metric  \
# ID
# Copper|Refining_Annual production_AL     metric tons  Annual production
# Copper|Refining_Annual production_AR     metric tons  Annual production
# Copper|Refining_Annual production_AU     metric tons  Annual production
# Copper|Refining_Annual production_AT     metric tons  Annual production
# Copper|Refining_Annual production_BE     metric tons  Annual production
# Copper|Refining_Annual production_BR     metric tons  Annual production
# Copper|Refining_Annual production_BG     metric tons  Annual production
# Copper|Refining_Annual production_MM     metric tons  Annual production
# Copper|Refining_Annual production_CA     metric tons  Annual production
# Copper|Refining_Annual production_CL     metric tons  Annual production
# Copper|Refining_Annual production_CN     metric tons  Annual production
# Copper|Refining_Annual production_CD     metric tons  Annual production
# Copper|Refining_Annual production_CY     metric tons  Annual production
# Copper|Refining_Annual production_CZ     metric tons  Annual production
# Copper|Refining_Annual production_CSK    metric tons  Annual production
# Copper|Refining_Annual production_EG     metric tons  Annual production
# Copper|Refining_Annual production_FI     metric tons  Annual production
# Copper|Refining_Annual production_FR     metric tons  Annual production
# Copper|Refining_Annual production_DE     metric tons  Annual production
# Copper|Refining_Annual production_HU     metric tons  Annual production
# Copper|Refining_Annual production_IN     metric tons  Annual production
# Copper|Refining_Annual production_ID     metric tons  Annual production
# Copper|Refining_Annual production_IR     metric tons  Annual production
# Copper|Refining_Annual production_IT     metric tons  Annual production
# Copper|Refining_Annual production_JP     metric tons  Annual production
# Copper|Refining_Annual production_KZ     metric tons  Annual production
# Copper|Refining_Annual production_KP     metric tons  Annual production
# Copper|Refining_Annual production_KR     metric tons  Annual production
# Copper|Refining_Annual production_LA     metric tons  Annual production
# Copper|Refining_Annual production_MX     metric tons  Annual production
# Copper|Refining_Annual production_MN     metric tons  Annual production
# Copper|Refining_Annual production_NO     metric tons  Annual production
# Copper|Refining_Annual production_OM     metric tons  Annual production
# Copper|Refining_Annual production_PE     metric tons  Annual production
# Copper|Refining_Annual production_PH     metric tons  Annual production
# Copper|Refining_Annual production_PL     metric tons  Annual production
# Copper|Refining_Annual production_PT     metric tons  Annual production
# Copper|Refining_Annual production_RO     metric tons  Annual production
# Copper|Refining_Annual production_RU     metric tons  Annual production
# Copper|Refining_Annual production_RS     metric tons  Annual production
# Copper|Refining_Annual production_CS     metric tons  Annual production
# Copper|Refining_Annual production_SK     metric tons  Annual production
# Copper|Refining_Annual production_ZA     metric tons  Annual production
# Copper|Refining_Annual production_ES     metric tons  Annual production
# Copper|Refining_Annual production_SE     metric tons  Annual production
# Copper|Refining_Annual production_TW     metric tons  Annual production
# Copper|Refining_Annual production_TH     metric tons  Annual production
# Copper|Refining_Annual production_TR     metric tons  Annual production
# Copper|Refining_Annual production_UA     metric tons  Annual production
# Copper|Refining_Annual production_SU     metric tons  Annual production
# Copper|Refining_Annual production_GB     metric tons  Annual production
# Copper|Refining_Annual production_US     metric tons  Annual production
# Copper|Refining_Annual production_UZ     metric tons  Annual production
# Copper|Refining_Annual production_VN     metric tons  Annual production
# Copper|Refining_Annual production_YU     metric tons  Annual production
# Copper|Refining_Annual production_ZM     metric tons  Annual production
# Copper|Refining_Annual production_ZW     metric tons  Annual production
# Copper|Refining_Annual production_World  metric tons  Annual production
#
#                                          Technology Name
# ID
# Copper|Refining_Annual production_AL     Copper|Refining
# Copper|Refining_Annual production_AR     Copper|Refining
# Copper|Refining_Annual production_AU     Copper|Refining
# Copper|Refining_Annual production_AT     Copper|Refining
# Copper|Refining_Annual production_BE     Copper|Refining
# Copper|Refining_Annual production_BR     Copper|Refining
# Copper|Refining_Annual production_BG     Copper|Refining
# Copper|Refining_Annual production_MM     Copper|Refining
# Copper|Refining_Annual production_CA     Copper|Refining
# Copper|Refining_Annual production_CL     Copper|Refining
# Copper|Refining_Annual production_CN     Copper|Refining
# Copper|Refining_Annual production_CD     Copper|Refining
# Copper|Refining_Annual production_CY     Copper|Refining
# Copper|Refining_Annual production_CZ     Copper|Refining
# Copper|Refining_Annual production_CSK    Copper|Refining
# Copper|Refining_Annual production_EG     Copper|Refining
# Copper|Refining_Annual production_FI     Copper|Refining
# Copper|Refining_Annual production_FR     Copper|Refining
# Copper|Refining_Annual production_DE     Copper|Refining
# Copper|Refining_Annual production_HU     Copper|Refining
# Copper|Refining_Annual production_IN     Copper|Refining
# Copper|Refining_Annual production_ID     Copper|Refining
# Copper|Refining_Annual production_IR     Copper|Refining
# Copper|Refining_Annual production_IT     Copper|Refining
# Copper|Refining_Annual production_JP     Copper|Refining
# Copper|Refining_Annual production_KZ     Copper|Refining
# Copper|Refining_Annual production_KP     Copper|Refining
# Copper|Refining_Annual production_KR     Copper|Refining
# Copper|Refining_Annual production_LA     Copper|Refining
# Copper|Refining_Annual production_MX     Copper|Refining
# Copper|Refining_Annual production_MN     Copper|Refining
# Copper|Refining_Annual production_NO     Copper|Refining
# Copper|Refining_Annual production_OM     Copper|Refining
# Copper|Refining_Annual production_PE     Copper|Refining
# Copper|Refining_Annual production_PH     Copper|Refining
# Copper|Refining_Annual production_PL     Copper|Refining
# Copper|Refining_Annual production_PT     Copper|Refining
# Copper|Refining_Annual production_RO     Copper|Refining
# Copper|Refining_Annual production_RU     Copper|Refining
# Copper|Refining_Annual production_RS     Copper|Refining
# Copper|Refining_Annual production_CS     Copper|Refining
# Copper|Refining_Annual production_SK     Copper|Refining
# Copper|Refining_Annual production_ZA     Copper|Refining
# Copper|Refining_Annual production_ES     Copper|Refining
# Copper|Refining_Annual production_SE     Copper|Refining
# Copper|Refining_Annual production_TW     Copper|Refining
# Copper|Refining_Annual production_TH     Copper|Refining
# Copper|Refining_Annual production_TR     Copper|Refining
# Copper|Refining_Annual production_UA     Copper|Refining
# Copper|Refining_Annual production_SU     Copper|Refining
# Copper|Refining_Annual production_GB     Copper|Refining
# Copper|Refining_Annual production_US     Copper|Refining
# Copper|Refining_Annual production_UZ     Copper|Refining
# Copper|Refining_Annual production_VN     Copper|Refining
# Copper|Refining_Annual production_YU     Copper|Refining
# Copper|Refining_Annual production_ZM     Copper|Refining
# Copper|Refining_Annual production_ZW     Copper|Refining
# Copper|Refining_Annual production_World  Copper|Refining
#
# [58 rows x 29 columns]

# %%
# Iron ore and raw steel
# Omitting West Germany because there's only one data point
iron = read_usgs_896('Iron Ore', 'raw data/usgs/ds896-iron-steel.xlsx', 'Iron ore, gross weight')
iron = iron[(iron['Country Name']!='Germany: Western states')]
iron.to_csv('cleaned data/ds896_Iron ore.csv')

steel = read_usgs_896('Raw Steel Production', 'raw data/usgs/ds896-iron-steel.xlsx', 'Raw steel')
steel = steel[(steel['Country Name']!='Germany: Eastern states') & (steel['Country Name']!='Germany: Western states')]
steel.to_csv('cleaned data/ds896_Raw steel production.csv')
steel
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#                                                 1990       1991       1992  \
# ID
# Raw Steel Production_Annual production_AL    65000.0    35000.0    20000.0
# Raw Steel Production_Annual production_DZ   836000.0   838000.0   842000.0
# Raw Steel Production_Annual production_AO    10000.0    10000.0    10000.0
# Raw Steel Production_Annual production_AR  3640000.0  2990000.0  2700000.0
# Raw Steel Production_Annual production_AU  6670000.0  6140000.0  6800000.0
# ...                                              ...        ...        ...
# Raw Steel Production_Annual production_UZ        NaN        NaN   630000.0
# Raw Steel Production_Annual production_VE  3180000.0  3320000.0  3490000.0
# Raw Steel Production_Annual production_VN   102000.0   183000.0   219000.0
# Raw Steel Production_Annual production_YU  3840000.0  2140000.0        NaN
# Raw Steel Production_Annual production_ZW   580000.0   581000.0   547000.0
#
#                                                 1993       1994       1995  \
# ID
# Raw Steel Production_Annual production_AL    19000.0    19000.0    22000.0
# Raw Steel Production_Annual production_DZ   865000.0   808000.0   827000.0
# Raw Steel Production_Annual production_AO     9000.0     9000.0     9000.0
# Raw Steel Production_Annual production_AR  2890000.0  3310000.0  3580000.0
# Raw Steel Production_Annual production_AU  7850000.0  8420000.0  8450000.0
# ...                                              ...        ...        ...
# Raw Steel Production_Annual production_UZ   573000.0   364000.0   352000.0
# Raw Steel Production_Annual production_VE  3390000.0  3520000.0  3570000.0
# Raw Steel Production_Annual production_VN   270000.0   301000.0   271000.0
# Raw Steel Production_Annual production_YU        NaN        NaN        NaN
# Raw Steel Production_Annual production_ZW   221000.0   187000.0   210000.0
#
#                                                 1996       1997       1998  \
# ID
# Raw Steel Production_Annual production_AL    20000.0    20000.0    15000.0
# Raw Steel Production_Annual production_DZ   620000.0   427000.0   400000.0
# Raw Steel Production_Annual production_AO     9000.0     9000.0     9000.0
# Raw Steel Production_Annual production_AR  4080000.0  4170000.0  4210000.0
# Raw Steel Production_Annual production_AU  8420000.0  8770000.0  8800000.0
# ...                                              ...        ...        ...
# Raw Steel Production_Annual production_UZ   444000.0   365000.0   344000.0
# Raw Steel Production_Annual production_VE  3960000.0  3990000.0  3550000.0
# Raw Steel Production_Annual production_VN   311000.0   314000.0   306000.0
# Raw Steel Production_Annual production_YU        NaN        NaN        NaN
# Raw Steel Production_Annual production_ZW   212000.0   214000.0   220000.0
#
#                                                 1999  ...       2009  \
# ID                                                    ...
# Raw Steel Production_Annual production_AL    15100.0  ...   440000.0
# Raw Steel Production_Annual production_DZ   758000.0  ...   543000.0
# Raw Steel Production_Annual production_AO        NaN  ...        NaN
# Raw Steel Production_Annual production_AR  3800000.0  ...  4010000.0
# Raw Steel Production_Annual production_AU  8160000.0  ...  6140000.0
# ...                                              ...  ...        ...
# Raw Steel Production_Annual production_UZ   343000.0  ...   716000.0
# Raw Steel Production_Annual production_VE  3260000.0  ...  5000000.0
# Raw Steel Production_Annual production_VN   308000.0  ...  2700000.0
# Raw Steel Production_Annual production_YU        NaN  ...        NaN
# Raw Steel Production_Annual production_ZW   255000.0  ...    10000.0
#
#                                                 2010       2011  Country Name  \
# ID
# Raw Steel Production_Annual production_AL   440000.0   440000.0       Albania
# Raw Steel Production_Annual production_DZ   696000.0   440000.0       Algeria
# Raw Steel Production_Annual production_AO        NaN        NaN        Angola
# Raw Steel Production_Annual production_AR  5140000.0  5660000.0     Argentina
# Raw Steel Production_Annual production_AU  7140000.0  6540000.0     Australia
# ...                                              ...        ...           ...
# Raw Steel Production_Annual production_UZ   745000.0   760000.0    Uzbekistan
# Raw Steel Production_Annual production_VE  5000000.0  5000000.0     Venezuela
# Raw Steel Production_Annual production_VN  4310000.0  4300000.0       Vietnam
# Raw Steel Production_Annual production_YU        NaN        NaN    Yugoslavia
# Raw Steel Production_Annual production_ZW        NaN        NaN      Zimbabwe
#
#                                            Country Code  Spatial Scale  \
# ID
# Raw Steel Production_Annual production_AL            AL       National
# Raw Steel Production_Annual production_DZ            DZ       National
# Raw Steel Production_Annual production_AO            AO       National
# Raw Steel Production_Annual production_AR            AR       National
# Raw Steel Production_Annual production_AU            AU       National
# ...                                                 ...            ...
# Raw Steel Production_Annual production_UZ            UZ       National
# Raw Steel Production_Annual production_VE            VE       National
# Raw Steel Production_Annual production_VN            VN       National
# Raw Steel Production_Annual production_YU            YU       National
# Raw Steel Production_Annual production_ZW            ZW       National
#
#                                            Data Source         Unit  \
# ID
# Raw Steel Production_Annual production_AL         USGS  metric tons
# Raw Steel Production_Annual production_DZ         USGS  metric tons
# Raw Steel Production_Annual production_AO         USGS  metric tons
# Raw Steel Production_Annual production_AR         USGS  metric tons
# Raw Steel Production_Annual production_AU         USGS  metric tons
# ...                                                ...          ...
# Raw Steel Production_Annual production_UZ         USGS  metric tons
# Raw Steel Production_Annual production_VE         USGS  metric tons
# Raw Steel Production_Annual production_VN         USGS  metric tons
# Raw Steel Production_Annual production_YU         USGS  metric tons
# Raw Steel Production_Annual production_ZW         USGS  metric tons
#
#                                                       Metric  \
# ID
# Raw Steel Production_Annual production_AL  Annual production
# Raw Steel Production_Annual production_DZ  Annual production
# Raw Steel Production_Annual production_AO  Annual production
# Raw Steel Production_Annual production_AR  Annual production
# Raw Steel Production_Annual production_AU  Annual production
# ...                                                      ...
# Raw Steel Production_Annual production_UZ  Annual production
# Raw Steel Production_Annual production_VE  Annual production
# Raw Steel Production_Annual production_VN  Annual production
# Raw Steel Production_Annual production_YU  Annual production
# Raw Steel Production_Annual production_ZW  Annual production
#
#                                                 Technology Name
# ID
# Raw Steel Production_Annual production_AL  Raw Steel Production
# Raw Steel Production_Annual production_DZ  Raw Steel Production
# Raw Steel Production_Annual production_AO  Raw Steel Production
# Raw Steel Production_Annual production_AR  Raw Steel Production
# Raw Steel Production_Annual production_AU  Raw Steel Production
# ...                                                         ...
# Raw Steel Production_Annual production_UZ  Raw Steel Production
# Raw Steel Production_Annual production_VE  Raw Steel Production
# Raw Steel Production_Annual production_VN  Raw Steel Production
# Raw Steel Production_Annual production_YU  Raw Steel Production
# Raw Steel Production_Annual production_ZW  Raw Steel Production
#
# [104 rows x 29 columns]

# %%
# Lead
lead = read_usgs_896('Lead', 'raw data/usgs/ds896-lead.xlsx', 'Mine')
lead = lead[lead['Country Name']!='Germany: Western states']
lead.to_csv('cleaned data/ds896_Lead.csv')
lead
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#                                1990      1991      1992      1993      1994  \
# ID
# Lead_Annual production_DZ    1100.0    1150.0     900.0    1540.0    1100.0
# Lead_Annual production_AR   23400.0   23700.0   18000.0   11800.0    9980.0
# Lead_Annual production_AU  570000.0  579000.0  577000.0  519000.0  537000.0
# Lead_Annual production_AT    1490.0    1150.0     920.0    1340.0       NaN
# Lead_Annual production_BO   19900.0   20800.0   20000.0   21200.0   19700.0
# ...                             ...       ...       ...       ...       ...
# Lead_Annual production_GB    1380.0    1020.0    1000.0    1000.0    2000.0
# Lead_Annual production_UZ       NaN       NaN   35000.0   25000.0   15000.0
# Lead_Annual production_VN       NaN       NaN       NaN       NaN       NaN
# Lead_Annual production_YU   99100.0   90000.0       NaN       NaN       NaN
# Lead_Annual production_ZM    9640.0    9080.0    4450.0    7030.0       NaN
#
#                                1995      1996      1997      1998      1999  \
# ID
# Lead_Annual production_DZ    1380.0    1020.0     845.0     730.0    1220.0
# Lead_Annual production_AR   10500.0   11300.0   13800.0   15000.0   15300.0
# Lead_Annual production_AU  455000.0  522000.0  526000.0  618000.0  681000.0
# Lead_Annual production_AT       NaN       NaN       NaN       NaN       NaN
# Lead_Annual production_BO   20400.0   16500.0   18600.0   13800.0   10200.0
# ...                             ...       ...       ...       ...       ...
# Lead_Annual production_GB    1600.0    1800.0    1800.0    1600.0    1000.0
# Lead_Annual production_UZ   10000.0   10000.0       NaN       NaN       NaN
# Lead_Annual production_VN       NaN       NaN    1000.0    1000.0    1000.0
# Lead_Annual production_YU       NaN       NaN       NaN       NaN       NaN
# Lead_Annual production_ZM       NaN       NaN       NaN       NaN       NaN
#
#                            ...      2010      2011      2012    Country Name  \
# ID                         ...
# Lead_Annual production_DZ  ...       NaN       NaN       NaN         Algeria
# Lead_Annual production_AR  ...   22600.0   26100.0   25000.0       Argentina
# Lead_Annual production_AU  ...  625000.0  621000.0  648000.0       Australia
# Lead_Annual production_AT  ...       NaN       NaN       NaN         Austria
# Lead_Annual production_BO  ...   72800.0  100000.0  100000.0         Bolivia
# ...                        ...       ...       ...       ...             ...
# Lead_Annual production_GB  ...     500.0     500.0     500.0  United Kingdom
# Lead_Annual production_UZ  ...       NaN    6000.0    6000.0      Uzbekistan
# Lead_Annual production_VN  ...    7400.0    7400.0    7400.0         Vietnam
# Lead_Annual production_YU  ...       NaN       NaN       NaN      Yugoslavia
# Lead_Annual production_ZM  ...       NaN       NaN       NaN          Zambia
#
#                            Country Code  Spatial Scale  Data Source  \
# ID
# Lead_Annual production_DZ            DZ       National         USGS
# Lead_Annual production_AR            AR       National         USGS
# Lead_Annual production_AU            AU       National         USGS
# Lead_Annual production_AT            AT       National         USGS
# Lead_Annual production_BO            BO       National         USGS
# ...                                 ...            ...          ...
# Lead_Annual production_GB            GB       National         USGS
# Lead_Annual production_UZ            UZ       National         USGS
# Lead_Annual production_VN            VN       National         USGS
# Lead_Annual production_YU            YU       National         USGS
# Lead_Annual production_ZM            ZM       National         USGS
#
#                                   Unit             Metric  Technology Name
# ID
# Lead_Annual production_DZ  metric tons  Annual production             Lead
# Lead_Annual production_AR  metric tons  Annual production             Lead
# Lead_Annual production_AU  metric tons  Annual production             Lead
# Lead_Annual production_AT  metric tons  Annual production             Lead
# Lead_Annual production_BO  metric tons  Annual production             Lead
# ...                                ...                ...              ...
# Lead_Annual production_GB  metric tons  Annual production             Lead
# Lead_Annual production_UZ  metric tons  Annual production             Lead
# Lead_Annual production_VN  metric tons  Annual production             Lead
# Lead_Annual production_YU  metric tons  Annual production             Lead
# Lead_Annual production_ZM  metric tons  Annual production             Lead
#
# [61 rows x 30 columns]

# %%
# Salt
salt = pd.read_excel('raw data/usgs/ds896-salt.xlsx', sheet_name=0, header=3,
                     na_values=['XX','--', 'W', '(3/)', '(4/)','-- '])
drop_idx = []
for idx in salt.index:
    country = salt[salt.columns[0]].iloc[idx]
    drop_list = ['Limonite', 'Other', 'Puerto Rico', 'United States: Puerto Rico', 'Leeward and Windward Islands ']
    if country in drop_list:
        drop_idx.append(idx)
salt.drop(index=drop_idx, inplace=True)
salt.reset_index(drop=True, inplace=True)
for idx in salt.index:
    country = salt[salt.columns[0]].iloc[idx]
    if country == 'World':
        world_idx = idx
salt = salt[:world_idx]
countries = []
for country in salt[salt.columns[0]]:
    country = country.strip(string.digits)
    country = country.strip()
    countries.append(country)
salt['Country Name'] = countries
salt = salt[(salt['Country Name']!='Germany: Eastern states') & (salt['Country Name']!='Germany: Western states')]
salt.drop(columns=[salt.columns[0], 'Salt type'], inplace=True)
unique_countries = sorted(list(set(salt['Country Name'])))
salt_type_sum = []
for country in unique_countries:
    dup_df = salt[salt['Country Name']==country].sum()
    dup_df = dup_df[:-1]
    val_list = []
    for x in dup_df:
        val_list.append(x)
    val_list.append(country)
    salt_type_sum.append(val_list)
salt = pd.DataFrame(salt_type_sum, columns=salt.columns)
iso2 = []
spatial_scale = []
for country in salt['Country Name']:
    if country == 'Serbia and Montenegro':
        iso2.append('CS')
        spatial_scale.append('National')
    elif country == 'Czechoslovakia':
        iso2.append('CSK')
        spatial_scale.append('National')
    elif country == 'U.S.S.R.':
        iso2.append('SU')
        spatial_scale.append('National')
    elif country == 'Yugoslavia':
        iso2.append('YU')
        spatial_scale.append('National')
    elif country == 'World':
        iso2.append('World')
        spatial_scale.append('Global')
    elif country == 'Netherlands Antilles':
        iso2.append('AN')
        spatial_scale.append('National')
    else:
        iso2.append(coco.convert(names=country, to='iso2'))
        spatial_scale.append('National')
salt['Country Code'] = iso2
salt['Spatial Scale'] = spatial_scale
salt['Data Source'] = 'USGS'
salt['Unit'] = 'metric tons'
salt['Metric'] = 'Annual production'
salt['Technology Name'] = 'Salt Production'
salt['ID'] = salt['Technology Name'] + '_' + salt['Metric'] + '_' + salt['Country Code']
salt.set_index('ID', inplace=True)
# drop US dup - longer time series in ds140
salt.drop('Salt Production_Annual production_US', inplace=True)
salt.replace(0, np.nan, inplace=True)
salt.to_csv('cleaned data/ds896_Salt production.csv')

# %%
# https://www.usgs.gov/centers/national-minerals-information-center/historical-statistics-mineral-and-material-commodities
# Data Series 140

# %%
## adjusting for inflation from 1998 USD to 2022
nipa = pd.read_excel('A001RG3A086NBEA.xls', header=10)

year_list = []
for x in nipa['observation_date']:
    x = int(str(x)[:4])
    year_list.append(x)
nipa['Year'] = year_list
nipa.set_index('Year', drop=True, inplace=True)
nipa.drop(columns='observation_date', inplace=True)
nipa = nipa.transpose()

infl_1998_2022 = float(nipa[2022]/nipa[1998])
infl_1998_2022
# Out:
# 1.6912695457930007

# %%
def read_usgs_140(tech_name, file_name, sheet=0, header=4,
                  col_names=['Year','Production','Unit value (98$/t)','World production']):
    df = pd.read_excel(file_name, sheet_name=sheet, header=header, usecols=col_names, 
                       na_values=['XX','--', 'W', '(3/)', '(4/)','-- '])
    end_idx = None
    for idx in df.index:
        year = df['Year'].iloc[idx]
        if type(year) != int:
            end_idx = idx
            break
    df = df[:end_idx]
    df.set_index('Year', drop=True, inplace=True)
    df = df.transpose()
    
    for col in df.columns:
        df[col] = df[col] * infl_1998_2022
    
    df['Technology Name'] = tech_name
    df['Data Source'] = 'USGS'
    df['Country Name'] = ['United States', 'World', 'World']
    df['Country Code'] = ['US', 'World', 'World']
    df['Spatial Scale'] = ['National', 'Global', 'Global']
    df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
    df['Metric'] = ['Annual production', 'Price', 'Annual production']
    df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']
    df.set_index('ID', drop=True, inplace=True)
    df.columns.name = None    
    file_name = 'cleaned data/ds140_' + tech_name + '.csv'
    df.to_csv(file_name)
    return df

# %%
# raw steel
steel_ds140 = read_usgs_140('Raw Steel Production', 'raw data/usgs/ds140-iron-steel-2019.xlsx', header=5,
                            sheet='Steel',
                            col_names=['Year','Raw steel production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# cadmium
cadmium_ds140 = read_usgs_140('Cadmium Refining', 'raw data/usgs/ds140-cadmium-2019.xlsx',
                             col_names=['Year','Production','Unit value (98 $/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# iron ore
iron_ds140 = read_usgs_140('Iron Ore', 'raw data/usgs/ds140-iron-ore-2019.xlsx',
                          col_names=['Year','Production','Unit value (98$/t) ','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# lead
lead_ds140 = read_usgs_140('Lead', 'raw data/usgs/ds140-lead-2018.xlsx',
                          col_names=['Year','Primary production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# primary aluminum
aluminum_ds140 = read_usgs_140('Primary Aluminum Production', 'raw data/usgs/ds140-aluminum-2019.xlsx',
                          col_names=['Year','Primary production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# graphite
graphite = read_usgs_140('Graphite', 'raw data/usgs/ds140-graphite-2019.xlsx')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# cobalt
cobalt = read_usgs_140('Cobalt', 'raw data/usgs/ds140-cobalt-2019.xlsx',
                    col_names=['Year','Primary production','Unit value (98$/t)','World mine production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# lithium
lithium = read_usgs_140('Lithium Mine Production', 'raw data/usgs/ds140-lithium-2019.xlsx',
                    col_names=['Year','Production','Unit value (98$/t)','World production (gross weight)'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# rare earth
rare_earth = read_usgs_140('Rare Earth Mine Production', 'raw data/usgs/ds140-rare-earths-2019.xlsx')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# silver
silver = read_usgs_140('Silver Production', 'raw data/usgs/ds140-silver-2018.xlsx',
                    col_names=['Year','Mine production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# tin
tin = read_usgs_140('Tin Production', 'raw data/usgs/ds140-tin-2019.xlsx',
                    col_names=['Year','Primary production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# Cement
cement = read_usgs_140('Cement', 'raw data/usgs/ds140-cement-2019.xlsx')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# Primary copper
copper = read_usgs_140('Primary Copper', 'raw data/usgs/ds140-copper-2018.xlsx', 
             col_names=['Year','Primary production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# Gold
gold = read_usgs_140('Gold Production', 'raw data/usgs/ds140-gold-2018.xlsx', 
             col_names=['Year','Primary production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# Nickel
nickel = read_usgs_140('Nickel Production', 'raw data/usgs/ds140-nickel-2018_1.xlsx', 
             col_names=['Year','Primary production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# Sand and gravel (construction)
sand_gravel_construction = read_usgs_140('Sand and Gravel|Construction', 
                                         'raw data/usgs/ds140-sand-gravel-construction-2019.xlsx')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# Sand and gravel (industrial)
sand_gravel_industrial = read_usgs_140('Sand and Gravel|Industrial', 
                                         'raw data/usgs/ds140-sand-industrial-2019.xlsx')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# zinc
zinc = read_usgs_140('Zinc Production', 'raw data/usgs/ds140-zinc-2019.xlsx',
                    col_names=['Year',' Primary production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# salt
salt_ds140 = read_usgs_140('Salt Production', 'raw data/usgs/ds140-2017-salt.xlsx',
                    col_names=['Year','Production','Unit value  (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']

# %%
# bauxite
bauxite_ds140 = read_usgs_140('Primary Bauxite Production', 'raw data/usgs/ds140-bauxite-alumina-2019.xlsx',
                          col_names=['Year','Production','Unit value (98$/t)','World production'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Data Source'] = 'USGS'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Name'] = ['United States', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Country Code'] = ['US', 'World', 'World']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Spatial Scale'] = ['National', 'Global', 'Global']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Unit'] = ['metric tons', '2022 USD/metric ton', 'metric tons']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Metric'] = ['Annual production', 'Price', 'Annual production']
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_51697/2627807958.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']
