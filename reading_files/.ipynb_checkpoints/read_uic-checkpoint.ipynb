# %%
import os
import pandas as pd
from pandas import Series, DataFrame

# %%
# https://uic.org/IMG/pdf/uic-atlas-high-speed-2022.pdf
# data digitized from figure on page 16
# Length of the high-speed network in commercial operation worldwide (1964-2021)

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
high_speed_rail = pd.read_csv('raw data/UICAtlas_HighSpeedRail_TimeSeries.csv', index_col=0)
high_speed_rail = high_speed_rail.transpose()
high_speed_rail['Data Source'] = 'UIC'
high_speed_rail['Country Name'] = 'World'
high_speed_rail['Country Code'] = 'World'
high_speed_rail['Spatial Scale'] = 'Global'
high_speed_rail['Metric'] = 'Cumulative Total Capacity'
high_speed_rail['Technology Name'] = 'High-Speed Rail'
high_speed_rail['Unit'] = 'kilometers'
high_speed_rail['ID'] = high_speed_rail['Technology Name'] + '_' + high_speed_rail['Metric'] + '_' + high_speed_rail['Country Code']
high_speed_rail.set_index('ID', drop=True, inplace=True)
high_speed_rail.columns.name = None
high_speed_rail
# Out:
#                                                  1964  1965  1966  1967  1968  \
# ID
# High-Speed Rail_Cumulative Total Capacity_World   515   515   515   515   515
#
#                                                  1969  1970  1971  1972  1973  \
# ID
# High-Speed Rail_Cumulative Total Capacity_World   515   515   515   676   676
#
#                                                  ...   2019   2020   2021  \
# ID                                               ...
# High-Speed Rail_Cumulative Total Capacity_World  ...  53458  56167  58839
#
#                                                  Data Source  Country Name  \
# ID
# High-Speed Rail_Cumulative Total Capacity_World          UIC         World
#
#                                                  Country Code  Spatial Scale  \
# ID
# High-Speed Rail_Cumulative Total Capacity_World         World         Global
#
#                                                                     Metric  \
# ID
# ...

# %%
high_speed_rail.to_csv('cleaned data/uic.csv')
