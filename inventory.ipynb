# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech_version 2.0.csv')
all_tech
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 8499        Objects Launched Into Space_Total Number_UA      National
# 8500        Objects Launched Into Space_Total Number_TM      National
# 8501         Liquefied Natural Gas_Annual Production_US      National
# 8502        Objects Launched Into Space_Total Number_CO      National
# 8503       Geothermal Energy_Total Installed Cost_World        Global
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 8499           UA        Ukraine  Objects Launched Into Space
# 8500           TM   Turkmenistan  Objects Launched Into Space
# 8501           US  United States        Liquefied Natural Gas
# 8502           CO       Colombia  Objects Launched Into Space
# 8503        World          World            Geothermal Energy
#
#                          Metric                Unit Data Source  \
# 0        Cumulative Rated Power                  kW       GESDB
# 1     Cumulative Rated Capacity                 kWh       GESDB
# 2        Cumulative Rated Power                  kW       GESDB
# 3     Cumulative Rated Capacity                 kWh       GESDB
# 4      Levelized Cost of Energy        2022 USD/kWh       IRENA
# ...                         ...                 ...         ...
# 8499               Total Number                   -      UNOOSA
# 8500               Total Number                   -      UNOOSA
# 8501          Annual Production  billion cubic feet         EIA
# 8502               Total Number                   -      UNOOSA
# 8503       Total Installed Cost         2022 USD/kW       IRENA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 8499           Total Number|Objects Launched Into Space   NaN  ...
# 8500           Total Number|Objects Launched Into Space   NaN  ...
# 8501            Annual Production|Liquefied Natural Gas   NaN  ...
# 8502           Total Number|Objects Launched Into Space   NaN  ...
# 8503             Total Installed Cost|Geothermal Energy   NaN  ...
#
#               2017          2018         2019         2020         2021  2022  \
# 0     1.900000e+02  2.900000e+02          NaN          NaN          NaN   NaN
# 1     7.600000e+02  1.160000e+03          NaN          NaN          NaN   NaN
# 2     3.550000e+05  4.550000e+05          NaN          NaN          NaN   NaN
# 3     1.745000e+06  2.945000e+06          NaN          NaN          NaN   NaN
# 4     4.898293e-02  4.679236e-02     0.048501     0.042769          NaN   NaN
# ...            ...           ...          ...          ...          ...   ...
# 8499           NaN           NaN          NaN          NaN          NaN   1.0
# 8500           NaN           NaN          NaN          NaN          NaN   NaN
# 8501  7.075400e+02  1.083120e+03  1819.400000  2389.840000  3560.820000   NaN
# 8502           NaN  1.000000e+00          NaN          NaN          NaN   NaN
# 8503  4.294267e+03  4.657604e+03  4414.770041  3726.247383  4269.700034   NaN
#
#       2023  2024  2025  Unnamed: 0
# 0      NaN   NaN   NaN         NaN
# 1      NaN   NaN   NaN         NaN
# 2      NaN   NaN   NaN         NaN
# 3      NaN   NaN   NaN         NaN
# 4      NaN   NaN   NaN         NaN
# ...    ...   ...   ...         ...
# 8499   NaN   NaN   NaN         NaN
# 8500   NaN   NaN   NaN         NaN
# 8501   NaN   NaN   NaN         NaN
# 8502   NaN   NaN   NaN         NaN
# 8503   NaN   NaN   NaN         NaN
#
# [8504 rows x 336 columns]

# %%
source_dict = {}
for source in sorted(list(set(all_tech['Data Source']))):
    tech_list = list(set(all_tech[all_tech['Data Source']==source]['Technology Name']))
    source_dict[source] = tech_list
for source in source_dict['UN Industrial Commodity Statistics Database']:
    print(source)
# Out:
# Radio Receivers
# Caustic Soda
# Nitrogenous Fertilizers
# Combined Refrigerators-Freezers
# Synthetic Filament Tow and Staple Fibers
# Television Receivers
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Refined Copper
# Potassic Fertilizers
# Vacuum Cleaners
# Air Conditioning Machines
# Electric Water Heaters and Immersion Heaters
# Household Washing and Drying Machines
# Synthetic Filament Yarn
# Bicycles and Other Cycles
# Household Refrigerators and Freezers
# Telephones and Videophones
# Beer
# Motorcycles and Scooters
# Cars
# Microwave Ovens

# %%
len(list(set(all_tech['Data Source'])))
# Out:
# 39

# %%
tech_list = sorted(list(set(all_tech['Technology Name'])))
for x in tech_list:
    print(x)
# Out:
# Acrylic Fiber
# Acrylonitrile
# Air Conditioning Machines
# Air-Source Heat Pumps
# Amazon Prime Users
# Ammonia Synthesis
# Aniline
# Aquaculture Production
# Artificial and Synthetic Fibers
# Automatic Transmission
# BCG Vaccine
# Beer
# Beer Production
# Benzene
# Bicycles
# Bicycles and Other Cycles
# Bioenergy
# Biofuels Production
# Biogas
# BisphenolA
# CFLs
# Cable TV
# Cadmium Refining
# Canals
# Capillary DNA Sequencing
# Caprolactam
# Capture Fisheries
# Carbon Capture and Sequestration
# Cars
# Caustic Soda
# Caustic Soda Acid
# Cellphones
# Cement
# Central Heating
# Coal Power
# Coal Production
# Cobalt
# Colour TV
# Combined Refrigerators-Freezers
# Compact Fluorescent Light Bulbs
# Compressed Air Energy Storage
# Computing Growth
# Concentrated Solar Power
# Concentrating Solar Power
# Copper|Mining
# Copper|Refining
# Corn Production
# Cotton Seed Production
# Cow's Milk Production
# Crop Harvester
# Crude Oil
# Crude Petroleum
# Cyclohexane
# DNA Sequencing (All Methods)
# DTP1 Vaccine
# DTP3 Vaccine
# Desalination Capacity
# Dishwashers
# Disk Brakes
# Ebook Reader
# Electric Bicycles
# Electric Range
# Electric Water Heaters and Immersion Heaters
# Electricity
# Electro-Chemical Capacitor
# Electronic Ignition
# Ethanol
# Ethanolamine
# Ethylene
# Ethylene Glycol
# Flow Battery Storage
# Flue Gas Desulphurization (Wet and Dry)
# Fluid Catalytic Cracking Refineries
# Flush Toilet
# Flywheel Battery Storage
# Formaldehyde
# Freezer
# Geothermal Energy
# Gold
# Gold Production
# Graphite
# Ground Source Heat Pumps
# HEPB3 Vaccine
# HEPBB Vaccine
# HIB3 Vaccine
# Heat Thermal Battery Storage
# Herbicide-Tolerant Corn
# Herbicide-Tolerant Cotton
# Herbicide-Tolerant Soybeans
# High-Density Polyethylene
# High-Speed Rail
# Home Air Conditioning
# Home Computers
# Household Internet Access
# Household Refrigerators and Freezers
# Household Washing and Drying Machines
# Households With Only Mobile Phones (No Landlines)
# Hydrochloric Acid
# Hydroelectricity
# Hydrofluoric Acid
# Hydrogen Storage
# Hydropower
# Hydropower Mega-Dams
# IPV1 Vaccine
# Insect-Resistant Corn
# Insect-Resistant Cotton
# Internet Backbone Bandwidth
# Internet Traffic
# Iron
# Iron Ore
# Jet Aircraft
# Latent Heat Storage
# Laundry Dryers
# Lead
# Lead-Acid Battery
# Lead-Acid Battery Storage
# Liquefied Natural Gas
# Liquefied Natural Gas (LNG)
# Liquid Biofuels
# Lithium Mine Production
# Lithium-Ion Battery Storage
# Lithium-Ion Cells
# Low-Density Polyethylene
# MCV1 Vaccine
# MCV2 Vaccine
# Magnesium
# Magnetic Data Storage
# Maleic Anhydride
# Marine Energy
# Methanol
# Microcomputers
# Microprocessor Clock Speed
# Microwave Ovens
# Microwaves
# Milk
# Motor Gasoline
# Motorcycles
# Motorcycles and Scooters
# Natural Gas Pipeline
# Natural Gas Power
# Natural Gas Production
# Neoprene Rubber
# Nickel
# Nickel Production
# Nickel-Based Battery
# Nickel-Metal Hydride Battery
# Nitric Acid
# Nitrogen Fertilizer
# Nitrogenous Fertilizers
# Nox Pollution Controls (Boilers)
# Nuclear Energy
# Nuclear Weapons
# Objects Launched Into Space
# Offshore Wind Energy
# Oil Pipeline
# Oil Production
# Oil Refining Capacity
# Onshore Wind Energy
# PCV3 Vaccine
# POL3 Vaccine
# Paraxylene
# Passenger Cars
# Passenger Vehicles
# Pentaerythritol
# Phenol
# Phosphate Fertilizer
# Phthalic Anhydride
# Podcasting
# Polyester Fiber
# Polystyrene
# Polyvinylchloride
# Postal Traffic
# Potash Fertilizer
# Potassic Fertilizers
# Power Steering
# Primary Aluminum Production
# Primary Bauxite Production
# Primary Copper
# Primary Magnesium
# Processor Performance
# Public Roads
# Pumped Hydro Storage
# Pumped Hydropower
# RCV1 Vaccine
# ROTAC Vaccine
# Radial Tires
# Radio
# Radio Receivers
# Railroad
# Random Access Memory
# Rare Earth Mine Production
# Raw Steel Production
# Real-Time Gross Settlement Adoption
# Refined Copper
# Refrigerators
# Renewable Power
# Running Water
# Salt Production
# Sand and Gravel|Construction
# Sand and Gravel|Industrial
# Sensible Heat Storage
# Shale Production
# Shotgun Sanger DNA Sequencing
# Silver
# Silver Production
# Smartphone Usage
# Social Media Usage
# Sodium
# Sodium Chlorate
# Sodium-Based Battery Storage
# Sodium-Sulphur Battery
# Solar Photovoltaic
# Solar Thermal Energy
# Solid Biofuels
# Soybean Production
# Space Launches
# Stationary Steam Engines
# Steam Locomotives
# Steamships
# Stove
# Styrene
# Submarine Cables
# Sugar Cane Production
# Sugar Output
# Sulphuric Acid
# Synthetic Filament Tow and Staple Fibers
# Synthetic Filament Yarn
# Tablet
# Telegraph Traffic
# Telephones
# Telephones and Videophones
# Television
# Television Receivers
# Tin
# Tin Production
# Titanium Sponge
# Transistors per Microprocessor
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Urea
# Vacuum Cleaners
# Vacuums
# Vanadium Redox-Flow Battery
# Videocassette Recorder
# Vinyl Acetate
# Vinyl Chloride
# Washing Machines
# Water Heater
# Wet Flue Gas Desulfurization Systems
# YFV Vaccine
# Zinc
# Zinc Production
# Zinc-Based Battery

# %%
len(tech_list)
# Out:
# 252

# %%
print(len(list(set(all_tech['Unit']))))
sorted(list(set(all_tech['Unit'])))
# Out:
# 58
# ['%',
#  '-',
#  '2022 USD',
#  '2022 USD/MW',
#  '2022 USD/barrel',
#  '2022 USD/gal',
#  '2022 USD/kW',
#  '2022 USD/kWh',
#  '2022 USD/lb',
#  '2022 USD/metric ton',
#  '2022 USD/tonne',
#  'GB/month',
#  'GW',
#  'GWe',
#  'GWh',
#  'Gbase',
#  'Hz',
#  'MW',
#  'MWt',
#  'TWh',
#  'Thousand 2022 USD/kg',
#  'USD/kilobase',
#  'USD/megabase',
#  'USD/metric ton',
#  'USD/million Btu',
#  'billion barrels',
#  'billion cubic feet',
#  'billion cubic metres',
#  'billion pounds',
#  'bits/2022 USD',
#  'bits/second',
#  'calculations per second/thousand USD',
#  'cumulative acres planted',
#  'kW',
#  'kWh',
#  'kilobase',
#  'kilometers',
#  'metric tons',
#  'miles',
#  'million USD/unit',
#  'million cubic meters/day',
#  'million gallons',
#  'million instructions/second',
#  'million metric tons',
#  'million pounds',
#  'million tons',
#  'net tons',
#  'no. of transistors/chip',
#  'petajoules',
#  'short tons',
#  'thousand USD/hectolitre',
#  'thousand USD/metric ton',
#  'thousand USD/unit',
#  'thousand barrels/day',
#  'thousand hectolitres',
#  'thousand metric tons',
#  'thousand tons',
#  'thousand tons of nitrogen equivalent']

# %%
tech_us_global = {}
for tech in tech_list:
    country_names = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    country_codes = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Code']))
    if 'World' in country_names or 'US' in country_codes:
        tech_us_global[tech] = 'x'
    else:
        tech_us_global[tech] = ''
        
for entry in tech_us_global:
    if tech_us_global[entry] == '':
        print(entry)
# Out:
# Air Conditioning Machines
# BCG Vaccine
# Beer
# Bicycles and Other Cycles
# Cars
# Caustic Soda
# Corn Production
# Cotton Seed Production
# Cow's Milk Production
# Gold
# Household Refrigerators and Freezers
# Hydrogen Storage
# Liquefied Natural Gas (LNG)
# Motorcycles and Scooters
# Nitrogenous Fertilizers
# Potassic Fertilizers
# Radio Receivers
# Refined Copper
# Silver
# Soybean Production
# Steamships
# Sugar Cane Production
# Synthetic Filament Tow and Staple Fibers
# Synthetic Filament Yarn
# Telephones and Videophones
# Television Receivers
# Tin
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Vacuum Cleaners
# YFV Vaccine

# %%
tech_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    tech_country_dict[tech] = countries
for country in tech_country_dict:
    country_list = tech_country_dict[country]
tech_country_dict
# Out:
# {'Acrylic Fiber': ['World'],
#  'Acrylonitrile': ['World'],
#  'Air Conditioning Machines': ['Sudan',
#   'Portugal',
#   'United Kingdom',
#   'Uzbekistan',
#   'Bulgaria',
#   'Sweden',
#   'Poland',
#   'Estonia',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Slovenia',
#   'Mexico',
#   'Lithuania',
#   'Germany',
#   'Netherlands',
#   'Czechia',
#   'Nigeria',
#   'Ecuador',
#   'Bosnia and Herzegovina',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Ireland',
#   'Finland',
#   'Greece',
#   'Egypt',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Iraq',
#   'Croatia',
#   'Spain',
#   'Italy',
#   'Japan',
#   'Denmark'],
#  'Air-Source Heat Pumps': ['United States'],
#  'Amazon Prime Users': ['United States'],
#  'Ammonia Synthesis': ['France',
#   'Poland',
#   'Sweden',
#   'World',
#   'USSR',
#   'Germany',
#   'Italy',
#   'Canada',
#   'Belgium',
#   'Netherlands',
#   'Japan',
#   'USA',
#   'Czechoslovakia'],
#  'Aniline': ['World'],
#  'Aquaculture Production': ['Austria',
#   'French Polynesia',
#   'Tuvalu',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'American Samoa',
#   'Cameroon',
#   'Faroe Islands',
#   'Nepal',
#   'Uganda',
#   'Switzerland',
#   'Turkiye',
#   'Korea, Rep.',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Thailand',
#   'Burundi',
#   'Moldova',
#   'Samoa',
#   'Palau',
#   'China',
#   'Zambia',
#   'Vanuatu',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'New Caledonia',
#   'Cambodia',
#   'Algeria',
#   'Gabon',
#   'Tajikistan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'Eswatini',
#   'Norway',
#   'Northern Mariana Islands',
#   'South Sudan',
#   'Ukraine',
#   'Yemen, Rep.',
#   'Haiti',
#   'Equatorial Guinea',
#   'Solomon Islands',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Guam',
#   'Russian Federation',
#   'Malta',
#   'Bolivia',
#   'Senegal',
#   'Cabo Verde',
#   'Georgia',
#   'Germany',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Libya',
#   'Slovak Republic',
#   'Fiji',
#   'Colombia',
#   'Tunisia',
#   'Kuwait',
#   'Turks and Caicos Islands',
#   'Honduras',
#   'Italy',
#   'Virgin Islands (U.S.)',
#   'Burkina Faso',
#   'Aruba',
#   'Congo, Dem. Rep.',
#   'Nicaragua',
#   'Philippines',
#   'Bahrain',
#   'Iran, Islamic Rep.',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'St. Lucia',
#   'Sudan',
#   'British Virgin Islands',
#   'Belize',
#   'Portugal',
#   'St. Vincent and the Grenadines',
#   'Singapore',
#   'Congo, Rep.',
#   'Canada',
#   'West Bank and Gaza',
#   'Venezuela, RB',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'Lao PDR',
#   'Slovenia',
#   'Montenegro',
#   'Indonesia',
#   'Mozambique',
#   'Micronesia, Fed. Sts.',
#   'Barbados',
#   'Gambia, The',
#   'Jamaica',
#   'Afghanistan',
#   'Dominica',
#   'Seychelles',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Pakistan',
#   'Kazakhstan',
#   'Rwanda',
#   'Turkmenistan',
#   'Ghana',
#   'United Arab Emirates',
#   'Spain',
#   'Marshall Islands',
#   'Dominican Republic',
#   "Korea, Dem. People's Rep.",
#   'Madagascar',
#   'Nauru',
#   'Timor-Leste',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'World',
#   'Kyrgyz Republic',
#   'United States',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Kiribati',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'St. Kitts and Nevis',
#   'Lesotho',
#   'Czechia',
#   'Bahamas, The',
#   'Mauritius',
#   'Albania',
#   'Niger',
#   'Bosnia and Herzegovina',
#   'North Macedonia',
#   'Curacao',
#   'Tonga',
#   'Guinea-Bissau',
#   'Puerto Rico',
#   'Trinidad and Tobago',
#   'Benin',
#   'Cyprus',
#   'Hong Kong SAR, China',
#   'Hungary',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   "Cote d'Ivoire",
#   'Croatia',
#   'Uruguay',
#   'Belarus',
#   'Sri Lanka',
#   'Morocco',
#   'Tanzania',
#   'Papua New Guinea',
#   'Botswana',
#   'Syrian Arab Republic',
#   'Vietnam',
#   'Egypt, Arab Rep.',
#   'El Salvador',
#   'Myanmar',
#   'Jordan',
#   'Grenada',
#   'Serbia',
#   'South Africa'],
#  'Artificial and Synthetic Fibers': ['Australia',
#   'Austria',
#   'United Kingdom',
#   'West Germany',
#   'Belgium',
#   'Sweden',
#   'Canada',
#   'Poland',
#   'India',
#   'United States of America',
#   'Brazil',
#   'Romania',
#   'Switzerland',
#   'Yugoslavia',
#   'Mexico',
#   'Indonesia',
#   'Netherlands',
#   'Iran',
#   'Germany',
#   'Thailand',
#   'Czechoslovakia',
#   'Argentina',
#   'Turkey',
#   'Malaysia',
#   'Russia',
#   'China',
#   'Finland',
#   'East Germany',
#   'Phillipines',
#   'Colombia',
#   'France',
#   'Pakistan',
#   'Egypt',
#   'Spain',
#   'South Korea',
#   'Italy',
#   'Japan',
#   'Norway',
#   'South Africa'],
#  'Automatic Transmission': ['United States'],
#  'BCG Vaccine': ['Austria',
#   'Saint Kitts and Nevis',
#   'Tuvalu',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Cameroon',
#   'Nepal',
#   "Democratic People's Republic of Korea",
#   'Uganda',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Thailand',
#   'Mauritania',
#   'Burundi',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'China',
#   'Zambia',
#   'Vanuatu',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Iraq',
#   'Azerbaijan',
#   'Guinea',
#   'Türkiye',
#   'Cambodia',
#   'Algeria',
#   'Gabon',
#   'Tajikistan',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Namibia',
#   'Eswatini',
#   'Ukraine',
#   'South Sudan',
#   'Yemen',
#   'Haiti',
#   'Equatorial Guinea',
#   'Solomon Islands',
#   'Sao Tome and Principe',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Russian Federation',
#   'Malta',
#   'Senegal',
#   'Cabo Verde',
#   'Georgia',
#   'Guyana',
#   'Argentina',
#   'Ireland',
#   'Libya',
#   'Fiji',
#   'Colombia',
#   'Niue',
#   'Tunisia',
#   'Kuwait',
#   'Comoros',
#   'Honduras',
#   'Burkina Faso',
#   'State of Palestine',
#   'Nicaragua',
#   'Philippines',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Sudan',
#   'Republic of Moldova',
#   'Belize',
#   'Portugal',
#   'Saint Lucia',
#   'Singapore',
#   'Republic of North Macedonia',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'Slovenia',
#   'Montenegro',
#   'Indonesia',
#   'Mozambique',
#   'Viet Nam',
#   'Jamaica',
#   'Afghanistan',
#   'Gambia',
#   'Dominica',
#   'Seychelles',
#   'Israel',
#   'Finland',
#   'Republic of Korea',
#   'Egypt',
#   'Kazakhstan',
#   'Pakistan',
#   'Rwanda',
#   'Turkmenistan',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Marshall Islands',
#   'Dominican Republic',
#   'Madagascar',
#   'Cook Islands',
#   'Mongolia',
#   'Nauru',
#   'Timor-Leste',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'Uzbekistan',
#   'Kiribati',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United Republic of Tanzania',
#   'Saint Vincent and the Grenadines',
#   'Monaco',
#   'Lesotho',
#   'Venezuela (Bolivarian Republic of)',
#   'Czechia',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Djibouti',
#   'Bosnia and Herzegovina',
#   'Tonga',
#   'Guinea-Bissau',
#   'Slovakia',
#   'Benin',
#   'Hungary',
#   'Latvia',
#   'Malaysia',
#   'Micronesia (Federated States of)',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   "Cote d'Ivoire",
#   'Maldives',
#   'Croatia',
#   'Congo',
#   'Belarus',
#   'Uruguay',
#   "Lao People's Democratic Republic",
#   'Sri Lanka',
#   'Morocco',
#   'Papua New Guinea',
#   'Botswana',
#   'Syrian Arab Republic',
#   'El Salvador',
#   'Myanmar',
#   'Jordan',
#   'Democratic Republic of the Congo',
#   'Serbia',
#   'South Africa'],
#  'Beer': ['Austria',
#   'The former Yugoslav Republic of Macedonia',
#   'Portugal',
#   'Panama',
#   'United Kingdom',
#   'Belgium',
#   'Canada',
#   'Bulgaria',
#   'Sweden',
#   'Chad',
#   'Uzbekistan',
#   'Nepal',
#   'Estonia',
#   'India',
#   'Poland',
#   'Chile',
#   'Brazil',
#   'Peru',
#   'Romania',
#   'Uganda',
#   'Slovenia',
#   'United Republic of Tanzania',
#   'Montenegro',
#   'Mexico',
#   'Lithuania',
#   'Germany',
#   'Georgia',
#   'Czechia',
#   'Mozambique',
#   'Ecuador',
#   'Albania',
#   'Netherlands',
#   'Nigeria',
#   'Bosnia and Herzegovina',
#   'Slovakia',
#   'Cyprus',
#   'Hungary',
#   'Turkey',
#   'Latvia',
#   'Ireland',
#   'Bolivia (Plurinational State of)',
#   'Kenya',
#   'Finland',
#   'Greece',
#   'France',
#   'Egypt',
#   'Azerbaijan',
#   'Croatia',
#   'Congo',
#   'Uruguay',
#   'Spain',
#   'Dominican Republic',
#   'Madagascar',
#   'Italy',
#   'Mongolia',
#   'Burkina Faso',
#   'Denmark',
#   'Norway',
#   'Serbia',
#   'Zimbabwe'],
#  'Beer Production': ['Austria',
#   'Kyrgistan',
#   'New Zealand',
#   'Sweden',
#   'Bulgaria',
#   'Angola',
#   'Cameroon',
#   'Ivory Coast',
#   'UK',
#   'Venezuela',
#   'Switzerland',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Thailand',
#   'Ecuador',
#   'Moldova',
#   'Burundi',
#   'Russia',
#   'China',
#   'Zambia',
#   'Costa Rica',
#   'France',
#   'Azerbaijan',
#   'Algeria',
#   'Gabon',
#   'Tajikistan',
#   'Macedonia',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Ukraine',
#   'Norway',
#   'Panama',
#   'West Germany',
#   'Bolivia',
#   'Germany',
#   'Georgia',
#   'USA',
#   'Argentina',
#   'Ireland',
#   'Colombia',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'Nicaragua',
#   'Philippines',
#   'Armenia',
#   'Australia',
#   'Czech Republic',
#   'Portugal',
#   'Singapore',
#   'Canada',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Slovenia',
#   'Yugoslavia',
#   'Indonesia',
#   'Mozambique',
#   'Jamaica',
#   'Israel',
#   'Finland',
#   'Turkmenistan',
#   'Egypt',
#   'Rwanda',
#   'Kazakhstan',
#   'Ghana',
#   'Korea',
#   'Spain',
#   'Dominican Republic',
#   'Southern Vietnam',
#   'Zimbabwe',
#   'Belgium',
#   'Uzbekistan',
#   'Estonia',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Czechoslovakia',
#   'Zaire',
#   'Hungary',
#   'Turkey',
#   'Latvia',
#   'Malaysia',
#   'Kenya',
#   'East Germany',
#   'Malawi',
#   'Croatia',
#   'Uruguay',
#   'Congo',
#   'Belarus',
#   'Tanzania',
#   'Morocco',
#   'Vietnam',
#   'El Salvador',
#   'Serbia',
#   'South Africa'],
#  'Benzene': ['World'],
#  'Bicycles': ['World'],
#  'Bicycles and Other Cycles': ['Bangladesh',
#   'Portugal',
#   'United Kingdom',
#   'Belgium',
#   'Canada',
#   'Bulgaria',
#   'Sweden',
#   'Uzbekistan',
#   'Poland',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Mexico',
#   'Lithuania',
#   'Germany',
#   'Netherlands',
#   'Czechia',
#   'Ecuador',
#   'Bosnia and Herzegovina',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Ireland',
#   'Finland',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Iraq',
#   'Croatia',
#   'Spain',
#   'El Salvador',
#   'Italy',
#   'Japan',
#   'Denmark',
#   'Serbia'],
#  'Bioenergy': ['World'],
#  'Biofuels Production': ['Australia',
#   'Austria',
#   'Portugal',
#   'United Kingdom',
#   'Canada',
#   'Belgium',
#   'Sweden',
#   'Poland',
#   'India',
#   'Brazil',
#   'Mexico',
#   'Indonesia',
#   'Germany',
#   'Netherlands',
#   'Thailand',
#   'US',
#   'Argentina',
#   'China',
#   'Finland',
#   'Colombia',
#   'France',
#   'Spain',
#   'South Korea',
#   'Italy'],
#  'Biogas': ['Austria',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Faroe Islands',
#   'Switzerland',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Ecuador',
#   'Thailand',
#   'Réunion',
#   'Samoa',
#   'Luxembourg',
#   'Bolivia (Plurinational State of)',
#   'China',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Türkiye',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Norway',
#   'Ukraine',
#   'Panama',
#   'Malta',
#   'Germany',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Colombia',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'State of Palestine',
#   'Philippines',
#   'Armenia',
#   'Australia',
#   'Republic of Moldova',
#   'Portugal',
#   'Canada',
#   'Republic of North Macedonia',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'United States of America',
#   'Slovenia',
#   'Indonesia',
#   'Viet Nam',
#   'Israel',
#   'Finland',
#   'Republic of Korea',
#   'Egypt',
#   'Kazakhstan',
#   'Pakistan',
#   'Ghana',
#   'United Arab Emirates',
#   'Spain',
#   'Guadeloupe',
#   'Belgium',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United Republic of Tanzania',
#   'Czechia',
#   'Mauritius',
#   'Martinique',
#   'Chinese Taipei',
#   'Bosnia and Herzegovina',
#   'Slovakia',
#   'Puerto Rico',
#   'Cyprus',
#   'Hungary',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Kenya',
#   'Croatia',
#   'Uruguay',
#   'Belarus',
#   'Sri Lanka',
#   'Morocco',
#   'Syrian Arab Republic',
#   'El Salvador',
#   'Jordan',
#   'Serbia',
#   'South Africa'],
#  'BisphenolA': ['World'],
#  'CFLs': ['World'],
#  'Cable TV': ['United States'],
#  'Cadmium Refining': ['Australia',
#   'World',
#   'Austria',
#   'Germany: Eastern states',
#   'United States',
#   'Korea, Republic of',
#   'United Kingdom',
#   'Belgium',
#   'Canada',
#   'Bulgaria',
#   'Congo (Kinshasa)',
#   'Poland',
#   'India',
#   'Peru',
#   'Brazil',
#   'Romania',
#   'Germany: Western states',
#   'U.S.S.R.',
#   'Mexico',
#   'Yugoslavia',
#   'Germany',
#   'Netherlands',
#   'Thailand',
#   'Serbia and Montenegro',
#   'Argentina',
#   'Turkey',
#   'Russia',
#   'China',
#   'Finland',
#   'France',
#   'Kazakhstan',
#   'Algeria',
#   'Spain',
#   'Korea, North',
#   'Macedonia',
#   'Ukraine',
#   'Italy',
#   'Japan',
#   'Namibia',
#   'Norway',
#   'South Africa'],
#  'Canals': ['United States'],
#  'Capillary DNA Sequencing': ['World'],
#  'Caprolactam': ['World'],
#  'Capture Fisheries': ['Gibraltar',
#   'Austria',
#   'French Polynesia',
#   'Macao SAR, China',
#   'Tuvalu',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'American Samoa',
#   'Cameroon',
#   'Faroe Islands',
#   'Nepal',
#   'Uganda',
#   'Switzerland',
#   'Turkiye',
#   'Korea, Rep.',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Thailand',
#   'Mauritania',
#   'Burundi',
#   'Moldova',
#   'Samoa',
#   'Luxembourg',
#   'Palau',
#   'China',
#   'Zambia',
#   'Vanuatu',
#   'Andorra',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'New Caledonia',
#   'Cambodia',
#   'Algeria',
#   'Gabon',
#   'Tajikistan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'Eswatini',
#   'Norway',
#   'Northern Mariana Islands',
#   'South Sudan',
#   'Ukraine',
#   'Yemen, Rep.',
#   'San Marino',
#   'St. Martin (French part)',
#   'Haiti',
#   'Equatorial Guinea',
#   'Solomon Islands',
#   'Sao Tome and Principe',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Guam',
#   'Russian Federation',
#   'Malta',
#   'Bolivia',
#   'Senegal',
#   'Cabo Verde',
#   'Georgia',
#   'Germany',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'St. Lucia',
#   'Libya',
#   'Slovak Republic',
#   'Fiji',
#   'Colombia',
#   'Tunisia',
#   'Kuwait',
#   'Comoros',
#   'Turks and Caicos Islands',
#   'Honduras',
#   'Italy',
#   'Virgin Islands (U.S.)',
#   'Burkina Faso',
#   'Aruba',
#   'Congo, Dem. Rep.',
#   'Nicaragua',
#   'Philippines',
#   'Bahrain',
#   'Iran, Islamic Rep.',
#   'Armenia',
#   'Bermuda',
#   'Bangladesh',
#   'Australia',
#   'Central African Republic',
#   'Sudan',
#   'British Virgin Islands',
#   'Belize',
#   'Portugal',
#   'St. Vincent and the Grenadines',
#   'Singapore',
#   'Congo, Rep.',
#   'Canada',
#   'West Bank and Gaza',
#   'Venezuela, RB',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'Lao PDR',
#   'Slovenia',
#   'Montenegro',
#   'Indonesia',
#   'Mozambique',
#   'Isle of Man',
#   'Greenland',
#   'Micronesia, Fed. Sts.',
#   'Barbados',
#   'Gambia, The',
#   'Jamaica',
#   'Afghanistan',
#   'Dominica',
#   'Seychelles',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Liechtenstein',
#   'Pakistan',
#   'Kazakhstan',
#   'Rwanda',
#   'Turkmenistan',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Spain',
#   'Marshall Islands',
#   'Dominican Republic',
#   "Korea, Dem. People's Rep.",
#   'Madagascar',
#   'Mongolia',
#   'Nauru',
#   'Cayman Islands',
#   'Timor-Leste',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'World',
#   'Kyrgyz Republic',
#   'United States',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Kiribati',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'St. Kitts and Nevis',
#   'Sint Maarten (Dutch part)',
#   'Monaco',
#   'Lesotho',
#   'Czechia',
#   'Bahamas, The',
#   'Mauritius',
#   'Albania',
#   'Djibouti',
#   'Niger',
#   'Bosnia and Herzegovina',
#   'North Macedonia',
#   'Curacao',
#   'Tonga',
#   'Guinea-Bissau',
#   'Puerto Rico',
#   'Trinidad and Tobago',
#   'Benin',
#   'Cyprus',
#   'Hong Kong SAR, China',
#   'Hungary',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   "Cote d'Ivoire",
#   'Maldives',
#   'Croatia',
#   'Uruguay',
#   'Belarus',
#   'Sri Lanka',
#   'Morocco',
#   'Tanzania',
#   'Papua New Guinea',
#   'Botswana',
#   'Syrian Arab Republic',
#   'Vietnam',
#   'Egypt, Arab Rep.',
#   'El Salvador',
#   'Myanmar',
#   'Jordan',
#   'Grenada',
#   'Serbia',
#   'South Africa'],
#  'Carbon Capture and Sequestration': ['World'],
#  'Cars': ['Bangladesh',
#   'Portugal',
#   'United Kingdom',
#   'Uzbekistan',
#   'Sweden',
#   'Poland',
#   'Estonia',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Mexico',
#   'Germany',
#   'Netherlands',
#   'Czechia',
#   'Nigeria',
#   'Ecuador',
#   'Viet Nam',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Ireland',
#   'Bolivia (Plurinational State of)',
#   'Kenya',
#   'Finland',
#   'Egypt',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Uruguay',
#   'Spain',
#   'Japan',
#   'Denmark'],
#  'Caustic Soda': ['Bangladesh',
#   'Portugal',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Sweden',
#   'Poland',
#   'India',
#   'Brazil',
#   'Romania',
#   'Mexico',
#   'Germany',
#   'Netherlands',
#   'Czechia',
#   'Ecuador',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Ireland',
#   'Finland',
#   'Greece',
#   'France',
#   'Egypt',
#   'Azerbaijan',
#   'Iraq',
#   'Croatia',
#   'Spain',
#   'El Salvador',
#   'Italy',
#   'Japan',
#   'Denmark',
#   'Norway'],
#  'Caustic Soda Acid': ['Pakistan',
#   'India',
#   'Australia',
#   'United States of America',
#   'Brazil',
#   'Argentina',
#   'Egypt',
#   'Turkey',
#   'Algeria',
#   'South Korea',
#   'Mexico',
#   'Israel',
#   'Canada',
#   'China',
#   'Japan'],
#  'Cellphones': ['Austria',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Cameroon',
#   'Ivory Coast',
#   'Nepal',
#   'Venezuela',
#   'Uganda',
#   'Switzerland',
#   'Hong Kong',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Thailand',
#   'Ecuador',
#   'Mauritania',
#   'Moldova',
#   'Burundi',
#   'Luxembourg',
#   'Russia',
#   'China',
#   'Zambia',
#   'Costa Rica',
#   'Greece',
#   'Bosnia-Herzegovina',
#   'France',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'Cambodia',
#   'Algeria',
#   'Tajikistan',
#   'Gabon',
#   'Macedonia',
#   'Burma',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'Ukraine',
#   'Norway',
#   'Yemen',
#   'Haiti',
#   'Equatorial Guinea',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Senegal',
#   'Bolivia',
#   'Germany',
#   'Georgia',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Slovak Republic',
#   'Libya',
#   'Colombia',
#   'Republic of the Congo',
#   'Tunisia',
#   'Kuwait',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'Nicaragua',
#   'Philippines',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'Czech Republic',
#   'Sudan',
#   'Belize',
#   'Portugal',
#   'Swaziland',
#   'Singapore',
#   'Canada',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Slovenia',
#   'Indonesia',
#   'Mozambique',
#   'Iran',
#   'Gambia',
#   'Afghanistan',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Pakistan',
#   'Egypt',
#   'Kazakhstan',
#   'Turkmenistan',
#   'Rwanda',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Spain',
#   'Dominican Republic',
#   'Madagascar',
#   'Mongolia',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'World',
#   'United States',
#   'Syria',
#   'Belgium',
#   'Uzbekistan',
#   'United Kingdom',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Lesotho',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Laos',
#   'Guinea-Bissau',
#   'Benin',
#   'Lebanon',
#   'Turkey',
#   'Hungary',
#   'Latvia',
#   'Malaysia',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   'Croatia',
#   'Uruguay',
#   'Belarus',
#   'Sri Lanka',
#   'Morocco',
#   'Tanzania',
#   'South Korea',
#   'Botswana',
#   'Papua New Guinea',
#   'Vietnam',
#   'El Salvador',
#   'Jordan',
#   'Democratic Republic of the Congo',
#   'South Africa'],
#  'Cement': ['United States', 'World'],
#  'Central Heating': ['United States'],
#  'Coal Power': ['World'],
#  'Coal Production': ['North America',
#   'Australia',
#   'Czech Republic',
#   'World',
#   'United Kingdom',
#   'Canada',
#   'Uzbekistan',
#   'Bulgaria',
#   'New Zealand',
#   'Poland',
#   'Venezuela',
#   'India',
#   'Brazil',
#   'Romania',
#   'Russian Federation',
#   'Mexico',
#   'Indonesia',
#   'Germany',
#   'Europe',
#   'Thailand',
#   'US',
#   'Hungary',
#   'Turkey',
#   'USSR',
#   'China',
#   'Rest of World',
#   'Greece',
#   'Colombia',
#   'Pakistan',
#   'Kazakhstan',
#   'Spain',
#   'Asia',
#   'South Korea',
#   'Vietnam',
#   'Mongolia',
#   'Japan',
#   'Ukraine',
#   'Serbia',
#   'South Africa',
#   'Zimbabwe'],
#  'Cobalt': ['United States', 'World'],
#  'Colour TV': ['United States'],
#  'Combined Refrigerators-Freezers': ['Portugal',
#   'United Kingdom',
#   'Uzbekistan',
#   'Sweden',
#   'Poland',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United States of America',
#   'Mexico',
#   'Lithuania',
#   'Bosnia and Herzegovina',
#   'Hungary',
#   'Finland',
#   'Egypt',
#   'Iran (Islamic Republic of)',
#   'Iraq',
#   'Spain',
#   'Italy',
#   'Japan',
#   'Denmark'],
#  'Compact Fluorescent Light Bulbs': ['World'],
#  'Compressed Air Energy Storage': ['Switzerland',
#   'United States',
#   'Germany',
#   'Netherlands',
#   'United Kingdom',
#   'China',
#   'Canada'],
#  'Computing Growth': ['World'],
#  'Concentrated Solar Power': ['World'],
#  'Concentrating Solar Power': ['World'],
#  'Copper|Mining': ['Australia',
#   'Saudi Arabia',
#   'World',
#   'United States',
#   'Portugal',
#   'Korea, Republic of',
#   'United Kingdom',
#   'Canada',
#   'Congo (Kinshasa)',
#   'Bulgaria',
#   'Sweden',
#   'Uzbekistan',
#   'Yugoslavia',
#   'Nepal',
#   'Oman',
#   'Cuba',
#   'India',
#   'Chile',
#   'Brazil',
#   'Peru',
#   'Poland',
#   'Romania',
#   'U.S.S.R.',
#   'Bolivia',
#   'Mexico',
#   'Indonesia',
#   'Germany',
#   'Georgia',
#   'Iran',
#   'Mozambique',
#   'Ecuador',
#   'Albania',
#   'Laos',
#   'Czechoslovakia',
#   'Mauritania',
#   'Serbia and Montenegro',
#   'Slovakia',
#   'Argentina',
#   'Cyprus',
#   'Zimbabwe',
#   'Turkey',
#   'Malaysia',
#   'Russia',
#   'China',
#   'Finland',
#   'Zambia',
#   'Colombia',
#   'France',
#   'Pakistan',
#   'Kazakhstan',
#   'Tanzania',
#   'Morocco',
#   'Korea, North',
#   'Dominican Republic',
#   'Macedonia',
#   'Botswana',
#   'Burma',
#   'Papua New Guinea',
#   'Honduras',
#   'Mongolia',
#   'Spain',
#   'Vietnam',
#   'Japan',
#   'Namibia',
#   'Philippines',
#   'Norway',
#   'Serbia',
#   'South Africa',
#   'Armenia'],
#  'Copper|Refining': ['Australia',
#   'Czech Republic',
#   'Austria',
#   'World',
#   'Taiwan',
#   'Portugal',
#   'Korea, Republic of',
#   'United States',
#   'United Kingdom',
#   'Belgium',
#   'Canada',
#   'Bulgaria',
#   'Congo (Kinshasa)',
#   'Sweden',
#   'Uzbekistan',
#   'Oman',
#   'Poland',
#   'India',
#   'Chile',
#   'Brazil',
#   'Peru',
#   'Romania',
#   'U.S.S.R.',
#   'Mexico',
#   'Yugoslavia',
#   'Indonesia',
#   'Germany',
#   'Iran',
#   'Thailand',
#   'Albania',
#   'Laos',
#   'Czechoslovakia',
#   'Serbia and Montenegro',
#   'Slovakia',
#   'Argentina',
#   'Cyprus',
#   'Hungary',
#   'Turkey',
#   'Russia',
#   'China',
#   'Finland',
#   'Zambia',
#   'France',
#   'Egypt',
#   'Kazakhstan',
#   'Spain',
#   'Korea, North',
#   'Burma',
#   'Ukraine',
#   'Vietnam',
#   'Italy',
#   'Mongolia',
#   'Japan',
#   'Philippines',
#   'Norway',
#   'Serbia',
#   'South Africa',
#   'Zimbabwe'],
#  'Corn Production': ['Austria',
#   'New Zealand',
#   'Bulgaria',
#   'Angola',
#   'Cameroon',
#   'Nepal',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Mauritania',
#   'Burundi',
#   'Luxembourg',
#   'Bolivia (Plurinational State of)',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Iraq',
#   'Azerbaijan',
#   'Guinea',
#   'New Caledonia',
#   'Cambodia',
#   'Algeria',
#   "Côte d'Ivoire",
#   'Kyrgyzstan',
#   'Namibia',
#   'Haiti',
#   'Mali',
#   'Netherlands (Kingdom of the)',
#   'Cabo Verde',
#   'Georgia',
#   'Germany',
#   'Argentina',
#   'Fiji',
#   'Colombia',
#   'Kuwait',
#   'Comoros',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'Nicaragua',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'Belize',
#   'Canada',
#   'Bhutan',
#   'Indonesia',
#   'Mozambique',
#   'Jamaica',
#   'Gambia',
#   'Israel',
#   'Egypt',
#   'Kazakhstan',
#   'Ghana',
#   'Dominican Republic',
#   'Madagascar',
#   'Eritrea',
#   'Chad',
#   'India',
#   'Chile',
#   'Brazil',
#   'Lesotho',
#   'Czechia',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Bosnia and Herzegovina',
#   'North Macedonia',
#   'Guinea-Bissau',
#   'Benin',
#   'Hungary',
#   'Lebanon',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Croatia',
#   'Congo',
#   'Belarus',
#   "Lao People's Democratic Republic",
#   'Morocco',
#   'Botswana',
#   'El Salvador',
#   'Jordan',
#   'Grenada',
#   'China, mainland'],
#  'Cotton Seed Production': ['Egypt',
#   'India',
#   'Azerbaijan',
#   'Iran (Islamic Republic of)',
#   'Burundi',
#   'Gambia',
#   'Morocco',
#   'Dominican Republic',
#   "Côte d'Ivoire",
#   'Mali',
#   'Bolivia (Plurinational State of)',
#   'El Salvador',
#   'Israel',
#   'Nigeria',
#   'Kenya',
#   'Nicaragua',
#   'China, mainland'],
#  "Cow's Milk Production": ['Austria',
#   'French Polynesia',
#   'New Zealand',
#   'Bulgaria',
#   'Angola',
#   'Cameroon',
#   'Nepal',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Mauritania',
#   'Burundi',
#   'Luxembourg',
#   'Bolivia (Plurinational State of)',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'New Caledonia',
#   'Algeria',
#   "Côte d'Ivoire",
#   'Kyrgyzstan',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'Mali',
#   'Netherlands (Kingdom of the)',
#   'Malta',
#   'Cabo Verde',
#   'Georgia',
#   'Germany',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Fiji',
#   'Colombia',
#   'Kuwait',
#   'Comoros',
#   'Honduras',
#   'Italy',
#   'Nicaragua',
#   'Bahrain',
#   'Armenia',
#   'Bangladesh',
#   'Australia',
#   'Belize',
#   'Canada',
#   'Bhutan',
#   'Indonesia',
#   'Mozambique',
#   'China, Hong Kong SAR',
#   'Barbados',
#   'Jamaica',
#   'Gambia',
#   'Israel',
#   'Finland',
#   'Egypt',
#   'Kazakhstan',
#   'Dominican Republic',
#   'Mongolia',
#   'Eritrea',
#   'Belgium',
#   'Chad',
#   'Estonia',
#   'India',
#   'Chile',
#   'Brazil',
#   'Lesotho',
#   'Czechia',
#   'Mauritius',
#   'Albania',
#   'Bosnia and Herzegovina',
#   'North Macedonia',
#   'Guinea-Bissau',
#   'Cyprus',
#   'Hungary',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Kenya',
#   'Croatia',
#   'Belarus',
#   "Lao People's Democratic Republic",
#   'Morocco',
#   'Botswana',
#   'El Salvador',
#   'Jordan',
#   'Grenada',
#   'China, mainland'],
#  'Crop Harvester': ['Austria',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Ivory Coast',
#   'Venezuela',
#   'Uganda',
#   'Switzerland',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Ethiopia',
#   'Thailand',
#   'Ecuador',
#   'Mauritania',
#   'Moldova',
#   'Burundi',
#   'Russia',
#   'China',
#   'Zambia',
#   'Costa Rica',
#   'Greece',
#   'Bosnia-Herzegovina',
#   'France',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'Cambodia',
#   'Algeria',
#   'Tajikistan',
#   'Macedonia',
#   'Burma',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Japan',
#   'Denmark',
#   'Ukraine',
#   'Norway',
#   'Yemen',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Senegal',
#   'Bolivia',
#   'Germany',
#   'Georgia',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Slovak Republic',
#   'Libya',
#   'Colombia',
#   'Republic of the Congo',
#   'Tunisia',
#   'Italy',
#   'Philippines',
#   'Armenia',
#   'Central African Republic',
#   'Australia',
#   'Czech Republic',
#   'Sudan',
#   'Belize',
#   'Portugal',
#   'Canada',
#   'Poland',
#   'Cuba',
#   'Slovenia',
#   'Indonesia',
#   'Iran',
#   'Gambia',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Pakistan',
#   'Egypt',
#   'Kazakhstan',
#   'Turkmenistan',
#   'Ghana',
#   'United Arab Emirates',
#   'Spain',
#   'Madagascar',
#   'Mongolia',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'United States',
#   'Syria',
#   'Belgium',
#   'Uzbekistan',
#   'United Kingdom',
#   'Chad',
#   'Estonia',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Lesotho',
#   'Albania',
#   'Czechoslovakia',
#   'Hungary',
#   'Lebanon',
#   'Turkey',
#   'Latvia',
#   'Kenya',
#   'Croatia',
#   'Uruguay',
#   'Belarus',
#   'Sri Lanka',
#   'Morocco',
#   'South Korea',
#   'Papua New Guinea',
#   'Vietnam',
#   'Botswana',
#   'El Salvador',
#   'Jordan',
#   'South Africa'],
#  'Crude Oil': ['World'],
#  'Crude Petroleum': ['Australia',
#   'Saudi Arabia',
#   'Austria',
#   'Democratic Republic of Congo',
#   'Taiwan',
#   'Syria',
#   'West Germany',
#   'New Zealand',
#   'Canada',
#   'Angola',
#   'Yugoslavia',
#   'Cameroon',
#   'Ivory Coast',
#   'Oman',
#   'Venezuela',
#   'Cuba',
#   'Poland',
#   'UK',
#   'Brazil',
#   'Romania',
#   'Qatar',
#   'UAE',
#   'Chile',
#   'Trinidad & Tobago',
#   'Peru',
#   'India',
#   'Bolivia',
#   'Mexico',
#   'Indonesia',
#   'Germany',
#   'Iran',
#   'Netherlands',
#   'Nigeria',
#   'Thailand',
#   'Ecuador',
#   'USA',
#   'Argentina',
#   'Hungary',
#   'Turkey',
#   'Russia',
#   'Israel',
#   'China',
#   'Libya',
#   'Colombia',
#   'Republic of the Congo',
#   'Pakistan',
#   'Egypt',
#   'Tunisia',
#   'Iraq',
#   'Kuwait',
#   'Algeria',
#   'Gabon',
#   'Morocco',
#   'Italy',
#   'Myanmar',
#   'Japan',
#   'Brunei',
#   'Philippines',
#   'Norway',
#   'Bahrain'],
#  'Cyclohexane': ['World'],
#  'DNA Sequencing (All Methods)': ['World'],
#  'DTP1 Vaccine': ['Austria',
#   'Saint Kitts and Nevis',
#   'Tuvalu',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Cameroon',
#   'Nepal',
#   "Democratic People's Republic of Korea",
#   'Uganda',
#   'Switzerland',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Thailand',
#   'Mauritania',
#   'Burundi',
#   'Samoa',
#   'Luxembourg',
#   'Palau',
#   'Bahamas',
#   'Bolivia (Plurinational State of)',
#   'China',
#   'Zambia',
#   'Vanuatu',
#   'Andorra',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'Türkiye',
#   'Cambodia',
#   'Algeria',
#   'Gabon',
#   'Tajikistan',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'Eswatini',
#   'Norway',
#   'South Sudan',
#   'Ukraine',
#   'San Marino',
#   'Yemen',
#   'Haiti',
#   'Equatorial Guinea',
#   'Solomon Islands',
#   'Sao Tome and Principe',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Russian Federation',
#   'Malta',
#   'Senegal',
#   'Cabo Verde',
#   'Georgia',
#   'Germany',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Libya',
#   'Fiji',
#   'Colombia',
#   'Niue',
#   'Tunisia',
#   'Kuwait',
#   'Comoros',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'State of Palestine',
#   'Nicaragua',
#   'Philippines',
#   'Bahrain',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'Sudan',
#   'Republic of Moldova',
#   'Belize',
#   'Portugal',
#   'Saint Lucia',
#   'Singapore',
#   'Canada',
#   'Republic of North Macedonia',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'Slovenia',
#   'Montenegro',
#   'Indonesia',
#   'Mozambique',
#   'Viet Nam',
#   'Barbados',
#   'Jamaica',
#   'Afghanistan',
#   'Gambia',
#   'Dominica',
#   'Seychelles',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Republic of Korea',
#   'Egypt',
#   'Kazakhstan',
#   'Pakistan',
#   'Rwanda',
#   'Turkmenistan',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Spain',
#   'Marshall Islands',
#   'Dominican Republic',
#   'Madagascar',
#   'Cook Islands',
#   'Mongolia',
#   'Nauru',
#   'Timor-Leste',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'United States',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Kiribati',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United Republic of Tanzania',
#   'Saint Vincent and the Grenadines',
#   'Monaco',
#   'Lesotho',
#   'Venezuela (Bolivarian Republic of)',
#   'Czechia',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Djibouti',
#   'Bosnia and Herzegovina',
#   'Tonga',
#   'Guinea-Bissau',
#   'Slovakia',
#   'Trinidad and Tobago',
#   'Benin',
#   'Cyprus',
#   'Hungary',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Micronesia (Federated States of)',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   "Cote d'Ivoire",
#   'Maldives',
#   'Croatia',
#   'Congo',
#   'Belarus',
#   'Uruguay',
#   "Lao People's Democratic Republic",
#   'Sri Lanka',
#   'Morocco',
#   'Papua New Guinea',
#   'Botswana',
#   'Syrian Arab Republic',
#   'El Salvador',
#   'Myanmar',
#   'Jordan',
#   'Grenada',
#   'Democratic Republic of the Congo',
#   'Serbia',
#   'South Africa'],
#  'DTP3 Vaccine': ['Austria',
#   'Saint Kitts and Nevis',
#   'Tuvalu',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Cameroon',
#   'Nepal',
#   "Democratic People's Republic of Korea",
#   'Uganda',
#   'Switzerland',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Thailand',
#   'Mauritania',
#   'Burundi',
#   'Samoa',
#   'Luxembourg',
#   'Palau',
#   'Bahamas',
#   'Bolivia (Plurinational State of)',
#   'China',
#   'Zambia',
#   'Vanuatu',
#   'Andorra',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'Türkiye',
#   'Cambodia',
#   'Algeria',
#   'Gabon',
#   'Tajikistan',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'Eswatini',
#   'Norway',
#   'South Sudan',
#   'Ukraine',
#   'San Marino',
#   'Yemen',
#   'Haiti',
#   'Equatorial Guinea',
#   'Solomon Islands',
#   'Sao Tome and Principe',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Russian Federation',
#   'Malta',
#   'Senegal',
#   'Cabo Verde',
#   'Georgia',
#   'Germany',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Libya',
#   'Fiji',
#   'Colombia',
#   'Niue',
#   'Tunisia',
#   'Kuwait',
#   'Comoros',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'State of Palestine',
#   'Nicaragua',
#   'Philippines',
#   'Bahrain',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'Sudan',
#   'Republic of Moldova',
#   'Belize',
#   'Portugal',
#   'Saint Lucia',
#   'Singapore',
#   'Canada',
#   'Republic of North Macedonia',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'Slovenia',
#   'Montenegro',
#   'Indonesia',
#   'Mozambique',
#   'Viet Nam',
#   'Barbados',
#   'Jamaica',
#   'Afghanistan',
#   'Gambia',
#   'Dominica',
#   'Seychelles',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Republic of Korea',
#   'Egypt',
#   'Kazakhstan',
#   'Pakistan',
#   'Rwanda',
#   'Turkmenistan',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Spain',
#   'Marshall Islands',
#   'Dominican Republic',
#   'Madagascar',
#   'Cook Islands',
#   'Mongolia',
#   'Nauru',
#   'Timor-Leste',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'United States',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Kiribati',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United Republic of Tanzania',
#   'Saint Vincent and the Grenadines',
#   'Monaco',
#   'Lesotho',
#   'Venezuela (Bolivarian Republic of)',
#   'Czechia',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Djibouti',
#   'Bosnia and Herzegovina',
#   'Tonga',
#   'Guinea-Bissau',
#   'Slovakia',
#   'Trinidad and Tobago',
#   'Benin',
#   'Cyprus',
#   'Hungary',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Micronesia (Federated States of)',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   "Cote d'Ivoire",
#   'Maldives',
#   'Croatia',
#   'Congo',
#   'Belarus',
#   'Uruguay',
#   "Lao People's Democratic Republic",
#   'Sri Lanka',
#   'Morocco',
#   'Papua New Guinea',
#   'Botswana',
#   'Syrian Arab Republic',
#   'El Salvador',
#   'Myanmar',
#   'Jordan',
#   'Grenada',
#   'Democratic Republic of the Congo',
#   'Serbia',
#   'South Africa'],
#  'Desalination Capacity': ['World'],
#  'Dishwashers': ['United States'],
#  'Disk Brakes': ['United States'],
#  'Ebook Reader': ['United States'],
#  'Electric Bicycles': ['China', 'World'],
#  'Electric Range': ['United States'],
#  'Electric Water Heaters and Immersion Heaters': ['The former Yugoslav Republic of Macedonia',
#   'Portugal',
#   'United Kingdom',
#   'Uzbekistan',
#   'Bulgaria',
#   'Sweden',
#   'Poland',
#   'Estonia',
#   'India',
#   'United States of America',
#   'Brazil',
#   'Romania',
#   'Mexico',
#   'Germany',
#   'Netherlands',
#   'Bosnia and Herzegovina',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Ireland',
#   'Finland',
#   'Greece',
#   'Egypt',
#   'Azerbaijan',
#   'Iraq',
#   'Croatia',
#   'Spain',
#   'Italy',
#   'Denmark',
#   'Norway'],
#  'Electricity': ['Austria',
#   'Taiwan',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Venezuela',
#   'Switzerland',
#   'Trinidad & Tobago',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Ecuador',
#   'Thailand',
#   'Luxembourg',
#   'China',
#   'Greece',
#   'France',
#   'Azerbaijan',
#   'Iraq',
#   'Algeria',
#   'Japan',
#   'Denmark',
#   'Ukraine',
#   'Norway',
#   'Oman',
#   'Russian Federation',
#   'Germany',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Colombia',
#   'Kuwait',
#   'Italy',
#   'China Hong Kong SAR',
#   'Philippines',
#   'Bangladesh',
#   'Australia',
#   'Czech Republic',
#   'Portugal',
#   'Singapore',
#   'Canada',
#   'Poland',
#   'Peru',
#   'Slovenia',
#   'Indonesia',
#   'Iran',
#   'US',
#   'Israel',
#   'Finland',
#   'Pakistan',
#   'Kazakhstan',
#   'Turkmenistan',
#   'Egypt',
#   'United Arab Emirates',
#   'Spain',
#   'Saudi Arabia',
#   'World',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'North Macedonia',
#   'Slovakia',
#   'Cyprus',
#   'Hungary',
#   'Turkey',
#   'Latvia',
#   'Malaysia',
#   'Croatia',
#   'Belarus',
#   'Sri Lanka',
#   'Morocco',
#   'South Korea',
#   'Vietnam',
#   'South Africa'],
#  'Electro-Chemical Capacitor': ['Spain',
#   'United States',
#   'Ireland',
#   'South Korea',
#   'Italy',
#   'China'],
#  'Electronic Ignition': ['United States'],
#  'Ethanol': ['World'],
#  'Ethanolamine': ['World'],
#  'Ethylene': ['World'],
#  'Ethylene Glycol': ['World'],
#  'Flow Battery Storage': ['Australia',
#   'Czech Republic',
#   'Austria',
#   'United States',
#   'Portugal',
#   'French Polynesia',
#   'United Kingdom',
#   'Canada',
#   'New Zealand',
#   'India',
#   'Switzerland',
#   'Slovenia',
#   'Indonesia',
#   'Germany',
#   'Netherlands',
#   'Russia',
#   'Antigua and Barbuda',
#   'Israel',
#   'China',
#   'Kazakhstan',
#   'South Korea',
#   'Italy',
#   'Japan',
#   'Denmark',
#   'South Africa'],
#  'Flue Gas Desulphurization (Wet and Dry)': ['World'],
#  'Fluid Catalytic Cracking Refineries': ['US', 'World'],
#  'Flush Toilet': ['United States'],
#  'Flywheel Battery Storage': ['France',
#   'Australia',
#   'Czech Republic',
#   'Antarctica',
#   'Romania',
#   'Spain',
#   'United States',
#   'Ireland',
#   'South Korea',
#   'Mexico',
#   'Germany',
#   'United Kingdom',
#   'Canada',
#   'Netherlands',
#   'Kenya'],
#  'Formaldehyde': ['World'],
#  'Freezer': ['United States'],
#  'Geothermal Energy': ['Australia',
#   'Austria',
#   'World',
#   'Portugal',
#   'New Zealand',
#   'Chile',
#   'United States of America',
#   'Romania',
#   'Russian Federation',
#   'Guatemala',
#   'Mexico',
#   'Indonesia',
#   'Germany',
#   'Ethiopia',
#   'Thailand',
#   'Chinese Taipei',
#   'Argentina',
#   'Hungary',
#   'Iceland',
#   'China',
#   'Kenya',
#   'Costa Rica',
#   'France',
#   'Croatia',
#   'Türkiye',
#   'Guadeloupe',
#   'Honduras',
#   'El Salvador',
#   'Italy',
#   'Japan',
#   'Nicaragua',
#   'Philippines'],
#  'Gold': ['Australia',
#   'India',
#   'Ghana',
#   'Zaire',
#   'Korea',
#   'South Korea',
#   'Papua New Guinea',
#   'New Zealand',
#   'China',
#   'Japan',
#   'South Africa',
#   'Phillipines',
#   'Fiji',
#   'Zimbabwe'],
#  'Gold Production': ['United States', 'World'],
#  'Graphite': ['United States', 'World'],
#  'Ground Source Heat Pumps': ['World'],
#  'HEPB3 Vaccine': ['Austria',
#   'Saint Kitts and Nevis',
#   'Tuvalu',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Cameroon',
#   'Nepal',
#   "Democratic People's Republic of Korea",
#   'Uganda',
#   'Switzerland',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Thailand',
#   'Mauritania',
#   'Burundi',
#   'Samoa',
#   'Luxembourg',
#   'Palau',
#   'Bahamas',
#   'Bolivia (Plurinational State of)',
#   'China',
#   'Zambia',
#   'Vanuatu',
#   'Andorra',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'Türkiye',
#   'Cambodia',
#   'Algeria',
#   'Gabon',
#   'Tajikistan',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Namibia',
#   'Eswatini',
#   'Norway',
#   'South Sudan',
#   'Ukraine',
#   'San Marino',
#   'Yemen',
#   'Haiti',
#   'Equatorial Guinea',
#   'Solomon Islands',
#   'Sao Tome and Principe',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Russian Federation',
#   'Malta',
#   'Senegal',
#   'Cabo Verde',
#   'Georgia',
#   'Germany',
#   'Guyana',
#   'Argentina',
#   'Ireland',
#   'Libya',
#   'Fiji',
#   'Colombia',
#   'Niue',
#   'Tunisia',
#   'Kuwait',
#   'Comoros',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'State of Palestine',
#   'Nicaragua',
#   'Philippines',
#   'Bahrain',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'Sudan',
#   'Republic of Moldova',
#   'Belize',
#   'Portugal',
#   'Saint Lucia',
#   'Singapore',
#   'Canada',
#   'Republic of North Macedonia',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'Slovenia',
#   'Montenegro',
#   'Indonesia',
#   'Mozambique',
#   'Viet Nam',
#   'Barbados',
#   'Jamaica',
#   'Afghanistan',
#   'Gambia',
#   'Dominica',
#   'Seychelles',
#   'Israel',
#   'Suriname',
#   'Republic of Korea',
#   'Egypt',
#   'Kazakhstan',
#   'Pakistan',
#   'Rwanda',
#   'Turkmenistan',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Spain',
#   'Marshall Islands',
#   'Dominican Republic',
#   'Madagascar',
#   'Cook Islands',
#   'Mongolia',
#   'Nauru',
#   'Timor-Leste',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'United States',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Kiribati',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United Republic of Tanzania',
#   'Saint Vincent and the Grenadines',
#   'Monaco',
#   'Lesotho',
#   'Venezuela (Bolivarian Republic of)',
#   'Czechia',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Djibouti',
#   'Bosnia and Herzegovina',
#   'Tonga',
#   'Guinea-Bissau',
#   'Slovakia',
#   'Trinidad and Tobago',
#   'Benin',
#   'Cyprus',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Micronesia (Federated States of)',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   "Cote d'Ivoire",
#   'Maldives',
#   'Croatia',
#   'Congo',
#   'Belarus',
#   'Uruguay',
#   "Lao People's Democratic Republic",
#   'Sri Lanka',
#   'Morocco',
#   'Papua New Guinea',
#   'Botswana',
#   'Syrian Arab Republic',
#   'El Salvador',
#   'Myanmar',
#   'Jordan',
#   'Grenada',
#   'Democratic Republic of the Congo',
#   'Serbia',
#   'South Africa'],
#  'HEPBB Vaccine': ['Saint Kitts and Nevis',
#   'Tuvalu',
#   'Bulgaria',
#   "Democratic People's Republic of Korea",
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Nigeria',
#   'Ecuador',
#   'Thailand',
#   'Samoa',
#   'Palau',
#   'China',
#   'Vanuatu',
#   'Andorra',
#   'Costa Rica',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Iraq',
#   'Türkiye',
#   'Cambodia',
#   'Algeria',
#   'Tajikistan',
#   'Kyrgyzstan',
#   'Namibia',
#   'Ukraine',
#   'Solomon Islands',
#   'Sao Tome and Principe',
#   'Panama',
#   'Oman',
#   'Senegal',
#   'Cabo Verde',
#   'Georgia',
#   'Guyana',
#   'Argentina',
#   'Fiji',
#   'Niue',
#   'Colombia',
#   'Tunisia',
#   'Kuwait',
#   'Honduras',
#   'State of Palestine',
#   'Philippines',
#   'Bahrain',
#   'Armenia',
#   'Republic of Moldova',
#   'Belize',
#   'Portugal',
#   'Saint Lucia',
#   'Singapore',
#   'Republic of North Macedonia',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'Indonesia',
#   'Viet Nam',
#   'Afghanistan',
#   'Gambia',
#   'Dominica',
#   'Israel',
#   'Suriname',
#   'Republic of Korea',
#   'Egypt',
#   'Kazakhstan',
#   'Turkmenistan',
#   'United Arab Emirates',
#   'Marshall Islands',
#   'Dominican Republic',
#   'Cook Islands',
#   'Mongolia',
#   'Nauru',
#   'Timor-Leste',
#   'Saudi Arabia',
#   'United States',
#   'Uzbekistan',
#   'Kiribati',
#   'Qatar',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Saint Vincent and the Grenadines',
#   'Venezuela (Bolivarian Republic of)',
#   'Albania',
#   'Djibouti',
#   'Tonga',
#   'Benin',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Micronesia (Federated States of)',
#   'Brunei Darussalam',
#   "Cote d'Ivoire",
#   'Maldives',
#   'Croatia',
#   'Belarus',
#   "Lao People's Democratic Republic",
#   'Morocco',
#   'Papua New Guinea',
#   'El Salvador',
#   'Myanmar',
#   'Grenada',
#   'Serbia'],
#  'HIB3 Vaccine': ['Austria',
#   'Saint Kitts and Nevis',
#   'Tuvalu',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Cameroon',
#   'Nepal',
#   "Democratic People's Republic of Korea",
#   'Uganda',
#   'Switzerland',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Ecuador',
#   'Thailand',
#   'Mauritania',
#   'Burundi',
#   'Samoa',
#   'Luxembourg',
#   'Palau',
#   'Bahamas',
#   'Bolivia (Plurinational State of)',
#   'Zambia',
#   'Vanuatu',
#   'Andorra',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'Türkiye',
#   'Cambodia',
#   'Algeria',
#   'Gabon',
#   'Tajikistan',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'Eswatini',
#   'Norway',
#   'South Sudan',
#   'Ukraine',
#   'San Marino',
#   'Yemen',
#   'Haiti',
#   'Equatorial Guinea',
#   'Solomon Islands',
#   'Sao Tome and Principe',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Malta',
#   'Senegal',
#   'Cabo Verde',
#   'Georgia',
#   'Germany',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Libya',
#   'Fiji',
#   'Colombia',
#   'Niue',
#   'Tunisia',
#   'Kuwait',
#   'Comoros',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'State of Palestine',
#   'Nicaragua',
#   'Philippines',
#   'Bahrain',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'Sudan',
#   'Republic of Moldova',
#   'Belize',
#   'Portugal',
#   'Saint Lucia',
#   'Singapore',
#   'Canada',
#   'Republic of North Macedonia',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'Slovenia',
#   'Montenegro',
#   'Indonesia',
#   'Mozambique',
#   'Viet Nam',
#   'Barbados',
#   'Jamaica',
#   'Afghanistan',
#   'Gambia',
#   'Dominica',
#   'Seychelles',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Republic of Korea',
#   'Egypt',
#   'Kazakhstan',
#   'Pakistan',
#   'Rwanda',
#   'Turkmenistan',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Spain',
#   'Marshall Islands',
#   'Dominican Republic',
#   'Madagascar',
#   'Cook Islands',
#   'Mongolia',
#   'Nauru',
#   'Timor-Leste',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'United States',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Kiribati',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United Republic of Tanzania',
#   'Saint Vincent and the Grenadines',
#   'Monaco',
#   'Lesotho',
#   'Venezuela (Bolivarian Republic of)',
#   'Czechia',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Djibouti',
#   'Bosnia and Herzegovina',
#   'Tonga',
#   'Guinea-Bissau',
#   'Slovakia',
#   'Trinidad and Tobago',
#   'Benin',
#   'Cyprus',
#   'Hungary',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'Micronesia (Federated States of)',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   "Cote d'Ivoire",
#   'Maldives',
#   'Croatia',
#   'Congo',
#   'Belarus',
#   'Uruguay',
#   "Lao People's Democratic Republic",
#   'Sri Lanka',
#   'Morocco',
#   'Papua New Guinea',
#   'Botswana',
#   'Syrian Arab Republic',
#   'El Salvador',
#   'Myanmar',
#   'Jordan',
#   'Grenada',
#   'Democratic Republic of the Congo',
#   'Serbia',
#   'South Africa'],
#  'Heat Thermal Battery Storage': ['France',
#   'Australia',
#   'India',
#   'Chile',
#   'Morocco',
#   'United States',
#   'Spain',
#   'Germany',
#   'United Kingdom',
#   'China',
#   'South Africa'],
#  'Herbicide-Tolerant Corn': ['United States'],
#  'Herbicide-Tolerant Cotton': ['United States'],
#  'Herbicide-Tolerant Soybeans': ['United States'],
#  'High-Density Polyethylene': ['World'],
#  'High-Speed Rail': ['World'],
#  'Home Air Conditioning': ['United States'],
#  'Home Computers': ['United States'],
#  'Household Internet Access': ['United States'],
#  'Household Refrigerators and Freezers': ['Portugal',
#   'United Kingdom',
#   'Uzbekistan',
#   'Sweden',
#   'Poland',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Mexico',
#   'Lithuania',
#   'Germany',
#   'Netherlands',
#   'Ecuador',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Ireland',
#   'Finland',
#   'Greece',
#   'France',
#   'Egypt',
#   'Azerbaijan',
#   'Iraq',
#   'Spain',
#   'Italy',
#   'Denmark'],
#  'Household Washing and Drying Machines': ['United Kingdom',
#   'Uzbekistan',
#   'Sweden',
#   'Poland',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United States of America',
#   'Mexico',
#   'Lithuania',
#   'Germany',
#   'Ecuador',
#   'Hungary',
#   'Turkey',
#   'Finland',
#   'France',
#   'Egypt',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Spain',
#   'Italy',
#   'Japan',
#   'Denmark'],
#  'Households With Only Mobile Phones (No Landlines)': ['United States'],
#  'Hydrochloric Acid': ['Egypt',
#   'Australia',
#   'India',
#   'United States of America',
#   'Algeria',
# ...
#   'Burkina Faso',
#   'Aruba',
#   'State of Palestine',
#   'Nicaragua',
#   'Philippines',
#   'Bahrain',
#   'Armenia',
#   'Bangladesh',
#   'Australia',
#   'Sudan',
#   'British Virgin Islands',
#   'Republic of Moldova',
#   'Belize',
#   'Portugal',
#   'Saint Lucia',
#   'Singapore',
#   'Canada',
#   'Republic of North Macedonia',
#   'Tokelau',
#   'United States Virgin Islands',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Bhutan',
#   'United States of America',
#   'Slovenia',
#   'Montenegro',
#   'Indonesia',
#   'Mozambique',
#   'Viet Nam',
#   'Barbados',
#   'Jamaica',
#   'Afghanistan',
#   'Gambia',
#   'Dominica',
#   'Seychelles',
#   'Israel',
#   'Montserrat',
#   'Finland',
#   'Suriname',
#   'Republic of Korea',
#   'Egypt',
#   'Kazakhstan',
#   'Pakistan',
#   'Rwanda',
#   'Ghana',
#   'United Arab Emirates',
#   'Spain',
#   'Marshall Islands',
#   'Dominican Republic',
#   'Guadeloupe',
#   'Madagascar',
#   'Cook Islands',
#   'Mongolia',
#   'Saint Barthélemy',
#   'Nauru',
#   'Cayman Islands',
#   'Zimbabwe',
#   'Saudi Arabia',
#   'World',
#   'Bonaire, Sint Eustatius and Saba',
#   'United States',
#   'United Kingdom',
#   'Belgium',
#   'Uzbekistan',
#   'Kiribati',
#   'Chad',
#   'Estonia',
#   'India',
#   'Qatar',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'United Republic of Tanzania',
#   'Saint Vincent and the Grenadines',
#   'Lesotho',
#   'Venezuela (Bolivarian Republic of)',
#   'Czechia',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Martinique',
#   'Bosnia and Herzegovina',
#   'Chinese Taipei',
#   'Tonga',
#   'Slovakia',
#   'Puerto Rico',
#   'Trinidad and Tobago',
#   'Benin',
#   'Cyprus',
#   'Hungary',
#   'Lebanon',
#   'Latvia',
#   'Malaysia',
#   'Antigua and Barbuda',
#   'French Guiana',
#   'Micronesia (Federated States of)',
#   'Brunei Darussalam',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   'Croatia',
#   'Uruguay',
#   'Belarus',
#   "Lao People's Democratic Republic",
#   'Sri Lanka',
#   'Morocco',
#   'Papua New Guinea',
#   'Botswana',
#   'Syrian Arab Republic',
#   'El Salvador',
#   'Myanmar',
#   'Jordan',
#   'Grenada',
#   'Serbia',
#   'South Africa'],
#  'Solar Thermal Energy': ['Australia',
#   'Saudi Arabia',
#   'India',
#   'Chile',
#   'United States of America',
#   'Romania',
#   'Mexico',
#   'Germany',
#   'Thailand',
#   'Israel',
#   'China',
#   'Republic of Korea',
#   'France',
#   'Egypt',
#   'Kuwait',
#   'Türkiye',
#   'Algeria',
#   'United Arab Emirates',
#   'Morocco',
#   'Spain',
#   'Italy',
#   'South Africa'],
#  'Solid Biofuels': ['Austria',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Nepal',
#   'Uganda',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Ethiopia',
#   'Ecuador',
#   'Thailand',
#   'Réunion',
#   'Samoa',
#   'Luxembourg',
#   'Bolivia (Plurinational State of)',
#   'China',
#   'Zambia',
#   'Costa Rica',
#   'Greece',
#   'France',
#   'Türkiye',
#   'Cambodia',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Namibia',
#   'Denmark',
#   'Eswatini',
#   'Norway',
#   'Ukraine',
#   'Russian Federation',
#   'Senegal',
#   'Germany',
#   'Guyana',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Argentina',
#   'Ireland',
#   'Fiji',
#   'Colombia',
#   'Honduras',
#   'Italy',
#   'Nicaragua',
#   'Philippines',
#   'Australia',
#   'Sudan',
#   'Belize',
#   'Portugal',
#   'Singapore',
#   'Canada',
#   'Republic of North Macedonia',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'United States of America',
#   'Slovenia',
#   'Indonesia',
#   'Mozambique',
#   'Viet Nam',
#   'Jamaica',
#   'Finland',
#   'Republic of Korea',
#   'Egypt',
#   'Pakistan',
#   'Rwanda',
#   'Spain',
#   'Dominican Republic',
#   'Guadeloupe',
#   'Zimbabwe',
#   'Belgium',
#   'Chad',
#   'Estonia',
#   'India',
#   'United Republic of Tanzania',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Czechia',
#   'Mauritius',
#   'Martinique',
#   'Chinese Taipei',
#   'Bosnia and Herzegovina',
#   'Trinidad and Tobago',
#   'Slovakia',
#   'Puerto Rico',
#   'Hungary',
#   'Latvia',
#   'Malaysia',
#   'French Guiana',
#   'Kenya',
#   'Malawi',
#   'Croatia',
#   'Congo',
#   'Belarus',
#   'Uruguay',
#   "Lao People's Democratic Republic",
#   'Sri Lanka',
#   'El Salvador',
#   'Serbia',
#   'South Africa'],
#  'Soybean Production': ['Bangladesh',
#   'Australia',
#   'Austria',
#   'Belize',
#   'Canada',
#   'Bulgaria',
#   'Angola',
#   'Nepal',
#   'India',
#   'Bhutan',
#   'Brazil',
#   'Mexico',
#   'Indonesia',
#   'Germany',
#   'Georgia',
#   'Ethiopia',
#   'Nigeria',
#   'Ecuador',
#   'Albania',
#   'Bosnia and Herzegovina',
#   'North Macedonia',
#   'Burundi',
#   'Argentina',
#   'Hungary',
#   'Bolivia (Plurinational State of)',
#   'Malawi',
#   'Colombia',
#   'France',
#   'Egypt',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Kazakhstan',
#   'Croatia',
#   'Cambodia',
#   "Lao People's Democratic Republic",
#   'Morocco',
#   'Italy',
#   'Burkina Faso',
#   'Japan',
#   'Nicaragua',
#   'China, mainland'],
#  'Space Launches': ['World'],
#  'Stationary Steam Engines': ['World'],
#  'Steam Locomotives': ['World'],
#  'Steamships': ['Austria',
#   'United Kingdom',
#   'Belgium',
#   'Canada',
#   'Sweden',
#   'Cuba',
#   'Chile',
#   'Mexico',
#   'Germany',
#   'Netherlands',
#   'Hungary',
#   'Ireland',
#   'Russia',
#   'Finland',
#   'Greece',
#   'France',
#   'Spain',
#   'Italy',
#   'Denmark',
#   'Norway'],
#  'Stove': ['United States'],
#  'Styrene': ['World'],
#  'Submarine Cables': ['World'],
#  'Sugar Cane Production': ['Bangladesh',
#   'Australia',
#   'Belize',
#   'Nepal',
#   'India',
#   'Bhutan',
#   'Brazil',
#   'Mexico',
#   'Mozambique',
#   'Nigeria',
#   'Ethiopia',
#   'Mauritius',
#   'Ecuador',
#   'Niger',
#   'Barbados',
#   'Burundi',
#   'Argentina',
#   'Jamaica',
#   'Lebanon',
#   'Malaysia',
#   'Bolivia (Plurinational State of)',
#   'Kenya',
#   'Costa Rica',
#   'Fiji',
#   'Colombia',
#   'Egypt',
#   'Iran (Islamic Republic of)',
#   'Congo',
#   'Cambodia',
#   "Lao People's Democratic Republic",
#   'Morocco',
#   'Dominican Republic',
#   "Côte d'Ivoire",
#   'Madagascar',
#   'Honduras',
#   'El Salvador',
#   'Japan',
#   'Nicaragua',
#   'Grenada',
#   'China, mainland'],
#  'Sugar Output': ['Bangladesh',
#   'Sudan',
#   'Haiti',
#   'Taiwan',
#   'Swaziland',
#   'Panama',
#   'Ivory Coast',
#   'Cuba',
#   'India',
#   'Trinidad & Tobago',
#   'Guatemala',
#   'Mexico',
#   'Mozambique',
#   'Indonesia',
#   'Iran',
#   'Mauritius',
#   'Ethiopia',
#   'Thailand',
#   'USA',
#   'Barbados',
#   'Jamaica',
#   'Turkey',
#   'China',
#   'Kenya',
#   'Malawi',
#   'Costa Rica',
#   'Egypt',
#   'Pakistan',
#   'Tanzania',
#   'Morocco',
#   'Spain',
#   'Dominican Republic',
#   'Vietnam',
#   'Madagascar',
#   'Honduras',
#   'El Salvador',
#   'Myanmar',
#   'Japan',
#   'Nicaragua',
#   'Philippines',
#   'South Africa',
#   'Zimbabwe'],
#  'Sulphuric Acid': ['Australia',
#   'Austria',
#   'Portugal',
#   'United Kingdom',
#   'Canada',
#   'Belgium',
#   'Bulgaria',
#   'West Germany',
#   'Sweden',
#   'Poland',
#   'Venezuela',
#   'India',
#   'Cuba',
#   'Chile',
#   'Switzerland',
#   'Peru',
#   'United States of America',
#   'Brazil',
#   'Romania',
#   'Mexico',
#   'Yugoslavia',
#   'Indonesia',
#   'Germany',
#   'Iran',
#   'Netherlands',
#   'Thailand',
#   'Czechoslovakia',
#   'Zaire',
#   'Hungary',
#   'Argentina',
#   'Turkey',
#   'Ireland',
#   'Russia',
#   'Israel',
#   'China',
#   'East Germany',
#   'Zambia',
#   'Finland',
#   'Phillipines',
#   'Colombia',
#   'France',
#   'Egypt',
#   'Pakistan',
#   'Tunisia',
#   'Greece',
#   'Algeria',
#   'Morocco',
#   'South Korea',
#   'Italy',
#   'Japan',
#   'Denmark',
#   'Norway'],
#  'Synthetic Filament Tow and Staple Fibers': ['Portugal',
#   'United Kingdom',
#   'Uzbekistan',
#   'Sweden',
#   'Poland',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Mexico',
#   'Lithuania',
#   'Germany',
#   'Netherlands',
#   'Czechia',
#   'Ecuador',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Ireland',
#   'Finland',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Spain',
#   'Italy',
#   'Denmark'],
#  'Synthetic Filament Yarn': ['Portugal',
#   'Uzbekistan',
#   'Bulgaria',
#   'Sweden',
#   'Poland',
#   'Estonia',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Lithuania',
#   'Germany',
#   'Netherlands',
#   'Czechia',
#   'Ecuador',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Latvia',
#   'Ireland',
#   'Finland',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Azerbaijan',
#   'Spain',
#   'Italy',
#   'Japan',
#   'Denmark'],
#  'Tablet': ['United States'],
#  'Telegraph Traffic': ['Australia',
#   'Sudan',
#   'Austria',
#   'Taiwan',
#   'United States',
#   'Portugal',
#   'Singapore',
#   'Syria',
#   'Belgium',
#   'United Kingdom',
#   'Canada',
#   'New Zealand',
#   'Angola',
#   'Sweden',
#   'Norway',
#   'Cameroon',
#   'Ivory Coast',
#   'Poland',
#   'Venezuela',
#   'India',
#   'Uganda',
#   'Chile',
#   'Peru',
#   'Switzerland',
#   'Romania',
#   'Brazil',
#   'Mexico',
#   'Indonesia',
#   'Germany',
#   'Mozambique',
#   'Netherlands',
#   'Nigeria',
#   'Thailand',
#   'Czechoslovakia',
#   'Guyana',
#   'Argentina',
#   'Hungary',
#   'Lebanon',
#   'Turkey',
#   'Ireland',
#   'Malaysia',
#   'Russia',
#   'Israel',
#   'China',
#   'Kenya',
#   'Finland',
#   'Zambia',
#   'Malawi',
#   'Greece',
#   'Togo',
#   'Pakistan',
#   'Egypt',
#   'Colombia',
#   'France',
#   'Iraq',
#   'Ghana',
#   'Uruguay',
#   'Tunisia',
#   'Algeria',
#   'Sri Lanka',
#   'Morocco',
#   'Spain',
#   'Tanzania',
#   'South Korea',
#   'Burma',
#   'Madagascar',
#   'El Salvador',
#   'Italy',
#   'Japan',
#   'Denmark',
#   'South Vietnam',
#   'Philippines',
#   'Democratic Republic of the Congo',
#   'Serbia',
#   'South Africa',
#   'Zimbabwe'],
#  'Telephones': ['Austria',
#   'Taiwan',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Cameroon',
#   'Ivory Coast',
#   'Nepal',
#   'Venezuela',
#   'Uganda',
#   'Switzerland',
#   'Hong Kong',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Thailand',
#   'Ecuador',
#   'Mauritania',
#   'Moldova',
#   'Burundi',
#   'Luxembourg',
#   'Russia',
#   'China',
#   'Zambia',
#   'Costa Rica',
#   'Greece',
#   'Bosnia-Herzegovina',
#   'France',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'Cambodia',
#   'Algeria',
#   'Tajikistan',
#   'Gabon',
#   'Macedonia',
#   'Burma',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'South Vietnam',
#   'Ukraine',
#   'Norway',
#   'Yemen',
#   'Haiti',
#   'Equatorial Guinea',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Senegal',
#   'Bolivia',
#   'Germany',
#   'Georgia',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Slovak Republic',
#   'Libya',
#   'Colombia',
#   'Republic of the Congo',
#   'Tunisia',
#   'Kuwait',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'Nicaragua',
#   'Philippines',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'Czech Republic',
#   'Sudan',
#   'Belize',
#   'Portugal',
#   'Swaziland',
#   'Singapore',
#   'Canada',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Slovenia',
#   'Indonesia',
#   'Mozambique',
#   'Iran',
#   'Gambia',
#   'Afghanistan',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Pakistan',
#   'Egypt',
#   'Kazakhstan',
#   'Turkmenistan',
#   'Rwanda',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Spain',
#   'Dominican Republic',
#   'Madagascar',
#   'Mongolia',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'United States',
#   'Syria',
#   'Belgium',
#   'Uzbekistan',
#   'United Kingdom',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Lesotho',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Laos',
#   'Czechoslovakia',
#   'Guinea-Bissau',
#   'Benin',
#   'Lebanon',
#   'Turkey',
#   'Hungary',
#   'Latvia',
#   'Malaysia',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   'Croatia',
#   'Uruguay',
#   'Belarus',
#   'Sri Lanka',
#   'Morocco',
#   'Tanzania',
#   'South Korea',
#   'Botswana',
#   'Papua New Guinea',
#   'Vietnam',
#   'El Salvador',
#   'Jordan',
#   'Democratic Republic of the Congo',
#   'South Africa'],
#  'Telephones and Videophones': ['Bangladesh',
#   'Portugal',
#   'United Kingdom',
#   'Uzbekistan',
#   'Bulgaria',
#   'Sweden',
#   'Poland',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Lithuania',
#   'Germany',
#   'Czechia',
#   'Hungary',
#   'Turkey',
#   'Finland',
#   'Egypt',
#   'Iran (Islamic Republic of)',
#   'Iraq',
#   'Spain',
#   'Italy',
#   'Japan',
#   'Denmark'],
#  'Television': ['Austria',
#   'Taiwan',
#   'New Zealand',
#   'Bulgaria',
#   'Sweden',
#   'Angola',
#   'Cameroon',
#   'Ivory Coast',
#   'Nepal',
#   'Venezuela',
#   'Uganda',
#   'Switzerland',
#   'Hong Kong',
#   'Guatemala',
#   'Mexico',
#   'Lithuania',
#   'Netherlands',
#   'Nigeria',
#   'Ethiopia',
#   'Thailand',
#   'Ecuador',
#   'Mauritania',
#   'Moldova',
#   'Burundi',
#   'Luxembourg',
#   'Russia',
#   'China',
#   'Zambia',
#   'Costa Rica',
#   'Greece',
#   'Bosnia-Herzegovina',
#   'France',
#   'Azerbaijan',
#   'Iraq',
#   'Guinea',
#   'Cambodia',
#   'Algeria',
#   'Tajikistan',
#   'Gabon',
#   'Macedonia',
#   'Burma',
#   'Kyrgyzstan',
#   'Sierra Leone',
#   'Paraguay',
#   'Japan',
#   'Denmark',
#   'Namibia',
#   'South Vietnam',
#   'Ukraine',
#   'Norway',
#   'Yemen',
#   'Haiti',
#   'Equatorial Guinea',
#   'Mali',
#   'Panama',
#   'Oman',
#   'Senegal',
#   'Bolivia',
#   'Germany',
#   'Georgia',
#   'Guyana',
#   'Argentina',
#   'Iceland',
#   'Ireland',
#   'Slovak Republic',
#   'Libya',
#   'Colombia',
#   'Republic of the Congo',
#   'Tunisia',
#   'Kuwait',
#   'Honduras',
#   'Italy',
#   'Burkina Faso',
#   'Nicaragua',
#   'Philippines',
#   'Armenia',
#   'Central African Republic',
#   'Bangladesh',
#   'Australia',
#   'Czech Republic',
#   'Sudan',
#   'Belize',
#   'Portugal',
#   'Swaziland',
#   'Singapore',
#   'Canada',
#   'Poland',
#   'Cuba',
#   'Peru',
#   'Slovenia',
#   'Indonesia',
#   'Mozambique',
#   'Iran',
#   'Gambia',
#   'Afghanistan',
#   'Israel',
#   'Finland',
#   'Suriname',
#   'Pakistan',
#   'Egypt',
#   'Kazakhstan',
#   'Turkmenistan',
#   'Rwanda',
#   'Ghana',
#   'Somalia',
#   'United Arab Emirates',
#   'Spain',
#   'Dominican Republic',
#   'Madagascar',
#   'Mongolia',
#   'Zimbabwe',
#   'Eritrea',
#   'Saudi Arabia',
#   'United States',
#   'Syria',
#   'Belgium',
#   'Uzbekistan',
#   'United Kingdom',
#   'Chad',
#   'Liberia',
#   'Estonia',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Lesotho',
#   'Mauritius',
#   'Niger',
#   'Albania',
#   'Laos',
#   'Czechoslovakia',
#   'Guinea-Bissau',
#   'Benin',
#   'Lebanon',
#   'Turkey',
#   'Hungary',
#   'Latvia',
#   'Malaysia',
#   'Kenya',
#   'Malawi',
#   'Togo',
#   'Croatia',
#   'Uruguay',
#   'Belarus',
#   'Sri Lanka',
#   'Morocco',
#   'Tanzania',
#   'South Korea',
#   'Botswana',
#   'Papua New Guinea',
#   'Vietnam',
#   'El Salvador',
#   'Jordan',
#   'Democratic Republic of the Congo',
#   'South Africa'],
#  'Television Receivers': ['Bangladesh',
#   'Portugal',
#   'Uzbekistan',
#   'Bulgaria',
#   'Sweden',
#   'Poland',
#   'Brazil',
#   'Lithuania',
#   'Germany',
#   'Nigeria',
#   'Czechia',
#   'Ecuador',
#   'Slovakia',
#   'Hungary',
#   'Turkey',
#   'Finland',
#   'Egypt',
#   'Azerbaijan',
#   'Iraq',
#   'Spain',
#   'Italy',
#   'Mongolia',
#   'Japan',
#   'Denmark'],
#  'Tin': ['Australia',
#   'Brazil',
#   'Malaysia',
#   'Bolivia',
#   'Indonesia',
#   'Nigeria',
#   'China',
#   'Thailand'],
#  'Tin Production': ['United States', 'World'],
#  'Titanium Sponge': ['World'],
#  'Transistors per Microprocessor': ['World'],
#  'Turbo-Jets of a Thrust Not Exceeding 25 kN': ['United Kingdom'],
#  'Urea': ['World'],
#  'Vacuum Cleaners': ['Portugal',
#   'United Kingdom',
#   'Uzbekistan',
#   'Sweden',
#   'Poland',
#   'India',
#   'Chile',
#   'Brazil',
#   'Romania',
#   'Germany',
#   'Netherlands',
#   'Ecuador',
#   'Hungary',
#   'Turkey',
#   'Ireland',
#   'Bolivia (Plurinational State of)',
#   'Finland',
#   'France',
#   'Egypt',
#   'Italy',
#   'Japan',
#   'Denmark'],
#  'Vacuums': ['United States'],
#  'Vanadium Redox-Flow Battery': ['World'],
#  'Videocassette Recorder': ['United States'],
#  'Vinyl Acetate': ['World'],
#  'Vinyl Chloride': ['World'],
#  'Washing Machines': ['US', 'World'],
#  'Water Heater': ['United States'],
#  'Wet Flue Gas Desulfurization Systems': ['Japan',
#   'Germany',
#   'United States',
#   'World'],
#  'YFV Vaccine': ['Central African Republic',
#   'Equatorial Guinea',
#   'Sao Tome and Principe',
#   'Mali',
#   'Panama',
#   'Angola',
#   'Chad',
#   'Cameroon',
#   'Liberia',
#   'Peru',
#   'Brazil',
#   'Senegal',
#   'Venezuela (Bolivarian Republic of)',
#   'Nigeria',
#   'Niger',
#   'Ecuador',
#   'Guyana',
#   'Trinidad and Tobago',
#   'Guinea-Bissau',
#   'Argentina',
#   'Benin',
#   'Gambia',
#   'Bolivia (Plurinational State of)',
#   'Kenya',
#   'Suriname',
#   'Colombia',
#   'Togo',
#   "Cote d'Ivoire",
#   'Guinea',
#   'Ghana',
#   'Congo',
#   'Gabon',
#   'Sierra Leone',
#   'Burkina Faso',
#   'Paraguay',
#   'Democratic Republic of the Congo'],
#  'Zinc': ['Australia',
#   'India',
#   'Peru',
#   'Brazil',
#   'Zaire',
#   'Argentina',
#   'United States of America',
#   'Algeria',
#   'Korea',
#   'North Korea',
#   'South Korea',
#   'Mexico',
#   'Canada',
#   'China',
#   'Japan',
#   'Zambia'],
#  'Zinc Production': ['United States', 'World'],
#  'Zinc-Based Battery': ['Madagascar', 'Indonesia', 'United States']}

# %%
bcg_country = tech_country_dict['BCG Vaccine']
gold_country = tech_country_dict['Gold']
hydrogen_country = tech_country_dict['Hydrogen Storage']
silver_country = tech_country_dict['Silver']
steam_country = tech_country_dict['Steamships']
synth_country = tech_country_dict['Artificial and Synthetic Fibers']
tin_country = tech_country_dict['Tin']
yfv_country = tech_country_dict['YFV Vaccine']

# %%
print(len(bcg_country))
print(len(gold_country))
print(len(hydrogen_country))
print(len(silver_country))
print(len(steam_country))
print(len(synth_country))
print(len(tin_country))
print(len(yfv_country))
# Out:
# 168
# 14
# 6
# 12
# 20
# 39
# 8
# 36

# %%
for country in bcg_country:
    if country in synth_country and country in yfv_country and country in tin_country:
        print(country)
# Out:
# Brazil

# %%
for country in hydrogen_country:
    if country in steam_country:
        print(country)
# Out:
# France
# Germany
# Italy
# Canada
# Denmark

# %%
for country in silver_country:
    if country in gold_country:
        print(country)
# Out:
# Australia
# Zaire
# Korea
# South Korea
# China
# New Zealand
# Japan
# South Africa

# %%
num_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    num_country_dict[tech] = len(countries)
num_country_dict = dict(sorted(num_country_dict.items(), key=lambda item: item[1])) 
num_country_dict
# Out:
# {'Acrylic Fiber': 1,
#  'Acrylonitrile': 1,
#  'Air-Source Heat Pumps': 1,
#  'Amazon Prime Users': 1,
#  'Aniline': 1,
#  'Automatic Transmission': 1,
#  'Benzene': 1,
#  'Bicycles': 1,
#  'Bioenergy': 1,
#  'BisphenolA': 1,
#  'CFLs': 1,
#  'Cable TV': 1,
#  'Canals': 1,
#  'Capillary DNA Sequencing': 1,
#  'Caprolactam': 1,
#  'Carbon Capture and Sequestration': 1,
#  'Central Heating': 1,
#  'Coal Power': 1,
#  'Colour TV': 1,
#  'Compact Fluorescent Light Bulbs': 1,
#  'Computing Growth': 1,
#  'Concentrated Solar Power': 1,
#  'Concentrating Solar Power': 1,
#  'Crude Oil': 1,
#  'Cyclohexane': 1,
#  'DNA Sequencing (All Methods)': 1,
#  'Desalination Capacity': 1,
#  'Dishwashers': 1,
#  'Disk Brakes': 1,
#  'Ebook Reader': 1,
#  'Electric Range': 1,
#  'Electronic Ignition': 1,
#  'Ethanol': 1,
#  'Ethanolamine': 1,
#  'Ethylene': 1,
#  'Ethylene Glycol': 1,
#  'Flue Gas Desulphurization (Wet and Dry)': 1,
#  'Flush Toilet': 1,
#  'Formaldehyde': 1,
#  'Freezer': 1,
#  'Ground Source Heat Pumps': 1,
#  'Herbicide-Tolerant Corn': 1,
#  'Herbicide-Tolerant Cotton': 1,
#  'Herbicide-Tolerant Soybeans': 1,
#  'High-Density Polyethylene': 1,
#  'High-Speed Rail': 1,
#  'Home Air Conditioning': 1,
#  'Home Computers': 1,
#  'Household Internet Access': 1,
#  'Households With Only Mobile Phones (No Landlines)': 1,
#  'Hydrofluoric Acid': 1,
#  'Hydropower': 1,
#  'Hydropower Mega-Dams': 1,
#  'Insect-Resistant Corn': 1,
#  'Insect-Resistant Cotton': 1,
#  'Internet Backbone Bandwidth': 1,
#  'Internet Traffic': 1,
#  'Iron': 1,
#  'Jet Aircraft': 1,
#  'Lead-Acid Battery': 1,
#  'Liquefied Natural Gas': 1,
#  'Liquefied Natural Gas (LNG)': 1,
#  'Lithium-Ion Cells': 1,
#  'Low-Density Polyethylene': 1,
#  'Magnesium': 1,
#  'Magnetic Data Storage': 1,
#  'Maleic Anhydride': 1,
#  'Methanol': 1,
#  'Microcomputers': 1,
#  'Microprocessor Clock Speed': 1,
#  'Microwaves': 1,
#  'Motor Gasoline': 1,
#  'Motorcycles': 1,
#  'Natural Gas Pipeline': 1,
#  'Natural Gas Power': 1,
#  'Neoprene Rubber': 1,
#  'Nickel-Metal Hydride Battery': 1,
#  'Nox Pollution Controls (Boilers)': 1,
#  'Oil Pipeline': 1,
#  'Paraxylene': 1,
#  'Pentaerythritol': 1,
#  'Phenol': 1,
#  'Phthalic Anhydride': 1,
#  'Podcasting': 1,
#  'Polyester Fiber': 1,
#  'Polystyrene': 1,
#  'Polyvinylchloride': 1,
#  'Power Steering': 1,
#  'Primary Magnesium': 1,
#  'Processor Performance': 1,
#  'Public Roads': 1,
#  'Pumped Hydropower': 1,
#  'Radial Tires': 1,
#  'Random Access Memory': 1,
#  'Real-Time Gross Settlement Adoption': 1,
#  'Running Water': 1,
#  'Shale Production': 1,
#  'Shotgun Sanger DNA Sequencing': 1,
#  'Smartphone Usage': 1,
#  'Social Media Usage': 1,
#  'Sodium': 1,
#  'Sodium Chlorate': 1,
#  'Sodium-Sulphur Battery': 1,
#  'Space Launches': 1,
#  'Stationary Steam Engines': 1,
#  'Steam Locomotives': 1,
#  'Stove': 1,
#  'Styrene': 1,
#  'Submarine Cables': 1,
#  'Tablet': 1,
#  'Titanium Sponge': 1,
#  'Transistors per Microprocessor': 1,
#  'Turbo-Jets of a Thrust Not Exceeding 25 kN': 1,
#  'Urea': 1,
#  'Vacuums': 1,
#  'Vanadium Redox-Flow Battery': 1,
#  'Videocassette Recorder': 1,
#  'Vinyl Acetate': 1,
#  'Vinyl Chloride': 1,
#  'Water Heater': 1,
#  'Cement': 2,
#  'Cobalt': 2,
#  'Electric Bicycles': 2,
#  'Fluid Catalytic Cracking Refineries': 2,
#  'Gold Production': 2,
#  'Graphite': 2,
#  'Laundry Dryers': 2,
#  'Lithium Mine Production': 2,
#  'Nickel Production': 2,
#  'Passenger Cars': 2,
#  'Primary Copper': 2,
#  'Rare Earth Mine Production': 2,
#  'Refrigerators': 2,
#  'Sand and Gravel|Construction': 2,
#  'Sand and Gravel|Industrial': 2,
#  'Silver Production': 2,
#  'Tin Production': 2,
#  'Washing Machines': 2,
#  'Zinc Production': 2,
#  'Zinc-Based Battery': 3,
#  'Latent Heat Storage': 4,
#  'Nickel-Based Battery': 4,
#  'Wet Flue Gas Desulfurization Systems': 4,
#  'Electro-Chemical Capacitor': 6,
#  'Hydrogen Storage': 6,
#  'Compressed Air Energy Storage': 7,
#  'Nuclear Weapons': 8,
#  'Tin': 8,
#  'Nitric Acid': 9,
#  'Nickel': 10,
#  'Sensible Heat Storage': 10,
#  'Heat Thermal Battery Storage': 11,
#  'Microwave Ovens': 11,
#  'Silver': 12,
#  'Ammonia Synthesis': 13,
#  'Hydrochloric Acid': 13,
#  'Gold': 14,
#  'Caustic Soda Acid': 15,
#  'Flywheel Battery Storage': 15,
#  'Potassic Fertilizers': 16,
#  'Sodium-Based Battery Storage': 16,
#  'Zinc': 16,
#  'Cotton Seed Production': 17,
#  'Lead-Acid Battery Storage': 18,
#  'Liquid Biofuels': 18,
#  'Marine Energy': 19,
#  'Offshore Wind Energy': 19,
#  'Steamships': 20,
#  'Combined Refrigerators-Freezers': 22,
#  'Refined Copper': 22,
#  'Solar Thermal Energy': 22,
#  'Vacuum Cleaners': 22,
#  'Radio Receivers': 23,
#  'Biofuels Production': 24,
#  'Household Washing and Drying Machines': 24,
#  'Synthetic Filament Tow and Staple Fibers': 24,
#  'Telephones and Videophones': 24,
#  'Television Receivers': 24,
#  'Flow Battery Storage': 25,
#  'Motorcycles and Scooters': 25,
#  'Household Refrigerators and Freezers': 26,
#  'Synthetic Filament Yarn': 27,
#  'Electric Water Heaters and Immersion Heaters': 30,
#  'Cars': 32,
#  'Caustic Soda': 32,
#  'Geothermal Energy': 32,
#  'Nitrogenous Fertilizers': 32,
#  'Air Conditioning Machines': 35,
#  'YFV Vaccine': 36,
#  'Bicycles and Other Cycles': 37,
#  'Primary Bauxite Production': 38,
#  'Artificial and Synthetic Fibers': 39,
#  'Coal Production': 40,
#  'Sugar Cane Production': 40,
#  'Cadmium Refining': 41,
#  'Soybean Production': 41,
#  'Sugar Output': 42,
#  'Pumped Hydro Storage': 44,
#  'Lithium-Ion Battery Storage': 47,
#  'Oil Production': 51,
#  'Natural Gas Production': 52,
#  'Sulphuric Acid': 52,
#  'Copper|Refining': 58,
#  'Primary Aluminum Production': 58,
#  'Beer': 60,
#  'Crude Petroleum': 60,
#  'Lead': 64,
#  'Iron Ore': 65,
#  'Copper|Mining': 69,
#  'Oil Refining Capacity': 75,
#  'Telegraph Traffic': 76,
#  'Electricity': 80,
#  'Postal Traffic': 80,
#  'Hydroelectricity': 81,
#  'Nuclear Energy': 81,
#  'Renewable Power': 81,
#  'Corn Production': 91,
#  'Objects Launched Into Space': 92,
#  'Biogas': 95,
#  "Cow's Milk Production": 98,
#  'Milk': 98,
#  'Beer Production': 102,
#  'Solid Biofuels': 102,
#  'HEPBB Vaccine': 105,
#  'Raw Steel Production': 108,
#  'Crop Harvester': 118,
#  'ROTAC Vaccine': 118,
#  'Salt Production': 125,
#  'Railroad': 128,
#  'Cellphones': 153,
#  'PCV3 Vaccine': 153,
#  'Passenger Vehicles': 153,
#  'Radio': 155,
#  'Telephones': 155,
#  'Television': 155,
#  'BCG Vaccine': 168,
#  'Potash Fertilizer': 171,
#  'RCV1 Vaccine': 173,
#  'Nitrogen Fertilizer': 175,
#  'Phosphate Fertilizer': 175,
#  'MCV2 Vaccine': 183,
#  'HEPB3 Vaccine': 191,
#  'HIB3 Vaccine': 193,
#  'Solar Photovoltaic': 193,
#  'DTP1 Vaccine': 195,
#  'DTP3 Vaccine': 195,
#  'IPV1 Vaccine': 195,
#  'MCV1 Vaccine': 195,
#  'POL3 Vaccine': 195,
#  'Aquaculture Production': 196,
#  'Capture Fisheries': 216,
#  'Onshore Wind Energy': 227}

# %%
country_data = []
for x in num_country_dict:
    if num_country_dict[x] > 2:
        print(x)
# Out:
# Zinc-Based Battery
# Latent Heat Storage
# Nickel-Based Battery
# Wet Flue Gas Desulfurization Systems
# Electro-Chemical Capacitor
# Hydrogen Storage
# Compressed Air Energy Storage
# Nuclear Weapons
# Tin
# Nitric Acid
# Nickel
# Sensible Heat Storage
# Heat Thermal Battery Storage
# Microwave Ovens
# Silver
# Ammonia Synthesis
# Hydrochloric Acid
# Gold
# Caustic Soda Acid
# Flywheel Battery Storage
# Potassic Fertilizers
# Sodium-Based Battery Storage
# Zinc
# Cotton Seed Production
# Lead-Acid Battery Storage
# Liquid Biofuels
# Marine Energy
# Offshore Wind Energy
# Steamships
# Combined Refrigerators-Freezers
# Refined Copper
# Solar Thermal Energy
# Vacuum Cleaners
# Radio Receivers
# Biofuels Production
# Household Washing and Drying Machines
# Synthetic Filament Tow and Staple Fibers
# Telephones and Videophones
# Television Receivers
# Flow Battery Storage
# Motorcycles and Scooters
# Household Refrigerators and Freezers
# Synthetic Filament Yarn
# Electric Water Heaters and Immersion Heaters
# Cars
# Caustic Soda
# Geothermal Energy
# Nitrogenous Fertilizers
# Air Conditioning Machines
# YFV Vaccine
# Bicycles and Other Cycles
# Primary Bauxite Production
# Artificial and Synthetic Fibers
# Coal Production
# Sugar Cane Production
# Cadmium Refining
# Soybean Production
# Sugar Output
# Pumped Hydro Storage
# Lithium-Ion Battery Storage
# Oil Production
# Natural Gas Production
# Sulphuric Acid
# Copper|Refining
# Primary Aluminum Production
# Beer
# Crude Petroleum
# Lead
# Iron Ore
# Copper|Mining
# Oil Refining Capacity
# Telegraph Traffic
# Electricity
# Postal Traffic
# Hydroelectricity
# Nuclear Energy
# Renewable Power
# Corn Production
# Objects Launched Into Space
# Biogas
# Cow's Milk Production
# Milk
# Beer Production
# Solid Biofuels
# HEPBB Vaccine
# Raw Steel Production
# Crop Harvester
# ROTAC Vaccine
# Salt Production
# Railroad
# Cellphones
# PCV3 Vaccine
# Passenger Vehicles
# Radio
# Telephones
# Television
# BCG Vaccine
# Potash Fertilizer
# RCV1 Vaccine
# Nitrogen Fertilizer
# Phosphate Fertilizer
# MCV2 Vaccine
# HEPB3 Vaccine
# HIB3 Vaccine
# Solar Photovoltaic
# DTP1 Vaccine
# DTP3 Vaccine
# IPV1 Vaccine
# MCV1 Vaccine
# POL3 Vaccine
# Aquaculture Production
# Capture Fisheries
# Onshore Wind Energy

# %%
cost_data = all_tech[(all_tech['Metric']=='Price') | (all_tech['Metric']=='Total Installed Cost') | (all_tech['Metric']=='Levelized Cost of Energy')]
cost_list = list(set(cost_data['Technology Name']))
print(len(cost_list))
for x in cost_list:
    print(x)
# Out:
# 105
# Formaldehyde
# Cow's Milk Production
# Ethanol
# Sodium-Sulphur Battery
# Offshore Wind Energy
# Polyester Fiber
# DNA Sequencing (All Methods)
# Ethylene Glycol
# Rare Earth Mine Production
# Benzene
# Lithium-Ion Cells
# Primary Aluminum Production
# Cement
# Salt Production
# Coal Production
# Refined Copper
# Primary Magnesium
# Cobalt
# Crude Oil
# Sodium
# Vanadium Redox-Flow Battery
# Primary Bauxite Production
# Household Refrigerators and Freezers
# Sand and Gravel|Industrial
# Acrylic Fiber
# Zinc Production
# Beer
# Nickel Production
# Soybean Production
# Primary Copper
# Tin Production
# Hydropower Mega-Dams
# Caustic Soda
# Sodium Chlorate
# Methanol
# Maleic Anhydride
# Sand and Gravel|Construction
# Lithium Mine Production
# Bioenergy
# Natural Gas Production
# Synthetic Filament Tow and Staple Fibers
# Pumped Hydropower
# Vacuum Cleaners
# Air Conditioning Machines
# Electric Water Heaters and Immersion Heaters
# Aniline
# Shotgun Sanger DNA Sequencing
# Silver Production
# Styrene
# Polyvinylchloride
# Lead
# Cotton Seed Production
# Bicycles and Other Cycles
# Low-Density Polyethylene
# Microwave Ovens
# Radio Receivers
# Urea
# Geothermal Energy
# Acrylonitrile
# Gold Production
# Magnesium
# Vinyl Chloride
# Iron Ore
# Caprolactam
# Solar Photovoltaic
# Cyclohexane
# Nickel-Metal Hydride Battery
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Raw Steel Production
# Concentrating Solar Power
# Household Washing and Drying Machines
# Hydropower
# Lead-Acid Battery
# Onshore Wind Energy
# Graphite
# Liquefied Natural Gas (LNG)
# Neoprene Rubber
# Hydrofluoric Acid
# Pentaerythritol
# Potassic Fertilizers
# Phenol
# Nitrogenous Fertilizers
# Combined Refrigerators-Freezers
# Flue Gas Desulphurization (Wet and Dry)
# High-Density Polyethylene
# Cadmium Refining
# Polystyrene
# Phthalic Anhydride
# BisphenolA
# Television Receivers
# Vinyl Acetate
# Capillary DNA Sequencing
# CFLs
# Titanium Sponge
# Sugar Cane Production
# Synthetic Filament Yarn
# Space Launches
# Corn Production
# Ethanolamine
# Paraxylene
# Ethylene
# Telephones and Videophones
# Motorcycles and Scooters
# Motor Gasoline
# Cars

# %%
for tech in cost_list:
    tech_df = all_tech[all_tech['Technology Name']==tech]
    sources = list(set(tech_df['Data Source']))
    if len(sources) > 1:
        print(tech, sources)
# Out:
# Offshore Wind Energy ['IRENA', 'IRENASTAT']
# Geothermal Energy ['IRENA', 'IRENASTAT']
# Solar Photovoltaic ['IRENA', 'IRENASTAT']
# Onshore Wind Energy ['IRENA', 'IRENASTAT']

# %%
def time_span(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    tech_df.dropna(axis=1, how='all', inplace=True)
    omit = []
    for col in tech_df.columns:
        if len(col) != 4 or col == 'Unit':
            omit.append(col)
    tech_df.drop(columns=omit, inplace=True)
    time_span = tech_df.columns[0] + '-' + tech_df.columns[-1]
    return time_span

# %%
time_span('Acrylic Fiber')
# Out:
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-1972'

# %%
time_span('Ammonia Synthesis')
# Out:
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1905-2020'

# %%
time_span('Aquaculture Production')
# Out:
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-2020'

# %%
timespan_dict = {}
for tech in tech_list:
    timespan_dict[tech] = time_span(tech)
# Out:
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/cy/xd4mmw610b3cr6tjgv0h8hlr0000gn/T/ipykernel_28432/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)

# %%
timespan_dict
# Out:
# {'Acrylic Fiber': '1960-1972',
#  'Acrylonitrile': '1959-1972',
#  'Air Conditioning Machines': '1995-2016',
#  'Air-Source Heat Pumps': '2003-2022',
#  'Amazon Prime Users': '2014-2018',
#  'Ammonia Synthesis': '1905-2020',
#  'Aniline': '1961-1972',
#  'Aquaculture Production': '1960-2020',
#  'Artificial and Synthetic Fibers': '1910-1999',
#  'Automatic Transmission': '1910-1984',
#  'BCG Vaccine': '1980-2021',
#  'Beer': '1995-2016',
#  'Beer Production': '1750-2007',
#  'Benzene': '1952-1968',
#  'Bicycles': '1861-2007',
#  'Bicycles and Other Cycles': '1995-2016',
#  'Bioenergy': '2010-2021',
#  'Biofuels Production': '1990-2021',
#  'Biogas': '2000-2021',
#  'BisphenolA': '1959-1972',
#  'CFLs': '1983-2006',
#  'Cable TV': '1968-1997',
#  'Cadmium Refining': '1900-2019',
#  'Canals': '1794-1861',
#  'Capillary DNA Sequencing': '2000-2008',
#  'Caprolactam': '1962-1972',
#  'Capture Fisheries': '1960-2020',
#  'Carbon Capture and Sequestration': '1971-2019',
#  'Cars': '1995-2016',
#  'Caustic Soda': '1995-2016',
#  'Caustic Soda Acid': '1899-2008',
#  'Cellphones': '1975-2010',
#  'Cement': '1900-2019',
#  'Central Heating': '1900-1970',
#  'Coal Power': '1908-2000',
#  'Coal Production': '1981-2021',
#  'Cobalt': '1900-2019',
#  'Colour TV': '1966-2005',
#  'Combined Refrigerators-Freezers': '1995-2016',
#  'Compact Fluorescent Light Bulbs': '1990-2003',
#  'Compressed Air Energy Storage': '1991-2020',
#  'Computing Growth': '1900-1998',
#  'Concentrated Solar Power': '1985-2022',
#  'Concentrating Solar Power': '2010-2021',
#  'Copper|Mining': '1990-2011',
#  'Copper|Refining': '1990-2011',
#  'Corn Production': '1991-2021',
#  'Cotton Seed Production': '1991-2021',
#  "Cow's Milk Production": '1991-2021',
#  'Crop Harvester': '1961-2001',
#  'Crude Oil': '1861-2021',
#  'Crude Petroleum': '1860-2008',
#  'Cyclohexane': '1956-1972',
#  'DNA Sequencing (All Methods)': '2001-2022',
#  'DTP1 Vaccine': '1980-2021',
#  'DTP3 Vaccine': '1980-2021',
#  'Desalination Capacity': '1960-2020',
#  'Dishwashers': '1922-2011',
#  'Disk Brakes': '1966-1984',
#  'Ebook Reader': '2009-2018',
#  'Electric Bicycles': '1997-2010',
#  'Electric Range': '1933-1986',
#  'Electric Water Heaters and Immersion Heaters': '1995-2016',
#  'Electricity': '1985-2021',
#  'Electro-Chemical Capacitor': '2012-2016',
#  'Electronic Ignition': '1962-1984',
#  'Ethanol': '1958-1972',
#  'Ethanolamine': '1955-1972',
#  'Ethylene': '1953-1968',
#  'Ethylene Glycol': '1960-1972',
#  'Flow Battery Storage': '2000-2018',
#  'Flue Gas Desulphurization (Wet and Dry)': '1969-2010',
#  'Fluid Catalytic Cracking Refineries': '1940-2007',
#  'Flush Toilet': '1860-1989',
#  'Flywheel Battery Storage': '2006-2020',
#  'Formaldehyde': '1962-1972',
#  'Freezer': '1950-2011',
#  'Geothermal Energy': '2000-2021',
#  'Gold': '1851-2008',
#  'Gold Production': '1900-2018',
#  'Graphite': '1900-2019',
#  'Ground Source Heat Pumps': '1995-2020',
#  'HEPB3 Vaccine': '1989-2021',
#  'HEPBB Vaccine': '2000-2021',
#  'HIB3 Vaccine': '1991-2021',
#  'Heat Thermal Battery Storage': '2007-2017',
#  'Herbicide-Tolerant Corn': '1996-2022',
#  'Herbicide-Tolerant Cotton': '1996-2022',
#  'Herbicide-Tolerant Soybeans': '1996-2022',
#  'High-Density Polyethylene': '1958-1972',
#  'High-Speed Rail': '1964-2021',
#  'Home Air Conditioning': '1957-2011',
#  'Home Computers': '1992-2016',
#  'Household Internet Access': '1993-2016',
#  'Household Refrigerators and Freezers': '1995-2016',
#  'Household Washing and Drying Machines': '1995-2016',
#  'Households With Only Mobile Phones (No Landlines)': '2013-2018',
#  'Hydrochloric Acid': '1929-2003',
#  'Hydroelectricity': '1965-2021',
#  'Hydrofluoric Acid': '1962-1972',
#  'Hydrogen Storage': '2012-2017',
#  'Hydropower': '2010-2021',
#  'Hydropower Mega-Dams': '1936-2013',
#  'IPV1 Vaccine': '2015-2021',
#  'Insect-Resistant Corn': '1996-2022',
#  'Insect-Resistant Cotton': '1996-2022',
#  'Internet Backbone Bandwidth': '1968-2004',
#  'Internet Traffic': '1984-2014',
#  'Iron': '1933-1970',
#  'Iron Ore': '1900-2019',
#  'Jet Aircraft': '1958-2007',
#  'Latent Heat Storage': '1991-2017',
#  'Laundry Dryers': '1920-2006',
#  'Lead': '1900-2018',
#  'Lead-Acid Battery': '1989-2012',
#  'Lead-Acid Battery Storage': '1987-2020',
#  'Liquefied Natural Gas': '1985-2021',
#  'Liquefied Natural Gas (LNG)': '1984-2021',
#  'Liquid Biofuels': '2001-2021',
#  'Lithium Mine Production': '1900-2019',
#  'Lithium-Ion Battery Storage': '2008-2021',
#  'Lithium-Ion Cells': '1991-2018',
#  'Low-Density Polyethylene': '1958-1972',
#  'MCV1 Vaccine': '1980-2021',
#  'MCV2 Vaccine': '2000-2021',
#  'Magnesium': '1954-1972',
#  'Magnetic Data Storage': '1952-2004',
#  'Maleic Anhydride': '1959-1972',
#  'Marine Energy': '2000-2021',
#  'Methanol': '1957-1972',
#  'Microcomputers': '1984-2016',
#  'Microprocessor Clock Speed': '1976-2016',
#  'Microwave Ovens': '1995-2016',
#  'Microwaves': '1975-2017',
#  'Milk': '1889-2010',
#  'Motor Gasoline': '1946-1968',
#  'Motorcycles': '1900-2008',
#  'Motorcycles and Scooters': '1996-2016',
#  'Natural Gas Pipeline': '1960-2021',
#  'Natural Gas Power': '1903-2000',
#  'Natural Gas Production': '1970-2021',
#  'Neoprene Rubber': '1960-1972',
#  'Nickel': '1889-2008',
#  'Nickel Production': '1900-2018',
#  'Nickel-Based Battery': '2003-2015',
#  'Nickel-Metal Hydride Battery': '1997-2014',
#  'Nitric Acid': '1929-2003',
#  'Nitrogen Fertilizer': '1961-2020',
#  'Nitrogenous Fertilizers': '1995-2016',
#  'Nox Pollution Controls (Boilers)': '1990-2005',
#  'Nuclear Energy': '1965-2021',
#  'Nuclear Weapons': '1945-2010',
#  'Objects Launched Into Space': '1957-2022',
#  'Offshore Wind Energy': '2000-2021',
#  'Oil Pipeline': '2001-2021',
#  'Oil Production': '1965-2021',
#  'Oil Refining Capacity': '1965-2021',
#  'Onshore Wind Energy': '1983-2022',
#  'PCV3 Vaccine': '2008-2021',
#  'POL3 Vaccine': '1980-2021',
#  'Paraxylene': '1957-1968',
#  'Passenger Cars': '1900-2005',
#  'Passenger Vehicles': '1895-2003',
#  'Pentaerythritol': '1952-1972',
#  'Phenol': '1959-1972',
#  'Phosphate Fertilizer': '1961-2020',
#  'Phthalic Anhydride': '1955-1972',
#  'Podcasting': '2006-2015',
#  'Polyester Fiber': '1960-1972',
#  'Polystyrene': '1943-1968',
#  'Polyvinylchloride': '1946-1968',
#  'Postal Traffic': '1830-2000',
#  'Potash Fertilizer': '1961-2020',
#  'Potassic Fertilizers': '1999-2016',
#  'Power Steering': '1951-1984',
#  'Primary Aluminum Production': '1900-2019',
#  'Primary Bauxite Production': '1900-2019',
#  'Primary Copper': '1900-2018',
#  'Primary Magnesium': '1929-1968',
#  'Processor Performance': '1971-2002',
#  'Public Roads': '1900-2020',
#  'Pumped Hydro Storage': '1944-2020',
#  'Pumped Hydropower': '1983-2018',
#  'RCV1 Vaccine': '1980-2021',
#  'ROTAC Vaccine': '2006-2021',
#  'Radial Tires': '1972-1984',
#  'Radio': '1815-2000',
#  'Radio Receivers': '1995-2016',
#  'Railroad': '1825-2004',
#  'Random Access Memory': '1949-2004',
#  'Rare Earth Mine Production': '1900-2019',
#  'Raw Steel Production': '1900-2019',
#  'Real-Time Gross Settlement Adoption': '1970-2005',
#  'Refined Copper': '1995-2016',
#  'Refrigerators': '1918-2009',
#  'Renewable Power': '1965-2021',
#  'Running Water': '1890-1989',
#  'Salt Production': '1900-2017',
#  'Sand and Gravel|Construction': '1902-2019',
#  'Sand and Gravel|Industrial': '1902-2019',
#  'Sensible Heat Storage': '1982-2018',
#  'Shale Production': '2007-2019',
#  'Shotgun Sanger DNA Sequencing': '2001-2009',
#  'Silver': '1874-2008',
#  'Silver Production': '1900-2018',
#  'Smartphone Usage': '2011-2019',
#  'Social Media Usage': '2005-2019',
#  'Sodium': '1957-1972',
#  'Sodium Chlorate': '1958-1972',
#  'Sodium-Based Battery Storage': '1999-2019',
#  'Sodium-Sulphur Battery': '2007-2021',
#  'Solar Photovoltaic': '2000-2021',
#  'Solar Thermal Energy': '2000-2021',
#  'Solid Biofuels': '2000-2021',
#  'Soybean Production': '1991-2021',
#  'Space Launches': '1957-2018',
#  'Stationary Steam Engines': '1720-1920',
#  'Steam Locomotives': '1830-1920',
#  'Steamships': '1814-1998',
#  'Stove': '1900-2011',
#  'Styrene': '1958-1972',
#  'Submarine Cables': '1989-2021',
#  'Sugar Cane Production': '1991-2021',
#  'Sugar Output': '1750-2010',
#  'Sulphuric Acid': '1860-2003',
#  'Synthetic Filament Tow and Staple Fibers': '1995-2016',
#  'Synthetic Filament Yarn': '1995-2016',
#  'Tablet': '2010-2017',
#  'Telegraph Traffic': '1830-2000',
#  'Telephones': '1876-2003',
#  'Telephones and Videophones': '1995-2016',
#  'Television': '1946-2002',
#  'Television Receivers': '1997-2016',
#  'Tin': '1910-2003',
#  'Tin Production': '1900-2019',
#  'Titanium Sponge': '1950-1968',
#  'Transistors per Microprocessor': '1971-2003',
#  'Turbo-Jets of a Thrust Not Exceeding 25 kN': '1995-1999',
#  'Urea': '1961-1972',
#  'Vacuum Cleaners': '1995-2016',
#  'Vacuums': '1922-1978',
#  'Vanadium Redox-Flow Battery': '2008-2019',
#  'Videocassette Recorder': '1992-2011',
#  'Vinyl Acetate': '1960-1972',
#  'Vinyl Chloride': '1962-1972',
#  'Washing Machines': '1920-2008',
#  'Water Heater': '1933-1986',
#  'Wet Flue Gas Desulfurization Systems': '1972-1999',
#  'YFV Vaccine': '1997-2021',
#  'Zinc': '1860-2008',
#  'Zinc Production': '1900-2019',
#  'Zinc-Based Battery': '2013-2020'}

# %%
timespan_dict_lower = {}
for item in timespan_dict:
    timespan_dict_lower[item.lower()] = timespan_dict[item]
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air conditioning machines': '1995-2016',
#  'air-source heat pumps': '2003-2022',
#  'amazon prime users': '2014-2018',
#  'ammonia synthesis': '1905-2020',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'artificial and synthetic fibers': '1910-1999',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer': '1995-2016',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'bicycles and other cycles': '1995-2016',
#  'bioenergy': '2010-2021',
#  'biofuels production': '1990-2021',
#  'biogas': '2000-2021',
#  'bisphenola': '1959-1972',
#  'cfls': '1983-2006',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1900-2019',
#  'canals': '1794-1861',
#  'capillary dna sequencing': '2000-2008',
#  'caprolactam': '1962-1972',
#  'capture fisheries': '1960-2020',
#  'carbon capture and sequestration': '1971-2019',
#  'cars': '1995-2016',
#  'caustic soda': '1995-2016',
#  'caustic soda acid': '1899-2008',
#  'cellphones': '1975-2010',
#  'cement': '1900-2019',
#  'central heating': '1900-1970',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt': '1900-2019',
#  'colour tv': '1966-2005',
#  'combined refrigerators-freezers': '1995-2016',
#  'compact fluorescent light bulbs': '1990-2003',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'concentrating solar power': '2010-2021',
#  'copper|mining': '1990-2011',
#  'copper|refining': '1990-2011',
#  'corn production': '1991-2021',
#  'cotton seed production': '1991-2021',
#  "cow's milk production": '1991-2021',
#  'crop harvester': '1961-2001',
#  'crude oil': '1861-2021',
#  'crude petroleum': '1860-2008',
#  'cyclohexane': '1956-1972',
#  'dna sequencing (all methods)': '2001-2022',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electric water heaters and immersion heaters': '1995-2016',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanol': '1958-1972',
#  'ethanolamine': '1955-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'flow battery storage': '2000-2018',
#  'flue gas desulphurization (wet and dry)': '1969-2010',
#  'fluid catalytic cracking refineries': '1940-2007',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold': '1851-2008',
#  'gold production': '1900-2018',
#  'graphite': '1900-2019',
#  'ground source heat pumps': '1995-2020',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'hib3 vaccine': '1991-2021',
#  'heat thermal battery storage': '2007-2017',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'high-density polyethylene': '1958-1972',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'household refrigerators and freezers': '1995-2016',
#  'household washing and drying machines': '1995-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'hydropower': '2010-2021',
#  'hydropower mega-dams': '1936-2013',
#  'ipv1 vaccine': '2015-2021',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'iron': '1933-1970',
#  'iron ore': '1900-2019',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead': '1900-2018',
#  'lead-acid battery': '1989-2012',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1985-2021',
#  'liquefied natural gas (lng)': '1984-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1900-2019',
#  'lithium-ion battery storage': '2008-2021',
#  'lithium-ion cells': '1991-2018',
#  'low-density polyethylene': '1958-1972',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwave ovens': '1995-2016',
#  'microwaves': '1975-2017',
#  'milk': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'motorcycles and scooters': '1996-2016',
#  'natural gas pipeline': '1960-2021',
#  'natural gas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel': '1889-2008',
#  'nickel production': '1900-2018',
#  'nickel-based battery': '2003-2015',
#  'nickel-metal hydride battery': '1997-2014',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nitrogenous fertilizers': '1995-2016',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'objects launched into space': '1957-2022',
#  'offshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'onshore wind energy': '1983-2022',
#  'pcv3 vaccine': '2008-2021',
#  'pol3 vaccine': '1980-2021',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1900-2005',
#  'passenger vehicles': '1895-2003',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'polyester fiber': '1960-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'potassic fertilizers': '1999-2016',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1900-2019',
#  'primary bauxite production': '1900-2019',
#  'primary copper': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'pumped hydropower': '1983-2018',
#  'rcv1 vaccine': '1980-2021',
#  'rotac vaccine': '2006-2021',
#  'radial tires': '1972-1984',
#  'radio': '1815-2000',
#  'radio receivers': '1995-2016',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1900-2019',
#  'raw steel production': '1900-2019',
#  'real-time gross settlement adoption': '1970-2005',
#  'refined copper': '1995-2016',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'running water': '1890-1989',
#  'salt production': '1900-2017',
#  'sand and gravel|construction': '1902-2019',
#  'sand and gravel|industrial': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2008',
#  'silver production': '1900-2018',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'sodium-sulphur battery': '2007-2021',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'soybean production': '1991-2021',
#  'space launches': '1957-2018',
#  'stationary steam engines': '1720-1920',
#  'steam locomotives': '1830-1920',
#  'steamships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sugar cane production': '1991-2021',
#  'sugar output': '1750-2010',
#  'sulphuric acid': '1860-2003',
#  'synthetic filament tow and staple fibers': '1995-2016',
#  'synthetic filament yarn': '1995-2016',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'telephones and videophones': '1995-2016',
#  'television': '1946-2002',
#  'television receivers': '1997-2016',
#  'tin': '1910-2003',
#  'tin production': '1900-2019',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'turbo-jets of a thrust not exceeding 25 kn': '1995-1999',
#  'urea': '1961-1972',
#  'vacuum cleaners': '1995-2016',
#  'vacuums': '1922-1978',
#  'vanadium redox-flow battery': '2008-2019',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2008',
#  'zinc production': '1900-2019',
#  'zinc-based battery': '2013-2020'}

# %%
timespan_dict_lower = dict(sorted(timespan_dict_lower.items(), key=lambda item: item[0])) 
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air conditioning machines': '1995-2016',
#  'air-source heat pumps': '2003-2022',
#  'amazon prime users': '2014-2018',
#  'ammonia synthesis': '1905-2020',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'artificial and synthetic fibers': '1910-1999',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer': '1995-2016',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'bicycles and other cycles': '1995-2016',
#  'bioenergy': '2010-2021',
#  'biofuels production': '1990-2021',
#  'biogas': '2000-2021',
#  'bisphenola': '1959-1972',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1900-2019',
#  'canals': '1794-1861',
#  'capillary dna sequencing': '2000-2008',
#  'caprolactam': '1962-1972',
#  'capture fisheries': '1960-2020',
#  'carbon capture and sequestration': '1971-2019',
#  'cars': '1995-2016',
#  'caustic soda': '1995-2016',
#  'caustic soda acid': '1899-2008',
#  'cellphones': '1975-2010',
#  'cement': '1900-2019',
#  'central heating': '1900-1970',
#  'cfls': '1983-2006',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt': '1900-2019',
#  'colour tv': '1966-2005',
#  'combined refrigerators-freezers': '1995-2016',
#  'compact fluorescent light bulbs': '1990-2003',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'concentrating solar power': '2010-2021',
#  'copper|mining': '1990-2011',
#  'copper|refining': '1990-2011',
#  'corn production': '1991-2021',
#  'cotton seed production': '1991-2021',
#  "cow's milk production": '1991-2021',
#  'crop harvester': '1961-2001',
#  'crude oil': '1861-2021',
#  'crude petroleum': '1860-2008',
#  'cyclohexane': '1956-1972',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'dna sequencing (all methods)': '2001-2022',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electric water heaters and immersion heaters': '1995-2016',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanol': '1958-1972',
#  'ethanolamine': '1955-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'flow battery storage': '2000-2018',
#  'flue gas desulphurization (wet and dry)': '1969-2010',
#  'fluid catalytic cracking refineries': '1940-2007',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold': '1851-2008',
#  'gold production': '1900-2018',
#  'graphite': '1900-2019',
#  'ground source heat pumps': '1995-2020',
#  'heat thermal battery storage': '2007-2017',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'hib3 vaccine': '1991-2021',
#  'high-density polyethylene': '1958-1972',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'household refrigerators and freezers': '1995-2016',
#  'household washing and drying machines': '1995-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'hydropower': '2010-2021',
#  'hydropower mega-dams': '1936-2013',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'ipv1 vaccine': '2015-2021',
#  'iron': '1933-1970',
#  'iron ore': '1900-2019',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead': '1900-2018',
#  'lead-acid battery': '1989-2012',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1985-2021',
#  'liquefied natural gas (lng)': '1984-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1900-2019',
#  'lithium-ion battery storage': '2008-2021',
#  'lithium-ion cells': '1991-2018',
#  'low-density polyethylene': '1958-1972',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwave ovens': '1995-2016',
#  'microwaves': '1975-2017',
#  'milk': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'motorcycles and scooters': '1996-2016',
#  'natural gas pipeline': '1960-2021',
#  'natural gas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel': '1889-2008',
#  'nickel production': '1900-2018',
#  'nickel-based battery': '2003-2015',
#  'nickel-metal hydride battery': '1997-2014',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nitrogenous fertilizers': '1995-2016',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'objects launched into space': '1957-2022',
#  'offshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'onshore wind energy': '1983-2022',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1900-2005',
#  'passenger vehicles': '1895-2003',
#  'pcv3 vaccine': '2008-2021',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'pol3 vaccine': '1980-2021',
#  'polyester fiber': '1960-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'potassic fertilizers': '1999-2016',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1900-2019',
#  'primary bauxite production': '1900-2019',
#  'primary copper': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'pumped hydropower': '1983-2018',
#  'radial tires': '1972-1984',
#  'radio': '1815-2000',
#  'radio receivers': '1995-2016',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1900-2019',
#  'raw steel production': '1900-2019',
#  'rcv1 vaccine': '1980-2021',
#  'real-time gross settlement adoption': '1970-2005',
#  'refined copper': '1995-2016',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'rotac vaccine': '2006-2021',
#  'running water': '1890-1989',
#  'salt production': '1900-2017',
#  'sand and gravel|construction': '1902-2019',
#  'sand and gravel|industrial': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2008',
#  'silver production': '1900-2018',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'sodium-sulphur battery': '2007-2021',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'soybean production': '1991-2021',
#  'space launches': '1957-2018',
#  'stationary steam engines': '1720-1920',
#  'steam locomotives': '1830-1920',
#  'steamships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sugar cane production': '1991-2021',
#  'sugar output': '1750-2010',
#  'sulphuric acid': '1860-2003',
#  'synthetic filament tow and staple fibers': '1995-2016',
#  'synthetic filament yarn': '1995-2016',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'telephones and videophones': '1995-2016',
#  'television': '1946-2002',
#  'television receivers': '1997-2016',
#  'tin': '1910-2003',
#  'tin production': '1900-2019',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'turbo-jets of a thrust not exceeding 25 kn': '1995-1999',
#  'urea': '1961-1972',
#  'vacuum cleaners': '1995-2016',
#  'vacuums': '1922-1978',
#  'vanadium redox-flow battery': '2008-2019',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2008',
#  'zinc production': '1900-2019',
#  'zinc-based battery': '2013-2020'}

# %%
for item in timespan_dict_lower:
    print(timespan_dict_lower[item])
# Out:
# 1960-1972
# 1959-1972
# 1995-2016
# 2003-2022
# 2014-2018
# 1905-2020
# 1961-1972
# 1960-2020
# 1910-1999
# 1910-1984
# 1980-2021
# 1995-2016
# 1750-2007
# 1952-1968
# 1861-2007
# 1995-2016
# 2010-2021
# 1990-2021
# 2000-2021
# 1959-1972
# 1968-1997
# 1900-2019
# 1794-1861
# 2000-2008
# 1962-1972
# 1960-2020
# 1971-2019
# 1995-2016
# 1995-2016
# 1899-2008
# 1975-2010
# 1900-2019
# 1900-1970
# 1983-2006
# 1908-2000
# 1981-2021
# 1900-2019
# 1966-2005
# 1995-2016
# 1990-2003
# 1991-2020
# 1900-1998
# 1985-2022
# 2010-2021
# 1990-2011
# 1990-2011
# 1991-2021
# 1991-2021
# 1991-2021
# 1961-2001
# 1861-2021
# 1860-2008
# 1956-1972
# 1960-2020
# 1922-2011
# 1966-1984
# 2001-2022
# 1980-2021
# 1980-2021
# 2009-2018
# 1997-2010
# 1933-1986
# 1995-2016
# 1985-2021
# 2012-2016
# 1962-1984
# 1958-1972
# 1955-1972
# 1953-1968
# 1960-1972
# 2000-2018
# 1969-2010
# 1940-2007
# 1860-1989
# 2006-2020
# 1962-1972
# 1950-2011
# 2000-2021
# 1851-2008
# 1900-2018
# 1900-2019
# 1995-2020
# 2007-2017
# 1989-2021
# 2000-2021
# 1996-2022
# 1996-2022
# 1996-2022
# 1991-2021
# 1958-1972
# 1964-2021
# 1957-2011
# 1992-2016
# 1993-2016
# 1995-2016
# 1995-2016
# 2013-2018
# 1929-2003
# 1965-2021
# 1962-1972
# 2012-2017
# 2010-2021
# 1936-2013
# 1996-2022
# 1996-2022
# 1968-2004
# 1984-2014
# 2015-2021
# 1933-1970
# 1900-2019
# 1958-2007
# 1991-2017
# 1920-2006
# 1900-2018
# 1989-2012
# 1987-2020
# 1985-2021
# 1984-2021
# 2001-2021
# 1900-2019
# 2008-2021
# 1991-2018
# 1958-1972
# 1954-1972
# 1952-2004
# 1959-1972
# 2000-2021
# 1980-2021
# 2000-2021
# 1957-1972
# 1984-2016
# 1976-2016
# 1995-2016
# 1975-2017
# 1889-2010
# 1946-1968
# 1900-2008
# 1996-2016
# 1960-2021
# 1903-2000
# 1970-2021
# 1960-1972
# 1889-2008
# 1900-2018
# 2003-2015
# 1997-2014
# 1929-2003
# 1961-2020
# 1995-2016
# 1990-2005
# 1965-2021
# 1945-2010
# 1957-2022
# 2000-2021
# 2001-2021
# 1965-2021
# 1965-2021
# 1983-2022
# 1957-1968
# 1900-2005
# 1895-2003
# 2008-2021
# 1952-1972
# 1959-1972
# 1961-2020
# 1955-1972
# 2006-2015
# 1980-2021
# 1960-1972
# 1943-1968
# 1946-1968
# 1830-2000
# 1961-2020
# 1999-2016
# 1951-1984
# 1900-2019
# 1900-2019
# 1900-2018
# 1929-1968
# 1971-2002
# 1900-2020
# 1944-2020
# 1983-2018
# 1972-1984
# 1815-2000
# 1995-2016
# 1825-2004
# 1949-2004
# 1900-2019
# 1900-2019
# 1980-2021
# 1970-2005
# 1995-2016
# 1918-2009
# 1965-2021
# 2006-2021
# 1890-1989
# 1900-2017
# 1902-2019
# 1902-2019
# 1982-2018
# 2007-2019
# 2001-2009
# 1874-2008
# 1900-2018
# 2011-2019
# 2005-2019
# 1957-1972
# 1958-1972
# 1999-2019
# 2007-2021
# 2000-2021
# 2000-2021
# 2000-2021
# 1991-2021
# 1957-2018
# 1720-1920
# 1830-1920
# 1814-1998
# 1900-2011
# 1958-1972
# 1989-2021
# 1991-2021
# 1750-2010
# 1860-2003
# 1995-2016
# 1995-2016
# 2010-2017
# 1830-2000
# 1876-2003
# 1995-2016
# 1946-2002
# 1997-2016
# 1910-2003
# 1900-2019
# 1950-1968
# 1971-2003
# 1995-1999
# 1961-1972
# 1995-2016
# 1922-1978
# 2008-2019
# 1992-2011
# 1960-1972
# 1962-1972
# 1920-2008
# 1933-1986
# 1972-1999
# 1997-2021
# 1860-2008
# 1900-2019
# 2013-2020

# %%
def metric(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    metric = set(tech_df['Metric'])
    return metric

# %%
metric_dict = {}
for tech in tech_list:
    metric_dict[tech] = metric(tech)
metric_dict
# Out:
# {'Acrylic Fiber': {'Annual production', 'Price'},
#  'Acrylonitrile': {'Annual production', 'Price'},
#  'Air Conditioning Machines': {'Price'},
#  'Air-Source Heat Pumps': {'Annual Production'},
#  'Amazon Prime Users': {'Share of Households'},
#  'Ammonia Synthesis': {'Annual Production'},
#  'Aniline': {'Annual production', 'Price'},
#  'Aquaculture Production': {'Annual production'},
#  'Artificial and Synthetic Fibers': {'Annual Production'},
#  'Automatic Transmission': {'Share of Market'},
#  'BCG Vaccine': {'Share of Population'},
#  'Beer': {'Price'},
#  'Beer Production': {'Annual Production'},
#  'Benzene': {'Annual production', 'Price'},
#  'Bicycles': {'Cumulative Total Capacity'},
#  'Bicycles and Other Cycles': {'Price'},
#  'Bioenergy': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'Biofuels Production': {'Annual Production'},
#  'Biogas': {'Installed electricity capacity'},
#  'BisphenolA': {'Annual production', 'Price'},
#  'CFLs': {'Price'},
#  'Cable TV': {'Share of Households'},
#  'Cadmium Refining': {'Annual production', 'Price'},
#  'Canals': {'Total Length'},
#  'Capillary DNA Sequencing': {'Annual production', 'Price'},
#  'Caprolactam': {'Annual production', 'Price'},
#  'Capture Fisheries': {'Annual production'},
#  'Carbon Capture and Sequestration': {'Installed Capacity'},
#  'Cars': {'Price'},
#  'Caustic Soda': {'Price'},
#  'Caustic Soda Acid': {'Annual Production'},
#  'Cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'Cement': {'Annual production', 'Price'},
#  'Central Heating': {'Share of Households'},
#  'Coal Power': {'Cumulative Total Capacity'},
#  'Coal Production': {'Annual Production', 'Price'},
#  'Cobalt': {'Annual production', 'Price'},
#  'Colour TV': {'Share of Households'},
#  'Combined Refrigerators-Freezers': {'Price'},
#  'Compact Fluorescent Light Bulbs': {'Cumulative Total Capacity'},
#  'Compressed Air Energy Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Computing Growth': {'Computing Capacity'},
#  'Concentrated Solar Power': {'Installed Capacity'},
#  'Concentrating Solar Power': {'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Copper|Mining': {'Annual production'},
#  'Copper|Refining': {'Annual production'},
#  'Corn Production': {'Price'},
#  'Cotton Seed Production': {'Price'},
#  "Cow's Milk Production": {'Price'},
#  'Crop Harvester': {'Total Number'},
#  'Crude Oil': {'Price'},
#  'Crude Petroleum': {'Annual Production'},
#  'Cyclohexane': {'Annual production', 'Price'},
#  'DNA Sequencing (All Methods)': {'Price'},
#  'DTP1 Vaccine': {'Share of Population'},
#  'DTP3 Vaccine': {'Share of Population'},
#  'Desalination Capacity': {'Total Capacity'},
#  'Dishwashers': {'Share of Households'},
#  'Disk Brakes': {'Share of Market'},
#  'Ebook Reader': {'Share of Population'},
#  'Electric Bicycles': {'Cumulative Total Capacity'},
#  'Electric Range': {'Share of Households'},
#  'Electric Water Heaters and Immersion Heaters': {'Price'},
#  'Electricity': {'Annual Production'},
#  'Electro-Chemical Capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Electronic Ignition': {'Share of Market'},
#  'Ethanol': {'Annual production', 'Price'},
#  'Ethanolamine': {'Annual production', 'Price'},
#  'Ethylene': {'Annual production', 'Price'},
#  'Ethylene Glycol': {'Annual production', 'Price'},
#  'Flow Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Flue Gas Desulphurization (Wet and Dry)': {'Price'},
#  'Fluid Catalytic Cracking Refineries': {'Average Capacity of Unit Additions',
#   'Net Total Capacity'},
#  'Flush Toilet': {'Share of Households'},
#  'Flywheel Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Formaldehyde': {'Annual production', 'Price'},
#  'Freezer': {'Share of Households'},
#  'Geothermal Energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Gold': {'Annual Production'},
#  'Gold Production': {'Annual production', 'Price'},
#  'Graphite': {'Annual production', 'Price'},
#  'Ground Source Heat Pumps': {'Cumulative Total Capacity'},
#  'HEPB3 Vaccine': {'Share of Population'},
#  'HEPBB Vaccine': {'Share of Population'},
#  'HIB3 Vaccine': {'Share of Population'},
#  'Heat Thermal Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Herbicide-Tolerant Corn': {'Cumulative Acreage'},
#  'Herbicide-Tolerant Cotton': {'Cumulative Acreage'},
#  'Herbicide-Tolerant Soybeans': {'Cumulative Acreage'},
#  'High-Density Polyethylene': {'Annual production', 'Price'},
#  'High-Speed Rail': {'Cumulative Total Capacity'},
#  'Home Air Conditioning': {'Share of Households'},
#  'Home Computers': {'Share of Households'},
#  'Household Internet Access': {'Share of Households'},
#  'Household Refrigerators and Freezers': {'Price'},
#  'Household Washing and Drying Machines': {'Price'},
#  'Households With Only Mobile Phones (No Landlines)': {'Share of Households'},
#  'Hydrochloric Acid': {'Annual Production'},
#  'Hydroelectricity': {'Annual Production'},
#  'Hydrofluoric Acid': {'Annual production', 'Price'},
#  'Hydrogen Storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'Hydropower': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'Hydropower Mega-Dams': {'Price'},
#  'IPV1 Vaccine': {'Share of Population'},
#  'Insect-Resistant Corn': {'Cumulative Acreage'},
#  'Insect-Resistant Cotton': {'Cumulative Acreage'},
#  'Internet Backbone Bandwidth': {'Computing Capacity'},
#  'Internet Traffic': {'Computing Capacity'},
#  'Iron': {'Share of Households'},
#  'Iron Ore': {'Annual production', 'Price'},
#  'Jet Aircraft': {'Cumulative Total Capacity'},
#  'Latent Heat Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Laundry Dryers': {'Cumulative Total Capacity'},
#  'Lead': {'Annual production', 'Price'},
#  'Lead-Acid Battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Lead-Acid Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Liquefied Natural Gas': {'Annual Production'},
#  'Liquefied Natural Gas (LNG)': {'Price'},
#  'Liquid Biofuels': {'Installed electricity capacity'},
#  'Lithium Mine Production': {'Annual production', 'Price'},
#  'Lithium-Ion Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Lithium-Ion Cells': {'Price'},
#  'Low-Density Polyethylene': {'Annual production', 'Price'},
#  'MCV1 Vaccine': {'Share of Population'},
#  'MCV2 Vaccine': {'Share of Population'},
#  'Magnesium': {'Annual production', 'Price'},
#  'Magnetic Data Storage': {'Computing Capacity'},
#  'Maleic Anhydride': {'Annual production', 'Price'},
#  'Marine Energy': {'Installed electricity capacity'},
#  'Methanol': {'Annual production', 'Price'},
#  'Microcomputers': {'Share of Households'},
#  'Microprocessor Clock Speed': {'Computing Capacity'},
#  'Microwave Ovens': {'Price'},
#  'Microwaves': {'Share of Households'},
#  'Milk': {'Annual Production'},
#  'Motor Gasoline': {'Annual production', 'Price'},
#  'Motorcycles': {'Cumulative Total Capacity'},
#  'Motorcycles and Scooters': {'Price'},
#  'Natural Gas Pipeline': {'Total Length'},
#  'Natural Gas Power': {'Cumulative Total Capacity'},
#  'Natural Gas Production': {'Annual Production', 'Price'},
#  'Neoprene Rubber': {'Annual production', 'Price'},
#  'Nickel': {'Annual Production'},
#  'Nickel Production': {'Annual production', 'Price'},
#  'Nickel-Based Battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Nickel-Metal Hydride Battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Nitric Acid': {'Annual Production'},
#  'Nitrogen Fertilizer': {'Annual Production'},
#  'Nitrogenous Fertilizers': {'Price'},
#  'Nox Pollution Controls (Boilers)': {'Share of Boilers'},
#  'Nuclear Energy': {'Annual Production'},
#  'Nuclear Weapons': {'Total Number'},
#  'Objects Launched Into Space': {'Total Number'},
#  'Offshore Wind Energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Oil Pipeline': {'Total Length'},
#  'Oil Production': {'Annual Production'},
#  'Oil Refining Capacity': {'Total Capacity'},
#  'Onshore Wind Energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'PCV3 Vaccine': {'Share of Population'},
#  'POL3 Vaccine': {'Share of Population'},
#  'Paraxylene': {'Annual production', 'Price'},
#  'Passenger Cars': {'Cumulative Total Capacity'},
#  'Passenger Vehicles': {'Total Number'},
#  'Pentaerythritol': {'Annual production', 'Price'},
#  'Phenol': {'Annual production', 'Price'},
#  'Phosphate Fertilizer': {'Annual Production'},
#  'Phthalic Anhydride': {'Annual production', 'Price'},
#  'Podcasting': {'Share of Population'},
#  'Polyester Fiber': {'Annual production', 'Price'},
#  'Polystyrene': {'Annual production', 'Price'},
#  'Polyvinylchloride': {'Annual production', 'Price'},
#  'Postal Traffic': {'Total Number'},
#  'Potash Fertilizer': {'Annual Production'},
#  'Potassic Fertilizers': {'Price'},
#  'Power Steering': {'Share of Market'},
#  'Primary Aluminum Production': {'Annual production', 'Price'},
#  'Primary Bauxite Production': {'Annual production', 'Price'},
#  'Primary Copper': {'Annual production', 'Price'},
#  'Primary Magnesium': {'Annual production', 'Price'},
#  'Processor Performance': {'Computing Capacity'},
#  'Public Roads': {'Total Length'},
#  'Pumped Hydro Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Pumped Hydropower': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'RCV1 Vaccine': {'Share of Population'},
#  'ROTAC Vaccine': {'Share of Population'},
#  'Radial Tires': {'Share of Market'},
#  'Radio': {'Total Number'},
#  'Radio Receivers': {'Price'},
#  'Railroad': {'Total Length'},
#  'Random Access Memory': {'Computing Capacity'},
#  'Rare Earth Mine Production': {'Annual production', 'Price'},
#  'Raw Steel Production': {'Annual production', 'Price'},
#  'Real-Time Gross Settlement Adoption': {'Share of Market'},
#  'Refined Copper': {'Price'},
#  'Refrigerators': {'Cumulative Total Capacity'},
#  'Renewable Power': {'Annual Production'},
#  'Running Water': {'Share of Households'},
#  'Salt Production': {'Annual production', 'Price'},
#  'Sand and Gravel|Construction': {'Annual production', 'Price'},
#  'Sand and Gravel|Industrial': {'Annual production', 'Price'},
#  'Sensible Heat Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Shale Production': {'Annual production'},
#  'Shotgun Sanger DNA Sequencing': {'Price', 'Total Number'},
#  'Silver': {'Annual Production'},
#  'Silver Production': {'Annual production', 'Price'},
#  'Smartphone Usage': {'Share of Population'},
#  'Social Media Usage': {'Share of Population'},
#  'Sodium': {'Annual production', 'Price'},
#  'Sodium Chlorate': {'Annual production', 'Price'},
#  'Sodium-Based Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Sodium-Sulphur Battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Solar Photovoltaic': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Solar Thermal Energy': {'Installed electricity capacity'},
#  'Solid Biofuels': {'Installed electricity capacity'},
#  'Soybean Production': {'Price'},
#  'Space Launches': {'Price'},
#  'Stationary Steam Engines': {'Cumulative Total Capacity'},
#  'Steam Locomotives': {'Cumulative Total Capacity'},
#  'Steamships': {'Total Number'},
#  'Stove': {'Share of Households'},
#  'Styrene': {'Annual production', 'Price'},
#  'Submarine Cables': {'Cumulative Length'},
#  'Sugar Cane Production': {'Price'},
#  'Sugar Output': {'Annual Production'},
#  'Sulphuric Acid': {'Annual Production'},
#  'Synthetic Filament Tow and Staple Fibers': {'Price'},
#  'Synthetic Filament Yarn': {'Price'},
#  'Tablet': {'Share of Population'},
#  'Telegraph Traffic': {'Total Number'},
#  'Telephones': {'Total Number'},
#  'Telephones and Videophones': {'Price'},
#  'Television': {'Total Number'},
#  'Television Receivers': {'Price'},
#  'Tin': {'Annual Production'},
#  'Tin Production': {'Annual production', 'Price'},
#  'Titanium Sponge': {'Annual production', 'Price'},
#  'Transistors per Microprocessor': {'Computing Capacity'},
#  'Turbo-Jets of a Thrust Not Exceeding 25 kN': {'Price'},
#  'Urea': {'Annual production', 'Price'},
#  'Vacuum Cleaners': {'Price'},
#  'Vacuums': {'Share of Households'},
#  'Vanadium Redox-Flow Battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Videocassette Recorder': {'Share of Households'},
#  'Vinyl Acetate': {'Annual production', 'Price'},
#  'Vinyl Chloride': {'Annual production', 'Price'},
#  'Washing Machines': {'Cumulative Total Capacity'},
#  'Water Heater': {'Share of Households'},
#  'Wet Flue Gas Desulfurization Systems': {'Cumulative Total Capacity'},
#  'YFV Vaccine': {'Share of Population'},
#  'Zinc': {'Annual Production'},
#  'Zinc Production': {'Annual production', 'Price'},
#  'Zinc-Based Battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
metric_dict_lower = {}
for item in metric_dict:
    metric_dict_lower[item.lower()] = metric_dict[item]
metric_dict_lower
# Out:
# {'acrylic fiber': {'Annual production', 'Price'},
#  'acrylonitrile': {'Annual production', 'Price'},
#  'air conditioning machines': {'Price'},
#  'air-source heat pumps': {'Annual Production'},
#  'amazon prime users': {'Share of Households'},
#  'ammonia synthesis': {'Annual Production'},
#  'aniline': {'Annual production', 'Price'},
#  'aquaculture production': {'Annual production'},
#  'artificial and synthetic fibers': {'Annual Production'},
#  'automatic transmission': {'Share of Market'},
#  'bcg vaccine': {'Share of Population'},
#  'beer': {'Price'},
#  'beer production': {'Annual Production'},
#  'benzene': {'Annual production', 'Price'},
#  'bicycles': {'Cumulative Total Capacity'},
#  'bicycles and other cycles': {'Price'},
#  'bioenergy': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'biofuels production': {'Annual Production'},
#  'biogas': {'Installed electricity capacity'},
#  'bisphenola': {'Annual production', 'Price'},
#  'cfls': {'Price'},
#  'cable tv': {'Share of Households'},
#  'cadmium refining': {'Annual production', 'Price'},
#  'canals': {'Total Length'},
#  'capillary dna sequencing': {'Annual production', 'Price'},
#  'caprolactam': {'Annual production', 'Price'},
#  'capture fisheries': {'Annual production'},
#  'carbon capture and sequestration': {'Installed Capacity'},
#  'cars': {'Price'},
#  'caustic soda': {'Price'},
#  'caustic soda acid': {'Annual Production'},
#  'cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'cement': {'Annual production', 'Price'},
#  'central heating': {'Share of Households'},
#  'coal power': {'Cumulative Total Capacity'},
#  'coal production': {'Annual Production', 'Price'},
#  'cobalt': {'Annual production', 'Price'},
#  'colour tv': {'Share of Households'},
#  'combined refrigerators-freezers': {'Price'},
#  'compact fluorescent light bulbs': {'Cumulative Total Capacity'},
#  'compressed air energy storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'computing growth': {'Computing Capacity'},
#  'concentrated solar power': {'Installed Capacity'},
#  'concentrating solar power': {'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'copper|mining': {'Annual production'},
#  'copper|refining': {'Annual production'},
#  'corn production': {'Price'},
#  'cotton seed production': {'Price'},
#  "cow's milk production": {'Price'},
#  'crop harvester': {'Total Number'},
#  'crude oil': {'Price'},
#  'crude petroleum': {'Annual Production'},
#  'cyclohexane': {'Annual production', 'Price'},
#  'dna sequencing (all methods)': {'Price'},
#  'dtp1 vaccine': {'Share of Population'},
#  'dtp3 vaccine': {'Share of Population'},
#  'desalination capacity': {'Total Capacity'},
#  'dishwashers': {'Share of Households'},
#  'disk brakes': {'Share of Market'},
#  'ebook reader': {'Share of Population'},
#  'electric bicycles': {'Cumulative Total Capacity'},
#  'electric range': {'Share of Households'},
#  'electric water heaters and immersion heaters': {'Price'},
#  'electricity': {'Annual Production'},
#  'electro-chemical capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'electronic ignition': {'Share of Market'},
#  'ethanol': {'Annual production', 'Price'},
#  'ethanolamine': {'Annual production', 'Price'},
#  'ethylene': {'Annual production', 'Price'},
#  'ethylene glycol': {'Annual production', 'Price'},
#  'flow battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'flue gas desulphurization (wet and dry)': {'Price'},
#  'fluid catalytic cracking refineries': {'Average Capacity of Unit Additions',
#   'Net Total Capacity'},
#  'flush toilet': {'Share of Households'},
#  'flywheel battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'formaldehyde': {'Annual production', 'Price'},
#  'freezer': {'Share of Households'},
#  'geothermal energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'gold': {'Annual Production'},
#  'gold production': {'Annual production', 'Price'},
#  'graphite': {'Annual production', 'Price'},
#  'ground source heat pumps': {'Cumulative Total Capacity'},
#  'hepb3 vaccine': {'Share of Population'},
#  'hepbb vaccine': {'Share of Population'},
#  'hib3 vaccine': {'Share of Population'},
#  'heat thermal battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'herbicide-tolerant corn': {'Cumulative Acreage'},
#  'herbicide-tolerant cotton': {'Cumulative Acreage'},
#  'herbicide-tolerant soybeans': {'Cumulative Acreage'},
#  'high-density polyethylene': {'Annual production', 'Price'},
#  'high-speed rail': {'Cumulative Total Capacity'},
#  'home air conditioning': {'Share of Households'},
#  'home computers': {'Share of Households'},
#  'household internet access': {'Share of Households'},
#  'household refrigerators and freezers': {'Price'},
#  'household washing and drying machines': {'Price'},
#  'households with only mobile phones (no landlines)': {'Share of Households'},
#  'hydrochloric acid': {'Annual Production'},
#  'hydroelectricity': {'Annual Production'},
#  'hydrofluoric acid': {'Annual production', 'Price'},
#  'hydrogen storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'hydropower': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'hydropower mega-dams': {'Price'},
#  'ipv1 vaccine': {'Share of Population'},
#  'insect-resistant corn': {'Cumulative Acreage'},
#  'insect-resistant cotton': {'Cumulative Acreage'},
#  'internet backbone bandwidth': {'Computing Capacity'},
#  'internet traffic': {'Computing Capacity'},
#  'iron': {'Share of Households'},
#  'iron ore': {'Annual production', 'Price'},
#  'jet aircraft': {'Cumulative Total Capacity'},
#  'latent heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'laundry dryers': {'Cumulative Total Capacity'},
#  'lead': {'Annual production', 'Price'},
#  'lead-acid battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'lead-acid battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'liquefied natural gas': {'Annual Production'},
#  'liquefied natural gas (lng)': {'Price'},
#  'liquid biofuels': {'Installed electricity capacity'},
#  'lithium mine production': {'Annual production', 'Price'},
#  'lithium-ion battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'lithium-ion cells': {'Price'},
#  'low-density polyethylene': {'Annual production', 'Price'},
#  'mcv1 vaccine': {'Share of Population'},
#  'mcv2 vaccine': {'Share of Population'},
#  'magnesium': {'Annual production', 'Price'},
#  'magnetic data storage': {'Computing Capacity'},
#  'maleic anhydride': {'Annual production', 'Price'},
#  'marine energy': {'Installed electricity capacity'},
#  'methanol': {'Annual production', 'Price'},
#  'microcomputers': {'Share of Households'},
#  'microprocessor clock speed': {'Computing Capacity'},
#  'microwave ovens': {'Price'},
#  'microwaves': {'Share of Households'},
#  'milk': {'Annual Production'},
#  'motor gasoline': {'Annual production', 'Price'},
#  'motorcycles': {'Cumulative Total Capacity'},
#  'motorcycles and scooters': {'Price'},
#  'natural gas pipeline': {'Total Length'},
#  'natural gas power': {'Cumulative Total Capacity'},
#  'natural gas production': {'Annual Production', 'Price'},
#  'neoprene rubber': {'Annual production', 'Price'},
#  'nickel': {'Annual Production'},
#  'nickel production': {'Annual production', 'Price'},
#  'nickel-based battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'nickel-metal hydride battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'nitric acid': {'Annual Production'},
#  'nitrogen fertilizer': {'Annual Production'},
#  'nitrogenous fertilizers': {'Price'},
#  'nox pollution controls (boilers)': {'Share of Boilers'},
#  'nuclear energy': {'Annual Production'},
#  'nuclear weapons': {'Total Number'},
#  'objects launched into space': {'Total Number'},
#  'offshore wind energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'oil pipeline': {'Total Length'},
#  'oil production': {'Annual Production'},
#  'oil refining capacity': {'Total Capacity'},
#  'onshore wind energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'pcv3 vaccine': {'Share of Population'},
#  'pol3 vaccine': {'Share of Population'},
#  'paraxylene': {'Annual production', 'Price'},
#  'passenger cars': {'Cumulative Total Capacity'},
#  'passenger vehicles': {'Total Number'},
#  'pentaerythritol': {'Annual production', 'Price'},
#  'phenol': {'Annual production', 'Price'},
#  'phosphate fertilizer': {'Annual Production'},
#  'phthalic anhydride': {'Annual production', 'Price'},
#  'podcasting': {'Share of Population'},
#  'polyester fiber': {'Annual production', 'Price'},
#  'polystyrene': {'Annual production', 'Price'},
#  'polyvinylchloride': {'Annual production', 'Price'},
#  'postal traffic': {'Total Number'},
#  'potash fertilizer': {'Annual Production'},
#  'potassic fertilizers': {'Price'},
#  'power steering': {'Share of Market'},
#  'primary aluminum production': {'Annual production', 'Price'},
#  'primary bauxite production': {'Annual production', 'Price'},
#  'primary copper': {'Annual production', 'Price'},
#  'primary magnesium': {'Annual production', 'Price'},
#  'processor performance': {'Computing Capacity'},
#  'public roads': {'Total Length'},
#  'pumped hydro storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'pumped hydropower': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'rcv1 vaccine': {'Share of Population'},
#  'rotac vaccine': {'Share of Population'},
#  'radial tires': {'Share of Market'},
#  'radio': {'Total Number'},
#  'radio receivers': {'Price'},
#  'railroad': {'Total Length'},
#  'random access memory': {'Computing Capacity'},
#  'rare earth mine production': {'Annual production', 'Price'},
#  'raw steel production': {'Annual production', 'Price'},
#  'real-time gross settlement adoption': {'Share of Market'},
#  'refined copper': {'Price'},
#  'refrigerators': {'Cumulative Total Capacity'},
#  'renewable power': {'Annual Production'},
#  'running water': {'Share of Households'},
#  'salt production': {'Annual production', 'Price'},
#  'sand and gravel|construction': {'Annual production', 'Price'},
#  'sand and gravel|industrial': {'Annual production', 'Price'},
#  'sensible heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'shale production': {'Annual production'},
#  'shotgun sanger dna sequencing': {'Price', 'Total Number'},
#  'silver': {'Annual Production'},
#  'silver production': {'Annual production', 'Price'},
#  'smartphone usage': {'Share of Population'},
#  'social media usage': {'Share of Population'},
#  'sodium': {'Annual production', 'Price'},
#  'sodium chlorate': {'Annual production', 'Price'},
#  'sodium-based battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'sodium-sulphur battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'solar photovoltaic': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'solar thermal energy': {'Installed electricity capacity'},
#  'solid biofuels': {'Installed electricity capacity'},
#  'soybean production': {'Price'},
#  'space launches': {'Price'},
#  'stationary steam engines': {'Cumulative Total Capacity'},
#  'steam locomotives': {'Cumulative Total Capacity'},
#  'steamships': {'Total Number'},
#  'stove': {'Share of Households'},
#  'styrene': {'Annual production', 'Price'},
#  'submarine cables': {'Cumulative Length'},
#  'sugar cane production': {'Price'},
#  'sugar output': {'Annual Production'},
#  'sulphuric acid': {'Annual Production'},
#  'synthetic filament tow and staple fibers': {'Price'},
#  'synthetic filament yarn': {'Price'},
#  'tablet': {'Share of Population'},
#  'telegraph traffic': {'Total Number'},
#  'telephones': {'Total Number'},
#  'telephones and videophones': {'Price'},
#  'television': {'Total Number'},
#  'television receivers': {'Price'},
#  'tin': {'Annual Production'},
#  'tin production': {'Annual production', 'Price'},
#  'titanium sponge': {'Annual production', 'Price'},
#  'transistors per microprocessor': {'Computing Capacity'},
#  'turbo-jets of a thrust not exceeding 25 kn': {'Price'},
#  'urea': {'Annual production', 'Price'},
#  'vacuum cleaners': {'Price'},
#  'vacuums': {'Share of Households'},
#  'vanadium redox-flow battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'videocassette recorder': {'Share of Households'},
#  'vinyl acetate': {'Annual production', 'Price'},
#  'vinyl chloride': {'Annual production', 'Price'},
#  'washing machines': {'Cumulative Total Capacity'},
#  'water heater': {'Share of Households'},
#  'wet flue gas desulfurization systems': {'Cumulative Total Capacity'},
#  'yfv vaccine': {'Share of Population'},
#  'zinc': {'Annual Production'},
#  'zinc production': {'Annual production', 'Price'},
#  'zinc-based battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
metric_dict_lower = dict(sorted(metric_dict_lower.items(), key=lambda item: item[0])) 
metric_dict_lower
# Out:
# {'acrylic fiber': {'Annual production', 'Price'},
#  'acrylonitrile': {'Annual production', 'Price'},
#  'air conditioning machines': {'Price'},
#  'air-source heat pumps': {'Annual Production'},
#  'amazon prime users': {'Share of Households'},
#  'ammonia synthesis': {'Annual Production'},
#  'aniline': {'Annual production', 'Price'},
#  'aquaculture production': {'Annual production'},
#  'artificial and synthetic fibers': {'Annual Production'},
#  'automatic transmission': {'Share of Market'},
#  'bcg vaccine': {'Share of Population'},
#  'beer': {'Price'},
#  'beer production': {'Annual Production'},
#  'benzene': {'Annual production', 'Price'},
#  'bicycles': {'Cumulative Total Capacity'},
#  'bicycles and other cycles': {'Price'},
#  'bioenergy': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'biofuels production': {'Annual Production'},
#  'biogas': {'Installed electricity capacity'},
#  'bisphenola': {'Annual production', 'Price'},
#  'cable tv': {'Share of Households'},
#  'cadmium refining': {'Annual production', 'Price'},
#  'canals': {'Total Length'},
#  'capillary dna sequencing': {'Annual production', 'Price'},
#  'caprolactam': {'Annual production', 'Price'},
#  'capture fisheries': {'Annual production'},
#  'carbon capture and sequestration': {'Installed Capacity'},
#  'cars': {'Price'},
#  'caustic soda': {'Price'},
#  'caustic soda acid': {'Annual Production'},
#  'cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'cement': {'Annual production', 'Price'},
#  'central heating': {'Share of Households'},
#  'cfls': {'Price'},
#  'coal power': {'Cumulative Total Capacity'},
#  'coal production': {'Annual Production', 'Price'},
#  'cobalt': {'Annual production', 'Price'},
#  'colour tv': {'Share of Households'},
#  'combined refrigerators-freezers': {'Price'},
#  'compact fluorescent light bulbs': {'Cumulative Total Capacity'},
#  'compressed air energy storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'computing growth': {'Computing Capacity'},
#  'concentrated solar power': {'Installed Capacity'},
#  'concentrating solar power': {'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'copper|mining': {'Annual production'},
#  'copper|refining': {'Annual production'},
#  'corn production': {'Price'},
#  'cotton seed production': {'Price'},
#  "cow's milk production": {'Price'},
#  'crop harvester': {'Total Number'},
#  'crude oil': {'Price'},
#  'crude petroleum': {'Annual Production'},
#  'cyclohexane': {'Annual production', 'Price'},
#  'desalination capacity': {'Total Capacity'},
#  'dishwashers': {'Share of Households'},
#  'disk brakes': {'Share of Market'},
#  'dna sequencing (all methods)': {'Price'},
#  'dtp1 vaccine': {'Share of Population'},
#  'dtp3 vaccine': {'Share of Population'},
#  'ebook reader': {'Share of Population'},
#  'electric bicycles': {'Cumulative Total Capacity'},
#  'electric range': {'Share of Households'},
#  'electric water heaters and immersion heaters': {'Price'},
#  'electricity': {'Annual Production'},
#  'electro-chemical capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'electronic ignition': {'Share of Market'},
#  'ethanol': {'Annual production', 'Price'},
#  'ethanolamine': {'Annual production', 'Price'},
#  'ethylene': {'Annual production', 'Price'},
#  'ethylene glycol': {'Annual production', 'Price'},
#  'flow battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'flue gas desulphurization (wet and dry)': {'Price'},
#  'fluid catalytic cracking refineries': {'Average Capacity of Unit Additions',
#   'Net Total Capacity'},
#  'flush toilet': {'Share of Households'},
#  'flywheel battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'formaldehyde': {'Annual production', 'Price'},
#  'freezer': {'Share of Households'},
#  'geothermal energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'gold': {'Annual Production'},
#  'gold production': {'Annual production', 'Price'},
#  'graphite': {'Annual production', 'Price'},
#  'ground source heat pumps': {'Cumulative Total Capacity'},
#  'heat thermal battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'hepb3 vaccine': {'Share of Population'},
#  'hepbb vaccine': {'Share of Population'},
#  'herbicide-tolerant corn': {'Cumulative Acreage'},
#  'herbicide-tolerant cotton': {'Cumulative Acreage'},
#  'herbicide-tolerant soybeans': {'Cumulative Acreage'},
#  'hib3 vaccine': {'Share of Population'},
#  'high-density polyethylene': {'Annual production', 'Price'},
#  'high-speed rail': {'Cumulative Total Capacity'},
#  'home air conditioning': {'Share of Households'},
#  'home computers': {'Share of Households'},
#  'household internet access': {'Share of Households'},
#  'household refrigerators and freezers': {'Price'},
#  'household washing and drying machines': {'Price'},
#  'households with only mobile phones (no landlines)': {'Share of Households'},
#  'hydrochloric acid': {'Annual Production'},
#  'hydroelectricity': {'Annual Production'},
#  'hydrofluoric acid': {'Annual production', 'Price'},
#  'hydrogen storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'hydropower': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'hydropower mega-dams': {'Price'},
#  'insect-resistant corn': {'Cumulative Acreage'},
#  'insect-resistant cotton': {'Cumulative Acreage'},
#  'internet backbone bandwidth': {'Computing Capacity'},
#  'internet traffic': {'Computing Capacity'},
#  'ipv1 vaccine': {'Share of Population'},
#  'iron': {'Share of Households'},
#  'iron ore': {'Annual production', 'Price'},
#  'jet aircraft': {'Cumulative Total Capacity'},
#  'latent heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'laundry dryers': {'Cumulative Total Capacity'},
#  'lead': {'Annual production', 'Price'},
#  'lead-acid battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'lead-acid battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'liquefied natural gas': {'Annual Production'},
#  'liquefied natural gas (lng)': {'Price'},
#  'liquid biofuels': {'Installed electricity capacity'},
#  'lithium mine production': {'Annual production', 'Price'},
#  'lithium-ion battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'lithium-ion cells': {'Price'},
#  'low-density polyethylene': {'Annual production', 'Price'},
#  'magnesium': {'Annual production', 'Price'},
#  'magnetic data storage': {'Computing Capacity'},
#  'maleic anhydride': {'Annual production', 'Price'},
#  'marine energy': {'Installed electricity capacity'},
#  'mcv1 vaccine': {'Share of Population'},
#  'mcv2 vaccine': {'Share of Population'},
#  'methanol': {'Annual production', 'Price'},
#  'microcomputers': {'Share of Households'},
#  'microprocessor clock speed': {'Computing Capacity'},
#  'microwave ovens': {'Price'},
#  'microwaves': {'Share of Households'},
#  'milk': {'Annual Production'},
#  'motor gasoline': {'Annual production', 'Price'},
#  'motorcycles': {'Cumulative Total Capacity'},
#  'motorcycles and scooters': {'Price'},
#  'natural gas pipeline': {'Total Length'},
#  'natural gas power': {'Cumulative Total Capacity'},
#  'natural gas production': {'Annual Production', 'Price'},
#  'neoprene rubber': {'Annual production', 'Price'},
#  'nickel': {'Annual Production'},
#  'nickel production': {'Annual production', 'Price'},
#  'nickel-based battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'nickel-metal hydride battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'nitric acid': {'Annual Production'},
#  'nitrogen fertilizer': {'Annual Production'},
#  'nitrogenous fertilizers': {'Price'},
#  'nox pollution controls (boilers)': {'Share of Boilers'},
#  'nuclear energy': {'Annual Production'},
#  'nuclear weapons': {'Total Number'},
#  'objects launched into space': {'Total Number'},
#  'offshore wind energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'oil pipeline': {'Total Length'},
#  'oil production': {'Annual Production'},
#  'oil refining capacity': {'Total Capacity'},
#  'onshore wind energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'paraxylene': {'Annual production', 'Price'},
#  'passenger cars': {'Cumulative Total Capacity'},
#  'passenger vehicles': {'Total Number'},
#  'pcv3 vaccine': {'Share of Population'},
#  'pentaerythritol': {'Annual production', 'Price'},
#  'phenol': {'Annual production', 'Price'},
#  'phosphate fertilizer': {'Annual Production'},
#  'phthalic anhydride': {'Annual production', 'Price'},
#  'podcasting': {'Share of Population'},
#  'pol3 vaccine': {'Share of Population'},
#  'polyester fiber': {'Annual production', 'Price'},
#  'polystyrene': {'Annual production', 'Price'},
#  'polyvinylchloride': {'Annual production', 'Price'},
#  'postal traffic': {'Total Number'},
#  'potash fertilizer': {'Annual Production'},
#  'potassic fertilizers': {'Price'},
#  'power steering': {'Share of Market'},
#  'primary aluminum production': {'Annual production', 'Price'},
#  'primary bauxite production': {'Annual production', 'Price'},
#  'primary copper': {'Annual production', 'Price'},
#  'primary magnesium': {'Annual production', 'Price'},
#  'processor performance': {'Computing Capacity'},
#  'public roads': {'Total Length'},
#  'pumped hydro storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'pumped hydropower': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'radial tires': {'Share of Market'},
#  'radio': {'Total Number'},
#  'radio receivers': {'Price'},
#  'railroad': {'Total Length'},
#  'random access memory': {'Computing Capacity'},
#  'rare earth mine production': {'Annual production', 'Price'},
#  'raw steel production': {'Annual production', 'Price'},
#  'rcv1 vaccine': {'Share of Population'},
#  'real-time gross settlement adoption': {'Share of Market'},
#  'refined copper': {'Price'},
#  'refrigerators': {'Cumulative Total Capacity'},
#  'renewable power': {'Annual Production'},
#  'rotac vaccine': {'Share of Population'},
#  'running water': {'Share of Households'},
#  'salt production': {'Annual production', 'Price'},
#  'sand and gravel|construction': {'Annual production', 'Price'},
#  'sand and gravel|industrial': {'Annual production', 'Price'},
#  'sensible heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'shale production': {'Annual production'},
#  'shotgun sanger dna sequencing': {'Price', 'Total Number'},
#  'silver': {'Annual Production'},
#  'silver production': {'Annual production', 'Price'},
#  'smartphone usage': {'Share of Population'},
#  'social media usage': {'Share of Population'},
#  'sodium': {'Annual production', 'Price'},
#  'sodium chlorate': {'Annual production', 'Price'},
#  'sodium-based battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'sodium-sulphur battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'solar photovoltaic': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'solar thermal energy': {'Installed electricity capacity'},
#  'solid biofuels': {'Installed electricity capacity'},
#  'soybean production': {'Price'},
#  'space launches': {'Price'},
#  'stationary steam engines': {'Cumulative Total Capacity'},
#  'steam locomotives': {'Cumulative Total Capacity'},
#  'steamships': {'Total Number'},
#  'stove': {'Share of Households'},
#  'styrene': {'Annual production', 'Price'},
#  'submarine cables': {'Cumulative Length'},
#  'sugar cane production': {'Price'},
#  'sugar output': {'Annual Production'},
#  'sulphuric acid': {'Annual Production'},
#  'synthetic filament tow and staple fibers': {'Price'},
#  'synthetic filament yarn': {'Price'},
#  'tablet': {'Share of Population'},
#  'telegraph traffic': {'Total Number'},
#  'telephones': {'Total Number'},
#  'telephones and videophones': {'Price'},
#  'television': {'Total Number'},
#  'television receivers': {'Price'},
#  'tin': {'Annual Production'},
#  'tin production': {'Annual production', 'Price'},
#  'titanium sponge': {'Annual production', 'Price'},
#  'transistors per microprocessor': {'Computing Capacity'},
#  'turbo-jets of a thrust not exceeding 25 kn': {'Price'},
#  'urea': {'Annual production', 'Price'},
#  'vacuum cleaners': {'Price'},
#  'vacuums': {'Share of Households'},
#  'vanadium redox-flow battery': {'Cumulative Total Capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'videocassette recorder': {'Share of Households'},
#  'vinyl acetate': {'Annual production', 'Price'},
#  'vinyl chloride': {'Annual production', 'Price'},
#  'washing machines': {'Cumulative Total Capacity'},
#  'water heater': {'Share of Households'},
#  'wet flue gas desulfurization systems': {'Cumulative Total Capacity'},
#  'yfv vaccine': {'Share of Population'},
#  'zinc': {'Annual Production'},
#  'zinc production': {'Annual production', 'Price'},
#  'zinc-based battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
for item in metric_dict_lower:
    print(item)
# Out:
# acrylic fiber
# acrylonitrile
# air conditioning machines
# air-source heat pumps
# amazon prime users
# ammonia synthesis
# aniline
# aquaculture production
# artificial and synthetic fibers
# automatic transmission
# bcg vaccine
# beer
# beer production
# benzene
# bicycles
# bicycles and other cycles
# bioenergy
# biofuels production
# biogas
# bisphenola
# cable tv
# cadmium refining
# canals
# capillary dna sequencing
# caprolactam
# capture fisheries
# carbon capture and sequestration
# cars
# caustic soda
# caustic soda acid
# cellphones
# cement
# central heating
# cfls
# coal power
# coal production
# cobalt
# colour tv
# combined refrigerators-freezers
# compact fluorescent light bulbs
# compressed air energy storage
# computing growth
# concentrated solar power
# concentrating solar power
# copper|mining
# copper|refining
# corn production
# cotton seed production
# cow's milk production
# crop harvester
# crude oil
# crude petroleum
# cyclohexane
# desalination capacity
# dishwashers
# disk brakes
# dna sequencing (all methods)
# dtp1 vaccine
# dtp3 vaccine
# ebook reader
# electric bicycles
# electric range
# electric water heaters and immersion heaters
# electricity
# electro-chemical capacitor
# electronic ignition
# ethanol
# ethanolamine
# ethylene
# ethylene glycol
# flow battery storage
# flue gas desulphurization (wet and dry)
# fluid catalytic cracking refineries
# flush toilet
# flywheel battery storage
# formaldehyde
# freezer
# geothermal energy
# gold
# gold production
# graphite
# ground source heat pumps
# heat thermal battery storage
# hepb3 vaccine
# hepbb vaccine
# herbicide-tolerant corn
# herbicide-tolerant cotton
# herbicide-tolerant soybeans
# hib3 vaccine
# high-density polyethylene
# high-speed rail
# home air conditioning
# home computers
# household internet access
# household refrigerators and freezers
# household washing and drying machines
# households with only mobile phones (no landlines)
# hydrochloric acid
# hydroelectricity
# hydrofluoric acid
# hydrogen storage
# hydropower
# hydropower mega-dams
# insect-resistant corn
# insect-resistant cotton
# internet backbone bandwidth
# internet traffic
# ipv1 vaccine
# iron
# iron ore
# jet aircraft
# latent heat storage
# laundry dryers
# lead
# lead-acid battery
# lead-acid battery storage
# liquefied natural gas
# liquefied natural gas (lng)
# liquid biofuels
# lithium mine production
# lithium-ion battery storage
# lithium-ion cells
# low-density polyethylene
# magnesium
# magnetic data storage
# maleic anhydride
# marine energy
# mcv1 vaccine
# mcv2 vaccine
# methanol
# microcomputers
# microprocessor clock speed
# microwave ovens
# microwaves
# milk
# motor gasoline
# motorcycles
# motorcycles and scooters
# natural gas pipeline
# natural gas power
# natural gas production
# neoprene rubber
# nickel
# nickel production
# nickel-based battery
# nickel-metal hydride battery
# nitric acid
# nitrogen fertilizer
# nitrogenous fertilizers
# nox pollution controls (boilers)
# nuclear energy
# nuclear weapons
# objects launched into space
# offshore wind energy
# oil pipeline
# oil production
# oil refining capacity
# onshore wind energy
# paraxylene
# passenger cars
# passenger vehicles
# pcv3 vaccine
# pentaerythritol
# phenol
# phosphate fertilizer
# phthalic anhydride
# podcasting
# pol3 vaccine
# polyester fiber
# polystyrene
# polyvinylchloride
# postal traffic
# potash fertilizer
# potassic fertilizers
# power steering
# primary aluminum production
# primary bauxite production
# primary copper
# primary magnesium
# processor performance
# public roads
# pumped hydro storage
# pumped hydropower
# radial tires
# radio
# radio receivers
# railroad
# random access memory
# rare earth mine production
# raw steel production
# rcv1 vaccine
# real-time gross settlement adoption
# refined copper
# refrigerators
# renewable power
# rotac vaccine
# running water
# salt production
# sand and gravel|construction
# sand and gravel|industrial
# sensible heat storage
# shale production
# shotgun sanger dna sequencing
# silver
# silver production
# smartphone usage
# social media usage
# sodium
# sodium chlorate
# sodium-based battery storage
# sodium-sulphur battery
# solar photovoltaic
# solar thermal energy
# solid biofuels
# soybean production
# space launches
# stationary steam engines
# steam locomotives
# steamships
# stove
# styrene
# submarine cables
# sugar cane production
# sugar output
# sulphuric acid
# synthetic filament tow and staple fibers
# synthetic filament yarn
# tablet
# telegraph traffic
# telephones
# telephones and videophones
# television
# television receivers
# tin
# tin production
# titanium sponge
# transistors per microprocessor
# turbo-jets of a thrust not exceeding 25 kn
# urea
# vacuum cleaners
# vacuums
# vanadium redox-flow battery
# videocassette recorder
# vinyl acetate
# vinyl chloride
# washing machines
# water heater
# wet flue gas desulfurization systems
# yfv vaccine
# zinc
# zinc production
# zinc-based battery
